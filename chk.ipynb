# %%
# %autosave 10
# Out:
# Autosaving every 10 seconds

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
import random
import numpy as np
import re
import string
from string import digits
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
from nltk.translate.bleu_score import sentence_bleu

# %%
os.chdir("/content/drive/My Drive/NeuralMT")
os.listdir()
# Out:
# ['en_hi.pkl',
#  'data',
#  'cc.en.300.vec.gz',
#  'cc.hi.300.vec.gz',
#  'seq2seq_0.02.params',
#  'seq2seq_0.01.params']

# %% [markdown]
# #try cuda

# %%
data_folder = "data"
files = os.listdir(data_folder)
source_files = [os.path.join(data_folder, file) for file in files if ".en" in file]
target_files = [os.path.join(data_folder, file) for file in files if ".hi" in file]
print(source_files)

def generate_vocab(filenames):
    vocab = set()
    # no_words = 0
    for file in filenames:
        content = open(file).read()
        sentences = [sentence.split() for sentence in content.split('\n')]
        for sentence in sentences:
            for word in sentence:
                if word.lower() not in vocab:
                    vocab.add(word.lower())
                    # no_words += 1
    vocab = {word: num for num, word in enumerate(vocab)}
    return vocab

def parse_files_to_indices(filename, vocab):
    content = open(filename).read()
    return [[vocab[word] for word in sentence.split() if word in vocab] for sentence in content.split('\n')]

class Dataset:
    def __init__(self, source_files, target_files, batch_size=10):
        self.source_vocab = generate_vocab(source_files) #for entire lang
        self.target_vocab = generate_vocab(target_files) #for entire lang
        
        self.len_source = len(self.source_vocab.keys())
        self.source_pad, self.source_start, self.source_end = self.len_source + 2, self.len_source + 1, self.len_source
        self.len_target = len(self.target_vocab.keys())
        self.target_pad, self.target_start, self.target_end = self.len_target + 2, self.len_target + 1, self.len_target
        
        self.source_vocab['<pad>'], self.source_vocab['<start>'], self.source_vocab['<end>'] = [self.source_pad, 
                                                                                                self.source_start, 
                                                                                                self.source_end]
        self.target_vocab['<pad>'], self.target_vocab['<start>'], self.target_vocab['<end>'] = [self.target_pad,
                                                                                                self.target_start, 
                                                                                                self.target_end]
                                                                                              
        ##created indices for <pad>, <start> and <end> tokens
        self.len_source = len(self.source_vocab.keys())
        self.len_target = len(self.target_vocab.keys())
        
        ##inverse vocab for entire lang
        self.source_vocab_inv = {value:key for key, value in self.source_vocab.items()}
        self.target_vocab_inv = {value:key for key, value in self.target_vocab.items()}
        
        ##parsing files into indices
        for filename in source_files:
            if 'train' in filename:
                self.source_train = parse_files_to_indices(filename, self.source_vocab)
            if 'test' in filename:
                self.source_test = parse_files_to_indices(filename, self.source_vocab)
            if 'dev' in filename:
                self.source_dev = parse_files_to_indices(filename, self.source_vocab)
                
        for filename in target_files:
            if 'train' in filename:
                self.target_train = parse_files_to_indices(filename, self.target_vocab)
            if 'test' in filename:
                self.target_test = parse_files_to_indices(filename, self.target_vocab)
            if 'dev' in filename:
                self.target_dev = parse_files_to_indices(filename, self.target_vocab)
                
        ##random shuffling of training data before splitting into batches    
        self.indices = list(range(len(self.source_train)))
        random.shuffle(self.indices)
        self.current = -batch_size
        self.batch_size = batch_size
        
    def __get_batch_input(self, indices):
        source, target_input, target_target = [], [], []
        
        # padding length of sentence
        source_max_len = max(len(self.source_train[i]) for i in indices)
        target_max_len = max(len(self.target_train[i]) for i in indices)
        
        for i in indices:
            length = len(self.source_train[i])
            # reverse_source_sentences and pad at beginning
            sentence = [self.source_pad for _ in range(source_max_len - length)] + [self.source_end] + self.source_train[i][::-1] + [self.source_start]
            source.append(sentence)
            
            length = len(self.target_train[i])
            # padding at end for target
            sentence = [self.target_start] + self.target_train[i] + [self.target_end] + [self.target_pad for _ in range(target_max_len - length)]
            target_input.append(sentence)
            #removed <sos> and put <pad> at end
            target_target.append(sentence[1:] + [self.target_pad])
            
        return np.array(source), np.array(target_input), np.array(target_target)
    
    def get_batch_input(self):
        if self.current > len(self.indices) - self.batch_size:
            self.current = 0
            return None, None, None
        self.current += self.batch_size
        return self.__get_batch_input(self.indices[self.current: self.current + self.batch_size])
    
    def convert_indices_to_words(self, indices):
        output = []
        for sentence in indices:
            s = []
            for word in sentence:
                s.append(self.target_vocab_inv[word])
            output.append(s)
        return output


# ```
# %run seq2seq.ipynb
# 
# d = Dataset(source_files, target_files, 10)
# m = Seq2Seq(d.len_source, d.len_target, 9, 7)
# m.cuda()
# 
# a, b = d.get_batch_input()
# source, target = torch.cuda.LongTensor(a), torch.cuda.LongTensor(b)
# 
# # For teacher forcing:
# m(source, target)
# 
# # Using model's own predictions:
# m(source)
# ```

# In[37]:


def train(model, dataset, coverage=False, coverage_type="linguistic", iterations=1, use_teacher_forcing=True, log=True):
    # TODO: attention error
    loss_func = nn.NLLLoss()
    attn_loss_func = nn.MSELoss()
    
    optimizer = optim.Adagrad(model.parameters()) 
    
    for i in range(iterations):
        while True:
            optimizer.zero_grad() #set the gradients to zero before starting to do backpropragation because PyTorch accumulates the gradients on subsequent backward passes.
            source, target_input, target_output = d.get_batch_input() #sentences made into indices and padded to sentence lenght 

            if source is None: # end of current iteration
                break

            source, target_input, target_output = [torch.LongTensor(source), 
                                                   torch.LongTensor(target_input).cuda, 
                                                   torch.LongTensor(target_output).cuda]
            
            source_mask = torch.ones(source.shape).cuda()
            source_mask[source == dataset.source_pad] = 0
            
            if use_teacher_forcing:
                pred, attn = model(source, target_input, source_mask=source_mask)
                # mask whatevers after <stop> 
                target_mask = torch.ones(target_output.shape).cuda()
                target_mask[target_output == dataset.target_pad] = 0
                pred = pred * target_mask.unsqueeze(-1)
                target_output = target_output * target_mask.long()
            else:
                pred, attn_weights = model(source)
                
            no_words = pred.shape[0] * pred.shape[1]
            pred = pred.reshape(no_words, -1)
            target_output = target_output.reshape(no_words)

            pred_error = loss_func(pred, target_output)
            attn_error = None
            
            if coverage:
                # if coverage type is linguistic, ignore fertility
                attn_weights, fertility = attn
                if coverage_type == "linguistic":
                    fertility = torch.ones(fertility.shape).cuda()
                attn_error = attn_loss_func(torch.sum(attn_weights, dim=-1) * source_mask, fertility * source_mask)
                pred_error += attn_error
                
            pred_error.backward() #backward prop
            optimizer.step()
            
            if log:
                print(d.current/d.batch_size, pred_error, end='\r')


# In[38]:


def convert_pred_to_indices(pred):
    return torch.max(pred, dim=-1)[1]


# In[39]:


def eval(model, dataset, log=False, source_test=None, target_test=None):
    scores = []
    if source_test is None:
        source_test = dataset.source_test
        target_test = dataset.target_test
        
    for sentence, target in zip(source_test, target_test):
        input = torch.LongTensor([[dataset.source_end] + sentence[::-1] + [dataset.source_start]]).cuda
        pred, _ = model(input).cuda()
        pred_words = convert_pred_to_indices(pred).cpu().numpy()
        predicted_target = dataset.convert_indices_to_words(pred_words)
        target = dataset.convert_indices_to_words([target])
        if log:
            print(target, predicted_target[0])
        scores.append(sentence_bleu(target, predicted_target[0], weights=(1, 0, 0, 0)))
    return sum(scores)/len(scores)
# Out:
# ['data/dev.en', 'data/train.en', 'data/test.en']

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import numpy as np


# In[2]:


import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as f


# In[3]:


class Encoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.encoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        
    def forward(self, input):
        '''
        input dim => 2d no_sentences * no_words
        make sure that the input is in reverse
        
        Outputs:
        output, h, c
        
        output => dim: (num_sentences * num_words * hidden_dim)
        h => (num_layers * num_sentences * hidden_dim)
        c => (num_layers * num_sentences * hidden_dim)
        '''
        embeddings = self.embedding(input)
        output, (h, c) = self.encoder(embeddings)
        
        return output, h, c


# In[4]:


class Decoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0, start_dim=1):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.decoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        self.word_predictor = nn.Linear(hidden_dim, num_embeddings)
        self.start_dim = start_dim
        
    def forward(self, output, h, c, input=None, max_sen_len=20):
        '''
        Output:
        pred: (no_sentences * no_words * no_embeddings)
        **Note: if input is not None, log_softmax is returned
        else, input is returned without softmax**
        '''
        
        if input is not None: # training with teacher forcing
            
            embeddings = self.embedding(input)
            yts, _ = self.decoder(embeddings, (h, c))
            orig_shape = yts.shape
            pred = self.word_predictor(yts.reshape(orig_shape[0]*orig_shape[1], -1)).reshape(*orig_shape[:-1], -1)
            return torch.log_softmax(pred, dim=-1), None
        
        else: # training using the decoders' own predictions
            
            num_sentences = output.shape[0]
            words_selected = torch.LongTensor([[self.start_dim] for _ in range(num_sentences)]).cuda
            pred = []
            for i in range(max_sen_len):
                embeddings = self.embedding(words_selected)
                y_t, (h, c) = self.decoder(embeddings, (h, c))
                orig_shape = y_t.shape
                pred_t = self.word_predictor(y_t.reshape(orig_shape[0]*orig_shape[1], 
                                                         -1)).reshape(*orig_shape[:-1], -1).squeeze(1)
                pred.append(pred_t)
                words_selected = torch.max(pred_t, dim=1)[1].unsqueeze(1)
            
            pred = torch.stack(pred, dim=1)
            return torch.log_softmax(pred, dim=-1), None


# In[5]:


class Seq2Seq(nn.Module):
    def __init__(self, source_vocab_len, target_vocab_len, embedding_dim, hidden_dim, num_layers=1,
                       padding_dim_source=0, start_dim_target=1, padding_dim_target=0):
        super().__init__()
        self.encoder = Encoder(source_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_source)
        self.decoder = Decoder(target_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_target, start_dim_target)
        
    def forward(self, source_input, target_input=None, source_mask=None):
        output, h, c = self.encoder(source_input)
        return self.decoder(output, h, c, target_input)


# **Without teacher forcing**
# ```
# input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s = Seq2Seq(10, 12, 9, 7)
# s.cuda()
# pred = s(input)
# ```

# **With teacher forcing**
# 
# ```
# tar_input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s(input, tar_input).shape
# ```

# In[ ]:

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cuda:0

# %%
#!/usr/bin/env python
# coding: utf-8

# In[30]:


# get_ipython().run_line_magic('run', 'utils.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq_with_attention.ipynb')
# get_ipython().run_line_magic('run', 'effective_approaches.ipynb')
# get_ipython().run_line_magic('run', 'coverage.ipynb')


# In[4]:

# device = 'cuda' if torch.cuda.is_available() else 'cpu'
# m.to(device)
# torch.cuda.set_device(0)
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# In[24]:


d = Dataset(source_files, target_files, batch_size=10)
embedding_dim = 50
hidden_dim = 100
num_layers = 2


# In[25]:


def train_and_save(m, d, str_, coverage=False, coverage_type="linguistic", log=False):
    prev_score = -1
    for i in range(20):
        train(m, d, coverage, coverage_type, log=log)
        score = eval(m, d)
        best_state = None
        print()
        print(score)
        if score > prev_score:
            #torch.save(m.state_dict(), str_ + str(score)[:4] + ".params_")
            best_state = m.state_dict()
            prev_score = score
            
    torch.save(best_state, str_ + str(prev_score)[:4] + ".params")
    print(prev_score)


# In[26]:

m = Seq2Seq(d.len_source, d.len_target, embedding_dim, hidden_dim, num_layers=2, 
            padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
#print(m.cuda())
train_and_save(m, d, "seq2seq_")


# In[ ]:


# m = Seq2SeqWithAttention(d.len_source, d.len_target, embedding_dim, hidden_dim, num_layers=2, 
#             padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
# print(m.cuda())
# train_and_save(m, d, "attention_")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-a2e13d2680a4> in <module>()
#      53             padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start).cuda()
#      54 #print(m.cuda())
# ---> 55 train_and_save(m, d, "seq2seq_")
#      56
#      57
#
# <ipython-input-12-a2e13d2680a4> in train_and_save(m, d, str_, coverage, coverage_type, log)
#      34     prev_score = -1
#      35     for i in range(20):
# ---> 36         train(m, d, coverage, coverage_type, log=log)
#      37         score = eval(m, d)
#      38         best_state = None
#
# <ipython-input-10-27ac5ca06b99> in train(model, dataset, coverage, coverage_type, iterations, use_teacher_forcing, log)
#     153
#     154             if use_teacher_forcing:
# --> 155                 pred, attn = model(source, target_input, source_mask=source_mask)
#     156                 # mask whatevers after <stop>
#     157                 target_mask = torch.ones(target_output.shape).cuda()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# <ipython-input-11-640a51409340> in forward(self, source_input, target_input, source_mask)
#     100
#     101     def forward(self, source_input, target_input=None, source_mask=None):
# --> 102         output, h, c = self.encoder(source_input)
#     103         return self.decoder(output, h, c, target_input)
#     104
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# <ipython-input-11-640a51409340> in forward(self, input)
#      38         c => (num_layers * num_sentences * hidden_dim)
#      39         '''
# ---> 40         embeddings = self.embedding(input)
#      41         output, (h, c) = self.encoder(embeddings)
#      42
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/sparse.py in forward(self, input)
#     124         return F.embedding(
#     125             input, self.weight, self.padding_idx, self.max_norm,
# --> 126             self.norm_type, self.scale_grad_by_freq, self.sparse)
#     127
#     128     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    1812         # remove once script supports set_grad_enabled
#    1813         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 1814     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    1815
#    1816
#
# RuntimeError: Expected object of device type cuda but got device type cpu for argument #3 'index' in call to _th_index_select

# %% [markdown]
# #try cpu

# %%
import re
import string
from string import digits

# %%
import pandas as pd
df = pd.read_pickle('en_hi.pkl')

# %%
df.head(20)
# Out:
#                               english                           hindi
# 57382              Who is this man?\n             -ये आदमी कौन है ?\n
# 28149        And the other brother?\n                 और दूसरे भाई?\n
# 80284  - Greetings, Mustakeen bhai.\n        नमस्ते, Mustakeen भाई।\n
# 63596     Please, reason with them.\n  कृपया, उन लोगों के साथ कारण.\n
# 9459        There's a howling gale.\n             तेज़ हवा आ रही है।\n
# 67410              - No, you don't.\n           - नहीं , कभी नहीं .\n
# 89506       the violence, the rage.\n              हिंसा, स्पूर्ति।\n
# 71637        Signal decoy in place.\n         सिग्नल जगह में लूभाव।\n
# 66488           You guys come with?\n    तुम लोग इसे ले तो आये हो ?\n
# 52809         How long you staying?\n                 तुम कब तक रह?\n
# 81442              Who is this now?\n                 अब यह कौन है?\n
# 59132       How's Rosie doing, Jim?\n     कैसे रोजी, जिम कर रहा है?\n
# 46795       100 feet radius, clear.\n     100 फुट त्रिज्या, स्पष्ट.\n
# 66121              - It's not safe.\n                 वहाँ खतरा है।\n
# 19491        TREVOR: No, no, don't.\n    नहीं, नहीं नहीं करते हैं,.\n
# 75022       Your passport is ready.\n       आपका पासपोर्ट तैयार है।\n
# 74177            Come on, let's go.\n                 चलो चलते हैं।\n
# 9285           "fruit of thy womb".\n         "तुम्हारे पेट का फल".\n
# 61090           Agh, that is tight.\n                तंग है कि आह,.\n
# 52338               - Is this wool?\n                   - यह ऊन है?\n

# %%
lines = df.copy()
# general
lines['english']=lines['english'].apply(lambda x: re.sub(r"n\'t", " not", x))
lines['english']=lines['english'].apply(lambda x: re.sub(r"\'re", " are", x))
lines['english']=lines['english'].apply(lambda x: re.sub(r"\'s", " is", x))
lines['english']=lines['english'].apply(lambda x: re.sub(r"n\'d", " would", x))
lines['english']=lines['english'].apply(lambda x: re.sub(r"n\'ll", " will", x))
lines['english']=lines['english'].apply(lambda x: re.sub(r"n\'ve", " have", x))
lines['english']=lines['english'].apply(lambda x: re.sub(r"n\'m", " am", x))

lines['hindi'] = lines['hindi'].apply(lambda x: x.replace('.',' ।'))
# lines['hindi'] = lines['hindi'].apply(lambda x: x.replace('।',' ।'))

# lines['english']=lines['english'].apply(lambda x: re.sub(r"n\in'", "ing", x))

# Lowercase all characters
lines['english']=lines['english'].apply(lambda x: x.lower())
lines['hindi']=lines['hindi'].apply(lambda x: x.lower())


exclude = set(['$','&','+',':',';','=','@','|','<','>','^','*','%','-','#','\'']) # Set of all special characters
# Remove all the special characters
lines['english']=lines['english'].apply(lambda x: ''.join(ch for ch in x if ch not in exclude))
lines['hindi']=lines['hindi'].apply(lambda x: ''.join(ch for ch in x if ch not in exclude))

# Remove all numbers from text
remove_digits = str.maketrans('', '', digits)
lines['english']=lines['english'].apply(lambda x: x.translate(remove_digits))
lines['hindi']=lines['hindi'].apply(lambda x: x.translate(remove_digits))

lines['hindi'] = lines['hindi'].apply(lambda x: re.sub("[२३०८१५७९४६]", "", x))

# Remove extra spaces
lines['english']=lines['english'].apply(lambda x: x.strip())
lines['hindi']=lines['hindi'].apply(lambda x: x.strip())
lines['english']=lines['english'].apply(lambda x: re.sub(" +", " ", x))
lines['hindi']=lines['hindi'].apply(lambda x: re.sub(" +", " ", x))

# Add start and end tokens to target sequences
lines['hindi'] = lines['hindi'].apply(lambda x :  x + '\n')

lines['english'] = lines['english'].apply(lambda x : x + '\n')
lines.head(20)
# Out:
#                             english                            hindi
# 57382            who is this man?\n               ये आदमी कौन है ?\n
# 28149      and the other brother?\n                  और दूसरे भाई?\n
# 80284  greetings, mustakeen bhai.\n         नमस्ते, mustakeen भाई।\n
# 63596   please, reason with them.\n  कृपया, उन लोगों के साथ कारण ।\n
# 9459     there is a howling gale.\n              तेज़ हवा आ रही है।\n
# 67410             no, you do not.\n              नहीं , कभी नहीं ।\n
# 89506     the violence, the rage.\n               हिंसा, स्पूर्ति।\n
# 71637      signal decoy in place.\n          सिग्नल जगह में लूभाव।\n
# 66488         you guys come with?\n     तुम लोग इसे ले तो आये हो ?\n
# 52809       how long you staying?\n                  तुम कब तक रह?\n
# 81442            who is this now?\n                  अब यह कौन है?\n
# 59132    how is rosie doing, jim?\n      कैसे रोजी, जिम कर रहा है?\n
# 46795         feet radius, clear.\n         फुट त्रिज्या, स्पष्ट ।\n
# 66121             it is not safe.\n                  वहाँ खतरा है।\n
# 19491      trevor no, no, do not.\n    नहीं, नहीं नहीं करते हैं, ।\n
# 75022     your passport is ready.\n        आपका पासपोर्ट तैयार है।\n
# 74177         come on, let is go.\n                  चलो चलते हैं।\n
# 9285         "fruit of thy womb".\n         "तुम्हारे पेट का फल" ।\n
# 61090         agh, that is tight.\n                तंग है कि आह, ।\n
# 52338               is this wool?\n                      यह ऊन है?\n

# %%
# for index,row in lines[:10].iterrows():
#   # for lan in ['english','hindi']:
  
#     ret = [re.sub(fr'([{string.punctuation}])\B', r' \1', row[lan]).split() for lan in ['english','hindi']]
#     print(ret)

# %%
train, validate, test = np.split(lines.sample(frac=1), [int(.7*len(df)), int(.8*len(df))])
print(train.shape, validate.shape, test.shape)
# Out:
# (7000, 2) (1000, 2) (2000, 2)

# %%
# for index,row in train[:10].iterrows():
#   # for lan in ['english','hindi']:
  
#     ret = [re.sub(fr'([{string.punctuation  }])\B', r' \1', str(row)).split()]
#     print(ret)
#     print(index,row)
# Out:
# [['english', 'i', 'knew', 'hed', 'go', '.', '.', '.', 'hindi', 'वे', 'आ', 'गए', '!', 'Name', ':', '6768', ',', 'dtype', ':', 'object']]
# 6768 english    i knew hed go...
# hindi              वे आ गए!
# Name: 6768, dtype: object
# [['english', 'write', 'it', 'all', 'down', '.', 'hindi', 'सब', 'लिखते', 'जाओ', '।', 'Name', ':', '628', ',', 'dtype', ':', 'object']]
# 628 english    write it all down.
# hindi          सब लिखते जाओ ।
# Name: 628, dtype: object
# [['english', 'look', 'at', 'his', 'mouth', '.', 'hindi', 'उसका', 'मुंह', 'देखो', '।', 'Name', ':', '11421', ',', 'dtype', ':', 'object']]
# 11421 english    look at his mouth.
# hindi        उसका मुंह देखो ।
# Name: 11421, dtype: object
# [['english', 'have', 'we', 'passed', 'eingarsstadir', '?', 'hindi', 'हम', 'eingarsstadir', 'पारित', 'कर', 'दिया', 'क्या', '?', 'Name', ':', '18769', ',', 'dtype', ':', 'object']]
# 18769 english           have we passed eingarsstadir?
# hindi      हम eingarsstadir पारित कर दिया क्या?
# Name: 18769, dtype: object
# [['english', 'but', ',', 'sir', ',', 'he', 'was', 'not', '.', 'hindi', 'लेकिन', ',', 'श्रीमान', ',', 'वह', 'नहीं', 'था', '।', 'Name', ':', '6415', ',', 'dtype', ':', 'object']]
# 6415 english           but, sir, he was not.
# hindi      लेकिन, श्रीमान, वह नहीं था ।
# Name: 6415, dtype: object
# [['english', 'i', 'searched', 'for', 'you', 'hindi', 'मैं', 'आप', 'के', 'लिए', 'खोज', 'Name', ':', '81995', ',', 'dtype', ':', 'object']]
# 81995 english    i searched for you
# hindi       मैं आप के लिए खोज
# Name: 81995, dtype: object
# [['english', 'see', ',', 'he', 'was', 'here', '!', 'hindi', 'देखो', ',', 'वह', 'यहीं', 'था', '!', 'Name', ':', '565', ',', 'dtype', ':', 'object']]
# 565 english    see, he was here!
# hindi      देखो, वह यहीं था!
# Name: 565, dtype: object
# [['english', 'let', 'is', 'find', 'her', '.', 'hindi', 'चलो', 'उसे', 'ढूढते', 'हैं', '।', 'Name', ':', '22261', ',', 'dtype', ':', 'object']]
# 22261 english       let is find her.
# hindi      चलो उसे ढूढते हैं ।
# Name: 22261, dtype: object
# [['english', 'and', 'i', 'handled', 'it', '.', 'hindi', 'और', 'मैं', 'इसे', 'संभाला', '।', 'Name', ':', '32716', ',', 'dtype', ':', 'object']]
# 32716 english      and i handled it.
# hindi      और मैं इसे संभाला ।
# Name: 32716, dtype: object
# [['english', 'i', 'have', 'a', 'plan', '.', 'hindi', 'मैं', 'एक', 'योजना', 'है', '।', 'Name', ':', '41122', ',', 'dtype', ':', 'object']]
# 41122 english       i have a plan.
# hindi      मैं एक योजना है ।
# Name: 41122, dtype: object

# %%
# with open('/content/drive/My Drive/NeuralMT/data/dev.en', 'w') as writefile:
#     writefile.write(('\n').join(validate['english']))
# with open('/content/drive/My Drive/NeuralMT/data/dev.hi', 'w') as writefile:
#     writefile.write(('\n').join(validate['hindi']))
# with open('/content/drive/My Drive/NeuralMT/data/test.en', 'w') as writefile:
#     writefile.write(('\n').join(test['english']))
# with open('/content/drive/My Drive/NeuralMT/data/test.hi', 'w') as writefile:
#     writefile.write(('\n').join(test['hindi']))
# with open('/content/drive/My Drive/NeuralMT/data/train.en', 'w') as writefile:
#     writefile.write(('\n').join(train['english']))
# with open('/content/drive/My Drive/NeuralMT/data/train.hi', 'w') as writefile:
#     writefile.write(('\n').join(train['hindi']))

with open('/content/drive/My Drive/NeuralMT/data/dev.en', 'w') as writefile:
    writefile.write(('').join(validate['english']))
with open('/content/drive/My Drive/NeuralMT/data/dev.hi', 'w') as writefile:
    writefile.write(('').join(validate['hindi']))
with open('/content/drive/My Drive/NeuralMT/data/test.en', 'w') as writefile:
    writefile.write(('').join(test['english']))
with open('/content/drive/My Drive/NeuralMT/data/test.hi', 'w') as writefile:
    writefile.write(('').join(test['hindi']))
with open('/content/drive/My Drive/NeuralMT/data/train.en', 'w') as writefile:
    writefile.write(('').join(train['english']))
with open('/content/drive/My Drive/NeuralMT/data/train.hi', 'w') as writefile:
    writefile.write(('').join(train['hindi']))

# %%
data_folder = "data"
files = os.listdir(data_folder)
source_files = [os.path.join(data_folder, file) for file in files if ".en" in file]
target_files = [os.path.join(data_folder, file) for file in files if ".hi" in file]
print(source_files)

def generate_vocab(filenames):
    vocab = set()
    # no_words = 0
    for file in filenames:
        content = open(file).read()
        sentences = [re.sub(fr'([{string.punctuation}])\B', r' \1', sentence).split() for sentence in content.split('\n')]
        for sentence in sentences:
            for word in sentence:
                if word.lower() not in vocab:
                    vocab.add(word.lower())
                    # no_words += 1

    vocab = {word: num for num, word in enumerate(vocab)}
    return vocab

def parse_files_to_indices(filename, vocab):
    content = open(filename).read()
    return [[vocab[word] for word in re.sub(fr'([{string.punctuation}])\B', r' \1', sentence).split() if word in vocab] for sentence in content.split('\n')]

class Dataset:
    def __init__(self, source_files, target_files, batch_size=10):
        self.source_vocab = generate_vocab(source_files) #for entire lang
        self.target_vocab = generate_vocab(target_files) #for entire lang
        
        self.len_source = len(self.source_vocab.keys())
        self.source_pad, self.source_start, self.source_end = self.len_source + 2, self.len_source + 1, self.len_source
        self.len_target = len(self.target_vocab.keys())
        self.target_pad, self.target_start, self.target_end = self.len_target + 2, self.len_target + 1, self.len_target
        
        self.source_vocab['<pad>'], self.source_vocab['<start>'], self.source_vocab['<end>'] = [self.source_pad, 
                                                                                                self.source_start, 
                                                                                                self.source_end]
        self.target_vocab['<pad>'], self.target_vocab['<start>'], self.target_vocab['<end>'] = [self.target_pad,
                                                                                                self.target_start, 
                                                                                                self.target_end]
                                                                                              
        ##created indices for <pad>, <start> and <end> tokens
        self.len_source = len(self.source_vocab.keys())
        self.len_target = len(self.target_vocab.keys())
        
        ##inverse vocab for entire lang
        self.source_vocab_inv = {value:key for key, value in self.source_vocab.items()}
        self.target_vocab_inv = {value:key for key, value in self.target_vocab.items()}
        
        ##parsing files into indices
        for filename in source_files:
            if 'train' in filename:
                self.source_train = parse_files_to_indices(filename, self.source_vocab)
            if 'test' in filename:
                self.source_test = parse_files_to_indices(filename, self.source_vocab)
            if 'dev' in filename:
                self.source_dev = parse_files_to_indices(filename, self.source_vocab)
                
        for filename in target_files:
            if 'train' in filename:
                self.target_train = parse_files_to_indices(filename, self.target_vocab)
            if 'test' in filename:
                self.target_test = parse_files_to_indices(filename, self.target_vocab)
            if 'dev' in filename:
                self.target_dev = parse_files_to_indices(filename, self.target_vocab)
                
        ##random shuffling of training data before splitting into batches    
        self.indices = list(range(len(self.source_train)))
        random.shuffle(self.indices)
        self.current = -batch_size
        self.batch_size = batch_size
        
    def __get_batch_input(self, indices):
        source, target_input, target_target = [], [], []
        
        # padding length of sentence
        source_max_len = max(len(self.source_train[i]) for i in indices)
        target_max_len = max(len(self.target_train[i]) for i in indices)
        
        for i in indices:
            length = len(self.source_train[i])
            # reverse_source_sentences and pad at beginning
            sentence = [self.source_pad for _ in range(source_max_len - length)] + [self.source_end] + self.source_train[i][::-1] + [self.source_start]
            source.append(sentence)
            
            length = len(self.target_train[i])
            # padding at end for target
            sentence = [self.target_start] + self.target_train[i] + [self.target_end] + [self.target_pad for _ in range(target_max_len - length)]
            target_input.append(sentence)
            #removed <sos> and put <pad> at end
            target_target.append(sentence[1:] + [self.target_pad])
            
        return np.array(source), np.array(target_input), np.array(target_target)
    
    def get_batch_input(self):
        if self.current > len(self.indices) - self.batch_size:
            self.current = 0
            return None, None, None
        self.current += self.batch_size
        return self.__get_batch_input(self.indices[self.current: self.current + self.batch_size])
    
    def convert_indices_to_words(self, indices):
        output = []
        for sentence in indices:
            s = []
            for word in sentence:
                if word == self.target_end:
                  break
                s.append(self.target_vocab_inv[word])
            output.append(s)
        return output

    def convert_indices_to_words_eng(self, indices):
        output = []
        for sentence in indices:
            s = []
            for word in sentence:
                s.append(self.source_vocab_inv[word])
            output.append(s)
        return output


# ```
# %run seq2seq.ipynb
# 
# d = Dataset(source_files, target_files, 10)
# m = Seq2Seq(d.len_source, d.len_target, 9, 7)
# m.cuda()
# 
# a, b = d.get_batch_input()
# source, target = torch.cuda.LongTensor(a), torch.cuda.LongTensor(b)
# 
# # For teacher forcing:
# m(source, target)
# 
# # Using model's own predictions:
# m(source)
# ```

# In[37]:


def train(model, dataset, coverage=False, coverage_type="linguistic", iterations=1, use_teacher_forcing=True, log=True):
    # TODO: attention error
    loss_func = nn.NLLLoss()
    attn_loss_func = nn.MSELoss()
    
    optimizer = optim.Adagrad(model.parameters()) 
    
    for i in range(iterations):
        iter_loss = 0
        while True:
            
            optimizer.zero_grad() #set the gradients to zero before starting to do backpropragation because PyTorch accumulates the gradients on subsequent backward passes.
            source, target_input, target_output = d.get_batch_input() #sentences made into indices and padded to sentence lenght 

            if source is None: # end of current iteration
                break

            source, target_input, target_output = [torch.LongTensor(source), 
                                                   torch.LongTensor(target_input), 
                                                   torch.LongTensor(target_output)]
            
            source_mask = torch.ones(source.shape)
            source_mask[source == dataset.source_pad] = 0
            
            if use_teacher_forcing:
                pred, attn = model(source, target_input, source_mask=source_mask)
                # mask whatevers after <stop> 
                target_mask = torch.ones(target_output.shape)
                target_mask[target_output == dataset.target_pad] = 0
                pred = pred * target_mask.unsqueeze(-1)
                target_output = target_output * target_mask.long()
            else:
                pred, attn_weights = model(source)
                
            no_words = pred.shape[0] * pred.shape[1]
            pred = pred.reshape(no_words, -1)
            target_output = target_output.reshape(no_words)

            pred_error = loss_func(pred, target_output)
            iter_loss += pred_error
            # print("loss ", pred_error)
            attn_error = None

                
            pred_error.backward() #backward prop
            optimizer.step()
            
            if log:
                print(d.current/d.batch_size, pred_error, end='\r')
        print("loss ", iter_loss)


# In[38]:


def convert_pred_to_indices(pred):
    return torch.max(pred, dim=-1)[1]


# In[39]:


def eval(model, dataset, log=False, source_test=None, target_test=None):
    scores = []
    if source_test is None:
        source_test = dataset.source_test
        target_test = dataset.target_test
        
    for sentence, target in zip(source_test, target_test):
        input_text = dataset.convert_indices_to_words_eng(sentence[::-1] )
        input = torch.LongTensor([[dataset.source_end] + sentence[::-1] + [dataset.source_start]])

        pred, _ = model(input)
        pred_words = convert_pred_to_indices(pred).cpu().numpy()
        
        predicted_target = dataset.convert_indices_to_words(pred_words)
        target = dataset.convert_indices_to_words([target])
        if log:
            print(input_text,target, predicted_target[0])
        scores.append(sentence_bleu(target, predicted_target[0], weights=(1, 0, 0, 0)))
    return sum(scores)/len(scores)
# Out:
# ['data/dev.en', 'data/test.en', 'data/train.en']

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import numpy as np


# In[2]:


import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as f


# In[3]:


class Encoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.encoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        
    def forward(self, input):
        '''
        input dim => 2d no_sentences * no_words
        make sure that the input is in reverse
        
        Outputs:
        output, h, c
        
        output => dim: (num_sentences * num_words * hidden_dim)
        h => (num_layers * num_sentences * hidden_dim)
        c => (num_layers * num_sentences * hidden_dim)
        '''
        embeddings = self.embedding(input)
        output, (h, c) = self.encoder(embeddings)
        
        return output, h, c


# In[4]:


class Decoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0, start_dim=1):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.decoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        self.word_predictor = nn.Linear(hidden_dim, num_embeddings)
        self.start_dim = start_dim
        
    def forward(self, output, h, c, input=None, max_sen_len=20):
        '''
        Output:
        pred: (no_sentences * no_words * no_embeddings)
        **Note: if input is not None, log_softmax is returned
        else, input is returned without softmax**
        '''
        
        if input is not None: # training with teacher forcing
            
            embeddings = self.embedding(input)
            yts, _ = self.decoder(embeddings, (h, c))
            orig_shape = yts.shape
            pred = self.word_predictor(yts.reshape(orig_shape[0]*orig_shape[1], -1)).reshape(*orig_shape[:-1], -1)
            return torch.log_softmax(pred, dim=-1), None
        
        else: # training using the decoders' own predictions
            
            num_sentences = output.shape[0]
            words_selected = torch.LongTensor([[self.start_dim] for _ in range(num_sentences)])
            pred = []
            for i in range(max_sen_len):
                embeddings = self.embedding(words_selected)
                y_t, (h, c) = self.decoder(embeddings, (h, c))
                orig_shape = y_t.shape
                pred_t = self.word_predictor(y_t.reshape(orig_shape[0]*orig_shape[1], 
                                                         -1)).reshape(*orig_shape[:-1], -1).squeeze(1)

                pred.append(pred_t)
                words_selected = torch.max(pred_t, dim=1)[1].unsqueeze(1)
            
            pred = torch.stack(pred, dim=1)
            return torch.log_softmax(pred, dim=-1), None


# In[5]:


class Seq2Seq(nn.Module):
    def __init__(self, source_vocab_len, target_vocab_len, embedding_dim, hidden_dim, num_layers=1,
                       padding_dim_source=0, start_dim_target=1, padding_dim_target=0):
        super().__init__()
        self.encoder = Encoder(source_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_source)
        self.decoder = Decoder(target_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_target, start_dim_target)
        
    def forward(self, source_input, target_input=None, source_mask=None):
        output, h, c = self.encoder(source_input)
        return self.decoder(output, h, c, target_input)


# **Without teacher forcing**
# ```
# input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s = Seq2Seq(10, 12, 9, 7)
# s.cuda()
# pred = s(input)
# ```

# **With teacher forcing**
# 
# ```
# tar_input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s(input, tar_input).shape
# ```

# In[ ]:

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cpu

# %%
#!/usr/bin/env python
# coding: utf-8

# In[30]:


# get_ipython().run_line_magic('run', 'utils.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq_with_attention.ipynb')
# get_ipython().run_line_magic('run', 'effective_approaches.ipynb')
# get_ipython().run_line_magic('run', 'coverage.ipynb')


# In[4]:

# device = 'cuda' if torch.cuda.is_available() else 'cpu'
# m.to(device)
# torch.cuda.set_dezce(0)
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# In[24]:


d = Dataset(source_files, target_files, batch_size=10)
embedding_dim = 50
hidden_dim = 100
num_layers = 2


# In[25]:


def train_and_save(m, d, str_, coverage=False, coverage_type="linguistic", log=False):
    prev_score = -1
    for i in range(20):
        train(m, d, coverage, coverage_type, log=log)
        score = eval(m, d, log=True)
        best_state = None
        print()
        print(score)
        if score > prev_score:
            #torch.save(m.state_dict(), str_ + str(score)[:4] + ".params_")
            best_state = m.state_dict()
            prev_score = score
            
    torch.save(best_state, str_ + str(prev_score)[:4] + ".params")
    print(prev_score)


# In[26]:

m = Seq2Seq(d.len_source, d.len_target, embedding_dim, hidden_dim, num_layers=2, 
            padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
#print(m.cuda())
train_and_save(m, d, "seq2seq_")


# In[ ]:


# m = Seq2SeqWithAttention(d.len_source, d.len_target, embedding_dim, hidden_dim, num_layers=2, 
#             padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
# print(m.cuda())
# train_and_save(m, d, "attention_")
# Out:
# loss  tensor(2292.8496, grad_fn=<AddBackward0>)
# [['<end>', '.', 'not', 'ca', 'you', ',', 'clark', ',', 'no', '<start>']] [['नहीं', ',', 'क्लार्क', ',', 'तुम', 'नहीं', 'कर', 'सकते।']] ['यह', ',', 'यह', ',', 'यह', 'नहीं', 'है', '।']
# [['<end>', '.', 'tommelilla', 'from', 'karlsson', 'lasse', 'im', '<start>']] [['मैं', 'हूँ', 'लेसे', 'कार्लस्सन', 'टॉमेलिला', 'से', '।']] ['मैं', 'एक', 'एक', 'लिए', 'है', '।']
# [['<end>', '.', 'day', 'every', 'there', 'up', 'is', 'he', '<start>']] [['वह', 'वहाँ', 'हर', 'दिन', 'जाता', 'है', '।']] ['वह', 'एक', 'एक', 'के', 'लिए', 'है', '।']
# [['<end>', '.', 'hurry', 'to', 'need', 'we', '<start>']] [['हमें', 'जल्दी', 'करनी', 'होगी।']] ['मैं', 'एक', 'एक', 'लिए', '।']
# [['<end>', '.', 'down', 'gun', 'the', 'put', 'just', '<start>']] [['बस', 'नीचे', 'बंदूक', 'रख', 'दिया।']] ['मैं', 'एक', 'के', 'लिए', 'लिए', '।']
# [['<end>', ']', 'chirping', 'insects', '[', '<start>']] [['[चहकती', 'कीड़े', ']']] ['मैं', 'के', 'लिए', 'है', '।']
# [['<end>', '.', 'family', 'protect', 'we', 'and', '<start>']] [['और', 'हम', 'परिवार', 'की', 'रक्षा।']] ['मैं', 'एक', 'एक', 'लिए', '।']
# [['<end>', '?', 'out', 'got', 'he', 'if', 'what', '<start>']] [['क्या', 'होगा', 'अगर', 'वह', 'है', '?']] ['तुम', 'एक', 'एक', 'लिए', 'है', '।']
# [['<end>', '!', 'sireness', 'your', ',', 'him', 'is', 'that', '<start>']] [['सलजार', '!']] ['यह', ',', 'एक', 'एक', 'के', 'है', '।']
# [['<end>', '.', 'message', 'a', 'you', 'sent', 'he', '<start>']] [['उसने', 'एक', 'संदेश', 'भेजा', 'है', 'तुमारे', 'लीए', '।']] ['मैं', 'एक', 'एक', 'एक', 'है', '।']
# [['<end>', '.', 'fit', 'could', 'i', 'if', ',', 'no', '<start>']] [['नहीं', ',', 'मेरे', 'नाप', 'का।']] ['मैं', ',', 'मैं', 'एक', 'नहीं', 'है', '।']
# [['<end>', '.', 'route', 'evacuation', 'your', 'know', '<start>']] [['सुरक्षित', 'स्थल', 'के', 'रास्ते', 'को', 'जान', 'लें।']] ['मैं', 'एक', 'एक', 'के', 'है', '।']
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# [['<end>', '.', 'weakness', 'forgives', 'never', 'life', '<start>']] [['जीवन', 'कभी', 'कमजोरी', 'को', 'माफ', 'नहीं', 'करती', 'है', '।']] ['मैं', 'एक', 'एक', 'के', 'लिए', 'है', '।']
# [['<end>', '.', 'him', 'like', 'you', 'over', 'more', '<start>']] [['और', 'तो', 'और', 'तुम', 'उसे', 'चाहती', 'हो', '।']] ['आप', 'एक', 'एक', 'में', 'है', '।']
# [['<end>', '.', 'land', 'of', 'piece', '<start>']] [['यह', 'जमीन', 'पर', 'है', '!']] ['मैं', 'एक', 'लिए', 'है', '।']
# [['<end>', '!', 'void', 'the', 'into', 'gone', 'is', 'he', '<start>']] [['क्या', '?', 'वह', 'शून्य', 'में', 'चला', 'गया', 'है', '।']] ['वह', 'एक', 'एक', 'के', 'लिए', 'है', '।']
# [['<end>', '.', 'exist', 'even', 'not', 'does', 'it', '<start>']] [['मुझे', 'मानचित्र', 'दिखाएं।']] ['मैं', 'एक', 'एक', 'नहीं', 'है', '।']
# [['<end>', '.', 'worse', 'it', 'had', 'mann', '.', 'dr', '<start>']] [['dr', '।', 'mann', 'इससे', 'भी', 'ज्यादा', 'अकेले', 'होंगे', '।']] ['वह', ',', 'एक', 'एक', 'लिए', '।']
# [['<end>', '.', 'up', 'keep', 'to', 'try', '<start>']] [['ताल', 'से', 'ताल', 'मिलाओ।']] ['वह', ',', 'एक', 'के', '।']
# [['<end>', '.', 'be', 'to', 'need', 'not', 'do', 'you', '<start>']] [['आप', 'करने', 'की', 'आवश्यकता', 'नहीं', 'है', '।']] ['मैं', 'एक', 'एक', 'नहीं', 'है', '।']
# [['<end>', '?', 'them', 'to', 'spoken', 'you', '<start>']] [['वाकई', '?']] ['तुम', 'क्या', 'हो', '?']
# [['<end>', '!', 'stop', 'not', 'do', '.', 'stop', 'not', 'do', '<start>']] [['मैं', 'उसे', 'पा', 'ही', 'लूंगा', 'तुम', 'रुकना', 'मत', 'रुकना', 'मत', '!']] ['वह', ',', 'एक', 'एक', 'नहीं', 'है', '।']
# [['<end>', '.', 'second', 'a', 'on', 'hold', '<start>']] [['एकमिनटरुको', '।']] ['मैं', 'एक', 'एक', 'लिए', '।']
# [['<end>', '.', 'on', 'belt', 'your', 'put', '<start>']] [['अपनी', 'बेल्ट', 'पर', 'रखो', '।']] ['वह', 'एक', 'लिए', 'है', '।']
# [['<end>', '.', 'now', 'her', 'take', 'ill', '<start>']] [['मैं', 'उसे', 'यहाँ', 'से', 'ले', 'जाऊँगा', '।']] ['वह', ',', 'एक', 'के', 'लिए', '।']
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Streaming output truncated to the last 5000 lines.
# [['<end>', '.', 'horse', 'your', 'on', 'back', 'get', '<start>']] [['अपने', 'घोड़े', 'पर', 'वापस', 'जाओ।']] ['अपने', 'अपने', 'वापस', 'को', 'वापस', 'हो', '।']
# [['<end>', '.', 'alive', 'out', 'get', 'never', 'well', '<start>']] [['हम', 'कभी', 'जीवित', 'बाहर', 'नहीं', 'निकलेंगे', '।']] ['हम', 'उसे', 'मिल', 'जाएगा', '।']
# [['<end>', '?', 'delivery', 'a', 'schedule', 'you', '<start>']] [['आप', 'एक', 'प्रसव', 'अनुसूची', '?']] ['क्या', 'आप', 'एक', 'अन्य', 'रहे', 'हैं', '?']
# [['<end>', '.', 'me', 'from', 'away', 'stay', '<start>']] [['मुझसे', 'दूर', 'रहो', '।']] ['मुझसे', 'दूर', 'मुझे', 'तो', 'हैं', '।']
# [['<end>', '"', '.', 'david', 'burt', 'incredible', '"the', '<start>']] [['"', '।', 'इनक्रेडिबल', 'बर्ट', 'और', 'डेविड', '"']] ['"मेरा', '"', 'के', 'साथ', '"', 'से', '"', '"', '"']
# [['<end>', '.', 'cool', 'pretty', 'is', 'it', ',', 'yeah', '<start>']] [['हाँ', ',', 'बहुत', 'मस्त', 'है।']] ['हाँ', ',', 'यह', 'बहुत', 'अच्छा', 'है', '।']
# [['<end>', '?', 'pisser', 'a', 'that', 'not', 'ai', 'now', '<start>']] [['अब', 'जब', 'कि', 'एक', 'pisser', 'नहीं', 'है', '?']] ['क्या', 'कहा', 'कि', 'क्या', 'नहीं', '?']
# [['<end>', '?', 'night', 'of', 'time', 'this', 'at', '<start>']] [['इतनी', 'रात', 'को', '?']] ['यह', 'एक', 'कौन', 'पर', 'है', '?']
# [['<end>', '!', 'why', 'fucking', 'me', 'tell', '<start>']] [['मुझे', 'क्यों', 'कमबख्त', 'बताओ', '!']] ['मुझे', 'मुझे', 'सकते', 'हैं', '!']
# [['<end>', '.', 'to', 'have', 'not', 'did', 'i', '<start>']] [['मुझे', 'ज़रूरत', 'नहीं', 'पड़ी।']] ['मैं', 'समय', 'नहीं', 'करना', 'चाहिए', '।']
# [['<end>', '?', 'got', 'you', 'do', 'what', '<start>']] [['तुम्\u200dहें', 'क्\u200dया', 'मिला', '?']] ['क्या', 'मतलब', 'है', '?']
# [['<end>', '.', 'please', ',', 'word', 'a', ',', 'erik', '<start>']] [['एरिक', ',', 'एक', 'शब्द', 'है', 'कृपया', '।']] ['ठीक', 'है', ',', 'मेरे', 'रहे', 'हैं', '।', '।', '।']
# [['<end>', '.', 'duke', 'brother', ',', 'down', 'pinned', '<start>']] [['भाई', 'ड्यूक', ',', 'नीचे', 'टिकी', '।']] ['हर', 'सब', 'अच्छा', ',', 'हम', 'हैं', '।']
# [['<end>', '.', '.', '.', 'caused', 'has', 'gasoline', 'that', '<start>']] [['इस', 'पेट्रोल', 'के', 'कारण', '।', '।', '।']] ['आप', 'पर', 'कि', 'कि', '।', '।', '।']
# [['<end>', '.', 'sir', ',', 'alive', 'still', 'is', 'thing', 'that', '<start>']] [['यह', 'बात', 'अभी', 'भी', 'जिंदा', 'है', ',', 'सर', '।']] ['यही', ',', 'अब', 'पर', 'कुछ', 'कर', 'सकते', 'हैं।']
# [['<end>', '.', 'moment', 'beautiful', 'a', 'what', '<start>']] [['क्या', 'एक', 'सुंदर', 'पल।']] ['एक', 'एक', 'और', 'एक', 'मैं']
# [['<end>', '.', 'you', 'miss', 'gonna', 'im', ',', 'oh', '<start>']] [['ओह', ',', 'मैं', 'तुम्हें', 'याद', 'कर', 'रहा', 'हूँ', '।']] ['हाँ', ',', 'मैं', 'तुम्हें', 'अच्छा', 'हूँ', '।']
# [['<end>', '?', 'mean', 'you', 'do', 'what', '<start>']] [['तुम्हारा', 'मतलब', 'क्या', 'है', '?']] ['क्या', 'मतलब', 'है', '?']
# [['<end>', '!', 'tim', ',', 'up', 'hang', 'not', 'do', '<start>']] [['फ़ोन', 'मत', 'काटना', ',', 'टिम', '!']] ['मत', 'मत', ',', '!']
# [['<end>', '.', 'man', ',', 'beautiful', 'is', 'she', ',', 'yeah', '/', '<start>']] [['/', 'हाँ', ',', 'वह', 'है', ',', 'खूबसूरत', 'आदमी', '।']] ['हाँ', ',', 'वह', ',', 'हम', 'से', 'बाहर', 'हो', 'गया', '।']
# [['<end>', '?', 'train', 'a', 'seen', 'ever', '<start>']] [['कभी', 'ट्रेन', 'देखी', 'है', '?']] ['आप', 'अपनी', 'एक', 'हैं', '!']
# [['<end>', '?', 'bad', 'something', 'expected', '..you', '.', 'you', '<start>']] [['आप', 'को', 'कुछ', 'बुरे', 'का', 'अंदेशा', 'था', '?']] ['आप', 'सब', 'आप', 'की', 'तरह', '?']
# [['<end>', '.', 'touch', 'in', 'already', 'are', 'we', '<start>']] [['हम', 'पहले', 'से', 'ही', 'संपर्क', 'में', 'हैं', '।']] ['हम', 'आज', 'हैं', 'में', 'कर', 'रहे', 'हैं', '।']
# [['<end>', '?', 'there', 'doing', 'you', 'were', 'what', '<start>']] [['तुम', 'वहाँ', 'क्या', 'कर', 'रहे', 'थे', '?']] ['क्या', 'कहा', '?']
# [['<end>', '.', 'medication', 'your', 'changed', 'we', '<start>']] [['हमने', 'तुम्हारी', 'दवा', 'बदल', 'दी', 'है', '।']] ['हम', 'अपने', 'पिता', 'को', 'कर', 'सकते', 'हैं', '।']
# [['<end>', '.', 'bible', 'the', 'and', 'discipline', '<start>']] [['अनुशासन', 'और', 'बाइबल', '।']] ['और', 'वापस', 'हैं', '।']
# [['<end>', '.', 'funeral', 'the', 'miss', 'not', 'do', 'and', '<start>']] [['और', 'अंतिम', 'संस्कार', 'पर', 'ज़रूर', 'जाना।']] ['और', 'अपने', 'पिता', 'नहीं', 'कर', 'सकते', '।']
# [['<end>', '!', 'enemy', 'the', 'fights', 'he', '<start>']] [['वह', 'दुश्मन', 'से', 'लड़ता', 'है', '!']] ['वह', 'का', 'उपयोग', 'ले', '!']
# [['<end>', '.', 'ever', 'and', 'ever', 'and', 'forever', '<start>']] [['हमेशा', 'के', 'लिए', '।', '।', '।', 'और', 'हमेशा', '।', '।', '।', '।', '।', '।']] ['और', 'और', 'वापस', 'हैं', '।']
# [['<end>', '?', 'doing', 'you', 'are', 'what', '<start>']] [['तुम', 'ये', 'क्या', 'कर', 'रहे', 'हो', '?']] ['तुम', 'क्या', 'कर', 'रहे', 'हो', '?']
# [['<end>', '.', 'later', 'back', 'you', 'call', 'ill', '<start>']] [['मैं', 'तुम्हें', 'बाद', 'में', 'वापस', 'फोन', 'करूंगा', '।']] ['मैं', 'यहाँ', 'से', 'भी', 'आप', 'को', 'प्यार', 'हो', 'जाएगा', '।']
# [['<end>', '.', 'fittest', 'the', 'of', 'survival', '<start>']] [['योग्यतम', 'की', 'उत्तरजीविता।']] ['हमारे', 'पिता', 'से', 'चले', '।']
# [['<end>', '!', 'here', 'of', 'out', 'get', '<start>']] [['यहां', 'से', 'निकलो', '!']] ['यहाँ', 'से', 'बाहर', 'जाओ', '!']
# [['<end>', '.', 'by', 'drop', 'might', 'i', '<start>']] [['शायद', 'मैं', 'भी', 'चला', 'जाऊँ।']] ['मैं', 'कुछ', 'भी', 'सकते', 'हैं', '।']
# [['<end>', '?', 'change', 'little', 'a', 'got', '<start>']] [['थोड़ा', 'परिवर्तन', 'समझे', '?']] ['एक', 'अन्य', 'कौन', 'है', '?']
# [['<end>', '.', 'bastard', 'the', 'gets', 'that', 'anything', '<start>']] [['कमीने', 'कि', 'कुछ', 'भी', '।']] ['यह', 'बहुत', 'अच्छा', 'है', '।']
# [['<end>', '.', 'presentation', 'your', 'on', ',', 'no', '<start>']] [['नहीं', '!', 'मैं', 'अपनी', 'प्रस्तुति', 'पर', 'मतलब', 'है', '।']] ['नहीं', ',', 'मेरी', 'मिनट', '!']
# [['<end>', '?', 'amaneh', 'to', 'talk', 'i', 'can', '<start>']] [['क्या', 'मैं', 'आमने', 'से', 'बात', 'कर', 'सकता', 'हूँ', '?']] ['क्या', 'मैं', 'तुम्हारे', 'लिए', 'नहीं', 'हूँ', '?']
# [['<end>', '.', '.', '.', 'me', 'for', 'this', 'do', '<start>']] [['मेरे', 'लिए', 'यह', 'करना', '।', '।', '।']] ['यह', 'बात', 'करो', '।', '।', '।']
# [['<end>', '.', '.', '.', 'merna', 'merna', 'de', 'claire', 'papanera', '<start>']] [['मैं', 'papanera', 'क्लेयर', 'डे', 'merna', 'merna', '।', '।', '।']] ['अब', 'समय', 'है', '।', '।', '।']
# [['<end>', '.', 'there', 'be', 'not', 'wo', 'alexander', '<start>']] [['अलेक्जेंडर', 'नहीं', 'होगा', '।']] ['वह', 'उसे', 'नहीं', 'वहाँ', '।']
# [['<end>', '.', 'it', 'believe', 'not', 'do', 'i', '<start>']] [['मुझे', 'यक़ीन', 'नहीं', 'हो', 'रहा।']] ['मैं', 'यह', 'नहीं', 'करना', 'चाहिए', '।']
# [['<end>', '.', 'wild', 'going', 'are', 'people', '<start>']] [['लोग', 'पागल', 'हुए', 'जा', 'रहे', 'हैं।']] ['अब', 'जा', 'रहे', 'हैं', '!']
# [['<end>', '.', 'think', 'you', 'what', 'not', 'is', 'it', '<start>']] [['यह', 'आप', 'ऋण', 'का', 'एक', 'बहुत', 'कुछ', 'है', 'कि', 'लगता', 'है', '।', '।', '।', 'यह', 'आप', 'क्या', 'सोचते', 'नहीं', 'है', '।']] ['क्या', 'है', 'तुम', 'नहीं', 'है', 'तुम', '?']
# [['<end>', '.', 'her', 'get', 'gotta', 'i', '<start>']] [['मुझे', 'उसे', 'लाना', 'होगा।']] ['मैं', 'एक', 'वापस', 'दो', '।']
# [['<end>', '.', 'not', 'do', 'some', 'and', 'shine', 'some', '<start>']] [['कुछ', 'चमकते', 'हैं', '।', '।', '।', '।', '।', '।और', 'कुछ', 'नहीं', '।']] ['वह', 'वह', 'वह', 'नहीं', 'था', '।']
# [['<end>', '?', 'macedon', 'to', 'benefit', 'what', '<start>']] [['मेसेडोन', 'को', 'क्या', 'लाभ', 'होगा', '?']] ['क्या', 'करना', 'रहे', 'हैं', '?']
# [['<end>', '.', 'guys', 'good', 'the', 'are', 'we', ',', 'yeah', '<start>']] [['हाँ', ',', 'हम', 'अच्छे', 'लोग', 'कर', 'रहे', 'हैं।']] ['हाँ', ',', 'हम', 'सब', 'हैं', '।']
# [['<end>', '?', 'you', 'not', 'do', ',', 'that', 'remember', 'you', '<start>']] [['आप', 'आपको', 'लगता', 'है', 'कि', 'याद', 'है', ',', 'नहीं', 'है', '?']] ['आप', ',', 'आप', 'नहीं', 'हैं', '।']
# [['<end>', '.', 'him', 'buttering', 'am', 'i', 'so', '<start>']] [['तो', 'मैं', 'उसे', 'मक्खन', 'रहा', 'हूँ।']] ['मैं', 'यहाँ', 'से', 'भी', 'प्यार', 'हो', 'सकता', 'है', '।']
# [['<end>', '?', 'doing', 'you', 'are', 'what', '<start>']] [['क्या', 'कर', 'रहे', 'हो', '?']] ['तुम', 'क्या', 'कर', 'रहे', 'हो', '?']
# [['<end>', '.', 'out', 'get', 'gotta', 'we', '<start>']] [['हम', 'बाहर', 'जाना', 'होगा', '।']] ['हम', 'बाहर', 'मिल', 'गया', 'है', '।']
# [['<end>', '.', '.', '.', 'you', 'ask', 'gotta', 'i', ',', 'hey', '<start>']] [['अरे', ',', 'मैं', 'आप', 'से', 'पूछना', 'होगा', '।', '।', '।']] ['लेकिन', 'मैं', ',', 'तुम', 'पर', 'था।', '।', '।']
# [['<end>', '.', 'it', 'by', 'profit', 'hell', '<start>']] [['उसे', 'इसे', 'से', 'लाभ', 'होगा', '।']] ['अब', 'साथ', 'साथ', 'हो', '।']
# [['<end>', '.', 'not', 'why', 'see', 'not', 'do', 'i', '<start>']] [['हाँ', ',', 'बिलकुल।']] ['मैं', 'नहीं', 'कर', 'सकता', 'है', '।']
# [['<end>', '?', 'ok', ',', 'fast', 'run', '<start>']] [['जल्दी', 'भागना', ',', 'ठीक', 'है', '?']] ['कोई', 'हो', ',', 'क्या', '?']
# [['<end>', '.', '.', '.', 'edmunds', 'and', 'brand', '.', 'dr', '<start>']] [['dr', '।', 'brand', 'और', 'edmunds', '।', '।', '।']] ['हाँ', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।']
# [['<end>', '.', 'right', 'all', ',', 'me', 'called', 'dad', '<start>']] [['पिताजी', 'ने', 'मुझे', 'फोन', 'किया', ',', 'ठीक', 'है', '।']] ['हम', 'सब', 'और', 'बहुत', 'मेरी', 'है', ',', '।']
# [['<end>', '?', 'me', 'at', 'mad', 'you', 'are', '<start>']] [['तुम', 'मुझसे', 'नाराज़', 'हो', '?']] ['क्या', 'तुम', 'मुझे', 'जानते', 'हो', '?']
# [['<end>', '?', 'doing', 'you', 'are', 'what', '<start>']] [['तुम', 'क्या', 'कर', 'रहे', 'हो', '?']] ['तुम', 'क्या', 'कर', 'रहे', 'हो', '?']
# [['<end>', '?', 'jim', 'is', 'how', ',', 'work', 'of', 'speaking', '<start>']] [['काम', 'के', 'बोलते', ',', 'कैसे', 'जिम', 'है', '?']] ['हम', 'हमारे', 'साथ', 'हैं', ',', 'ना', '?']
# [['<end>', '!', 'phones', 'fucking', 'useless', '<start>']] [['ये', 'सारे', 'फ़ोन', 'बेकार', 'हैं।']] ['सब', 'सब', 'की', '!']
# [['<end>', '.', 'all', 'us', 'bless', 'god', '<start>']] [['ईश्वर', 'हम', 'सबपे', 'कृपा', 'करे।']] ['हमारे', 'और', 'हमारे', 'और', 'हैं', '।']
# [['<end>', '.', 'overhear', 'will', 'father', 'your', '<start>']] [['अपने', 'पिता', 'सुन', 'पाना', 'होगा।']] ['तुम्हारे', 'पिता', 'कभी', 'नहीं', 'है।']
# [['<end>', '.', 'agree', 'not', 'did', 'she', 'but', '<start>']] [['लेकिन', 'वह', 'इस', 'बात', 'से', 'सहमत', 'नहीं', 'था।']] ['लेकिन', 'वह', 'उसे', 'नहीं', 'था', '।']
# [['<end>', '.', 'theory', 'the', 'knew', 'i', '<start>']] [['मुझे', 'थ्योरी', 'पता', 'थी', '।']] ['मैं', 'उसके', 'बारे', 'में', 'सकता', 'है।']
# [['<end>', '.', 'you', 'to', 'belongs', 'it', '<start>']] [['यह', 'आप', 'के', 'अंतर्गत', 'आता', 'है', '।']] ['आप', 'यह', 'मदद', 'के', 'लिए', 'है', '।']
# [['<end>', 'news', 'good', 'of', 'piece', 'nd', '<start>']] [['अच्छी', 'खबर', 'के', 'टुकड़े']] ['तुम्हारे', 'साथ', 'का', 'साथ', 'कर', 'रही', 'है']
# [['<end>', '.', 'up', 'it', 'switch', 'is', 'let', '<start>']] [['चलो', 'इसे', 'बदलते', 'हैं।']] ['चलो', 'यह', 'वापस', 'नीचे', 'है', '।']
# [['<end>', '.', 'meant', 'i', 'what', 'not', 'is', 'that', '<start>']] [['यही', 'कारण', 'है', 'कि', 'मैं', 'क्या', 'मतलब', 'नहीं', 'है', '।']] ['मैं', 'नहीं', ',', 'क्या', 'कहा', '।']
# [['<end>', '.', 'garage', 'the', 'to', 'going', 'were', '<start>']] [['हम', 'गेराज', 'के', 'लिए', 'जा', 'रहे', 'हैं', '।']] ['वहाँ', 'तुम', 'में', 'ले', '!']
# [['<end>', '!', 'up', 'stand', 'please', '!', 'up', 'get', '<start>']] [['खडा', 'हो', '!']] ['दूर', 'का', 'जाओ', '!']
# [['<end>', '.', 'back', 'your', 'got', 'i', '<start>']] [['मैं', 'तुम्हारे', 'साथ', 'हूं।']] ['मैं', 'एक', 'वापस', 'हो', 'जाएगा', '।']
# [['<end>', '.', 'me', 'stops', 'thing', 'one', 'only', '<start>']] [['केवल', 'एक', 'दिक्कत', 'थी', '।']] ['मुझे', 'भी', 'कुछ', 'भी', 'प्यार', '।']
# [['<end>', '.', 'thrilled', 'be', 'must', 'lucy', '<start>']] [['लूसी', 'बहुत', 'खुश', 'होगी।']] ['कुछ', 'पर', 'दूर', 'हो', 'गया']
# [['<end>', '.', 'jones', 'waylon', 'is', 'name', 'his', '<start>']] [['उसका', 'नाम', 'waylon', 'जोन्स', 'है।']] ['मेरा', 'नाम', 'नाम', 'है।']
# [['<end>', '?', 'right', 'all', ',', 'know', 'i', '<start>']] [['मुझे', 'पता', 'है', ',', 'सब', 'ठीक', 'है', '?']] ['मैं', 'ठीक', 'है', ',', 'सब', 'क्या', '?']
# [['<end>', '.', 'store', 'is', 'dad', 'and', 'mom', 'is', 'that', '<start>']] [['कि', 'माँ', 'और', 'पिताजी', 'की', 'दुकान', 'है', '।']] ['यही', 'यही', 'है', 'कि', 'मेरे', 'पास', 'कहा', 'है।']
# [['<end>', '?', 'friend', 'new', 'your', 'is', 'who', '<start>']] [['अपने', 'नए', 'दोस्त', 'कौन', 'है', '?']] ['कौन', 'अपने', 'कौन', 'है', '?']
# [['<end>', '.', 'start', 'not', 'wo', 'car', 'my', '<start>']] [['।', '?', '।', 'मेरी', 'कार', 'शुरू', 'नहीं', 'होगा']] ['तो', 'और', 'इस', 'को', 'नहीं', 'करता', '।']
# [['<end>', '.', 'physicist', 'old', 'an', 'im', '<start>']] [['मैं', 'एक', 'बूढ़ा', 'भौतिक', 'विज्ञानी', 'हूँ', '।']] ['मैं', 'एक', 'रास्ते', 'पर', 'हूँ', '।']
# [['<end>', '?', 'poltergeist', 'showroom', 'the', 'is', 'it', 'maybe', '<start>']] [['शायद', 'यह', 'शोरूम', 'का', 'भूत', 'हो', '?']] ['यह', 'क्या', 'कहा', '?']
# [['<end>', '.', 'belt', 'seat', 'your', 'fasten', '<start>']] [['अपनी', 'सीट', 'बेल्ट', 'बाँधो।']] ['हमारे', 'पिता', 'अपने', 'वापस', 'हैं', '।']
# [['<end>', '!', 'operations', 'docking', 'transporter', 'for', 'prepare', '<start>']] [['ट्रांसपोर्टर', 'डॉकिंग', 'के', 'संचालन', 'के', 'िलए', 'तैयार', '!']] ['उन्होंने', 'ने', 'ने', 'के', 'बारे', 'में', 'बात', 'कर', 'रहा', 'हूँ', '!']
# [['<end>', '.', 'conspiracy', 'a', 'is', 'this', '<start>']] [['यह', 'एक', 'षड्यंत्र', 'है', '।']] ['यह', 'एक', 'दाँत', 'है', '।']
# [['<end>', '.', 'mithravinda', 'princess', 'then', 'of', 'portrait', '<start>']] [['ये', 'तस्वीर', 'उस', 'समय', 'की', 'राजकुमारी', 'मित्राविन्दा', 'की', 'है', '।']] ['उसे', 'अभी', 'को', 'नहीं', 'कर', 'सकते', '।']
# [['<end>', '.', 'man', ',', 'down', 'going', 'is', 'shit', 'some', '<start>']] [['कुछ', 'गंदगी', 'के', 'नीचे', 'जा', 'रहा', 'है', ',', 'आदमी']] ['हमारे', 'पास', 'कोई', 'कोई', 'पर', 'आ', 'रहा', 'हूँ', '।']
# [['<end>', '.', 'found', 'i', 'who', 'look', '!', 'hey', '<start>']] [['ऐ', '!']] ['अरे', '।']
# [['<end>', '!', '.', 'man', ',', 'nailed', 'got', 'wejust', '<start>']] [['हम', 'फंस', 'गये', ',', 'यार', '।']] ['अरे', ',', 'मुझे', 'कुछ', 'भी', 'दो', '।', '।', '।']
# [['<end>', '.', 'it', 'control', 'me', 'let', 'just', '<start>']] [['बस', 'मुझे', 'इसे', 'नियंत्रित', 'करते', 'हैं', '।']] ['बस', 'मुझे', 'बस', 'बस', 'बस', '।']
# [['<end>', '.', 'does', 'it', ',', 'sir', ',', 'yes', '<start>']] [['हाँ', ',', 'सर', ',', 'यह', 'करता', 'है', '।']] ['हाँ', ',', 'हाँ', ',', 'यह', 'है', '।']
# [['<end>', '.', 'earlier', 'died', 'father', 'is', 'oei', '<start>']] [['पहले', 'पिता', 'ओएइ', 'की', 'मृत्यु', 'हो', 'गई', '।']] ['वह', 'उसके', 'साथ', 'ही', 'है', '।']
# [['<end>', '?', 'you', 'treating', 'wife', 'the', 'is', 'how', '<start>']] [['पत्नी', 'तुम्हारा', 'इलाज', 'कैसा', 'कर', 'रही', 'है', '?']] ['क्या', 'क्या', 'हुआ', 'है', '?']
# [['<end>', '.', 'do', 'i', ',', 'yes', '<start>']] [['हाँ', ',', 'मैं', 'करता', 'हूँ', '।']] ['हाँ', ',', 'मैं', 'हैं', '।']
# [['<end>', '.', 'work', 'at', 'physics', 'is', 'this', '<start>']] [['?']] ['यह', 'एक', 'आपकी', 'कौन', 'है', '।']
# [['<end>', '.', 'me', 'of', 'off', 'get', '<start>']] [['मुझसे', 'दूर', 'हो', 'जाओ', '।']] ['मुझे', 'मुझे', 'दो', 'से', '!']
# [['<end>', '.', 'tricks', 'some', 'do', 'is', 'let', ',', 'rance', '<start>']] [['rance', ',', 'चलो', 'कुछ', 'चाल', 'है', '।']] ['चलो', ',', 'वह', 'कोई', 'भी', 'नहीं', 'है', '।']
# [['<end>', '.', 'here', 'of', 'out', 'get', '<start>']] [['यहाँ', 'से', 'चले', 'जाओ', '।']] ['यहाँ', 'से', 'बाहर', 'जाओ', '।']
# [['<end>', '!', 'rules', 'the', 'changing', 'is', 'colonel', 'the', '<start>']] [['कर्नल', 'के', 'नियम', 'बदल', '!']] ['यही', 'में', 'है', '!']
# [['<end>', '?', 'cloning', 'through', 'not', 'why', '<start>']] [['क्यों', 'नहीं', 'क्लोनिंग', 'के', 'माध्यम', 'से', '?']] ['कुछ', 'भी', 'नहीं', 'आ', 'सकता', 'है', '?']
# [['<end>', '.', 'time', 'any', 'again', 'me', 'ask', '<start>']] [['बढीया', 'है।']] ['मुझे', 'मुझे', 'समय', 'की', 'तरह', '।']
# [['<end>', '.', 'her', 'do', 'can', 'we', ',', 'well', '<start>']] [['ठीक', 'है', ',', 'हम', 'उसे', 'कर', 'सकते', 'हैं', '।']] ['हम', 'है', 'हम', 'हैं', 'हम', 'हैं', '।']
# [['<end>', '.', 'me', 'betrayed', 'father', 'her', '<start>']] [['उसके', 'पिता', 'ने', 'मुझे', 'धोखा', 'दिया।']] ['मेरे', 'अपने', 'पिता', 'मुझे', 'मार', 'गया', '।']
# [['<end>', '.', 'there', 'in', 'get', 'gotta', 'weve', '<start>']] [['अंदर', 'जाना', 'होगा।']] ['हम', 'वहाँ', 'के', 'लिए', 'धन्यवाद']
# [['<end>', '!', 'justice', 'of', 'brand', 'bat', '<start>']] [['न्याय', 'के', 'बैट', 'ब्रांड', '!']] ['वहाँ', 'से', 'बाहर', '!']
# [['<end>', '!', 'mouth', 'fucking', 'your', 'watch', '<start>']] [['ज़बान', 'को', 'लगाम', 'दो।']] ['आपकी', 'का', 'साथ', 'का', '!']
# [['<end>', '.', 'side', 'the', 'at', 'look', '<start>']] [['बाजू', 'में', 'देखो', '।']] ['वहाँ', 'पर', 'था', '।']
# [['<end>', '?', 'do', 'i', 'do', 'what', '<start>']] [['मुझे', 'क्या', 'करना', 'चाहिए', '?']] ['मैं', 'क्या', 'कह', 'रहा', '?']
# [['<end>', '.', 'that', 'with', 'work', 'just', 'is', 'let', '<start>']] [['चलो', 'बस', 'उस', 'के', 'साथ', 'काम', 'करते', 'हैं।']] ['वह', 'सिर्फ', 'बस', 'तरह', '।']
# [['<end>', '!', 'hall', 'the', 'down', 'are', 'they', '<start>']] [['वे', 'नीचे', 'हॉल', 'में', 'हैं', '!']] ['वे', 'उन्हें', 'कर', 'रहे', 'हैं', '!']
# [['<end>', '.', 'convertible', 'not', 'is', 'bmw', 'your', 'and', '<start>']] [['तुम्हारी', 'बीएमडब्ल्यू', 'परिवर्तनीय', 'नहीं', 'है।']] ['और', 'इस', 'तुम्हारे', 'साथ', 'है', ',', 'नहीं', '।']
# [['<end>', '.', 'comfortable', 'yourself', 'make', 'just', '<start>']] [['बस', 'आराम', 'से', 'बैठो', '।']] ['बस', 'बस', 'तुम', 'हो', 'गया', '।']
# [['<end>', '.', 'boyfriend', 'a', 'have', 'not', 'does', 'amélie', '<start>']] [['amélie', 'का', 'boyfriend', 'नहीं', 'है', '।']] ['हमारे', 'समय', 'नहीं', 'है।']
# [['<end>', '.', 'drop', 'to', 'ready', 'gettin', '<start>']] [['ड्रॉप', 'करने', 'के', 'लिए', 'मिल', 'रही', 'तैयार', '।']] ['तुम', 'जाने', 'के', 'लिए', 'ले', '।', '।', '।']
# [['<end>', '.', 'cool', 'is', 'it', ',', 'no', ',', 'no', '<start>']] [['नहीं', ',', 'नहीं', ',', 'यह', 'अच्छा', 'है', '।']] ['नहीं', ',', 'नहीं', ',', 'यह', 'पता', 'है', '।']
# [['<end>', '?', 'that', 'done', 'you', 'have', 'why', '<start>']] [['ऐसा', 'क्यों', 'किया', '?']] ['आप', 'कुछ', 'भी', 'क्यों', 'हैं', '?']
# [['<end>', '?', 'name', 'your', 'is', 'what', '<start>']] [['तुमहरा', 'नाम', 'क्या', 'है', '?']] ['अपने', 'क्या', 'का', 'क्या', 'है', '?']
# [['<end>', '.', 'hummingbird', 'is', 'this', ',', 'castle', '<start>']] [['हम', 'हमिंगबर्ड', 'हैं।']] ['खैर', ',', 'यह', 'एक', 'तरह', '।']
# [['<end>', '.', 'rise', 'the', 'on', 'is', 'that', '<start>']] [['कि', 'बढ़', 'रही', 'है', '।']] ['कि', 'वाला', 'वाला', 'है', '।']
# [['<end>', '.', 'now', 'on', 'come', 'oh', '<start>']] [['समझा', '।']] ['अब', 'यह', 'पर', 'आ', 'रहा', 'है', '।']
# [['<end>', '.', 'right', 'the', 'on', 'is', 'room', 'your', '<start>']] [['तुम्हारे', 'कमरे', 'दाईं', 'तरफ', 'हैं', '।']] ['अपने', 'पिता', 'पर', 'है', '।']
# [['<end>', '.', 'brave', 'truly', 'are', 'you', '<start>']] [['तुम', 'सच', 'में', 'बहादुर', 'हैं', '।']] ['आप', 'भी', 'मजाक', 'कर', 'रहे', 'हैं', '।']
# [['<end>', '!', 'witnesses', 'for', 'need', 'no', 'is', 'there', '<start>']] [['गवाहों', 'की', 'कोई', 'ज़रूरत', 'नहीं', 'है', '!']] ['वहाँ', 'वहाँ', 'नहीं', 'है', '!']
# [['<end>', '.', 'note', 'rupee', 'a', '<start>']] [['रुपए', 'का', 'नोट', '।']] ['एक', 'अन्य', 'मिला', '।']
# [['<end>', '.', 'mutt', 'little', 'you', ',', 'comfortable', 'get', '<start>']] [['नन्ही', 'पिल्ली।']] ['तुम', 'में', ',', 'तुम', '।', '।', '।']
# [['<end>', '.', 'me', 'for', 'enough', 'good', 'is', 'that', '<start>']] [['यह', 'मेरे', 'लिए', 'काफी', 'अच्छा', 'है', '।']] ['कि', 'मेरे', 'मेरे', 'लिए', 'है', '।']
# [['<end>', '.', 'me', 'at', 'look', ',', 'carl', '<start>']] [['कार्ल', ',', 'मुझे', 'देखो', '।']] ['ठीक', 'है', ',', 'मेरे', 'लिए', '।']
# [['<end>', '.', 'answer', 'the', 'is', 'grand', '<start>']] [['जवाब', 'है', 'दो', 'सौ', 'चौरासी', 'हज़ार।']] ['यह', 'एक', 'काम', 'है', '।']
# [['<end>', '.', 'frankly', 'speak', 'is', 'let', ',', 'addison', '.', 'mr', '<start>']] [['श्री', 'एडिसन', ',', 'के', 'स्पष्ट', 'रूप', 'से', 'बोलने', 'करते', 'हैं।']] ['हाँ', ',', 'कृपया', '।', '।', '।', '!']
# [['<end>', '.', '.', '.', 'uh', ',', 'that', 'says', 'lois', '<start>']] [['lois', 'ने', 'कहा', ',', 'uh', '।', '।', '।']] ['ठीक', 'है', ',', 'श्री', 'कि', '।', '।', '।']
# [['<end>', '?', 'now', 'this', 'is', 'who', '<start>']] [['अब', 'यह', 'कौन', 'है', '?']] ['कौन', 'कौन', 'है', '?']
# [['<end>', '.', 'iodine', 'some', 'need', 'we', '<start>']] [['हमें', 'आयोडीन', 'चाहिए', '।']] ['हम', 'कुछ', 'कभी', 'नहीं', 'चाहिए', '।']
# [['<end>', '.', 'right', 'it', 'make', 'me', 'let', '<start>']] [['मुझे', 'यह', 'सही', 'कर', 'दूं', '।']] ['मुझे', 'यह', 'मुझे', 'नहीं', 'चाहिए', '।']
# [['<end>', '!', 'boy', 'my', ',', 'come', 'ive', '<start>']] [['मै', 'आ', 'गया', ',', 'मेरे', 'बेटे', '!']] ['मुझे', 'आओ', ',', 'मेरी', '!']
# [['<end>', '?', 'happening', 'is', 'hell', 'the', 'what', '<start>']] [['ये', 'साला', 'हो', 'क्या', 'रहा', 'है', '?']] ['ये', 'क्या', 'है', '?']
# [['<end>', '?', 'have', 'you', 'do', 'what', '.', 'yeah', '<start>']] [['हाँ', ',', 'क्या', 'है', '।']] ['हाँ', ',', 'तुम', 'क्या', 'चाहते', 'हो', '?']
# [['<end>', '.', 'know', 'even', 'not', 'do', 'i', '<start>']] [['मैं', 'भी', 'नहीं', 'जानती', '।']] ['मुझे', 'पता', 'है', 'कि', 'नहीं', ',', 'मैं', 'नहीं', 'हूँ', '।']
# [['<end>', '?', 'you', 'not', 'are', ',', 'bhairava', 'are', 'you', '<start>']] [['तुम', 'भैरवा', 'हो', ',', 'है', 'ना', '?']] ['तुम', 'पता', 'है', ',', 'नहीं', ',', 'तुम', 'नहीं', 'कर', 'रहे', 'हैं', '?']
# [['<end>', '.', 'favorite', 'your', ',', 'chocolate', 'is', 'it', '<start>']] [['यह', 'अपने', 'पसंदीदा', ',', 'चॉकलेट', 'है', '।']] ['यह', 'सब', 'अच्छा', 'है', ',', 'मेरी', 'है', '।']
# [['<end>', '?', 'that', 'know', 'you', 'howd', '<start>']] [['तुमने', 'कैसे', 'जाना', '?']] ['आप', 'कैसे', 'जानते', 'हैं', '?']
# [['<end>', '.', 'connect', 'not', 'wo', 'it', '<start>']] [['फ़ोन', 'नहीं', 'लग', 'रहा।']] ['यह', 'नहीं', 'है', '।']
# [['<end>', '.', 'it', 'afford', 'can', 'one', 'no', '<start>']] [['कोई', 'इसे', 'खरीदने', 'में', 'समर्थ', 'नहीं', 'है।']] ['नहीं', ',', 'हम', 'एक', 'वापस', 'हो', 'जाएगा', '।']
# [['<end>', '.', 'there', 'worked', 'both', 'we', '<start>']] [['हम', 'दोनों', 'वहाँ', 'काम', 'किया', '।']] ['हम', 'किसी', 'को', 'को', 'मार', 'चाहिए']
# [['<end>', '.', 'itself', 'life', 'is', 'he', '<start>']] [['वह', 'ही', 'जीवन', 'है', '।']] ['वह', 'अपने', 'रास्ते', 'पर', 'है', '।']
# [['<end>', '.', 'you', 'with', 'wrong', 'something', 'is', 'there', '<start>']] [['तुम्हारे', 'साथ', 'कुछ', 'तो', 'गड़बड़', 'है।']] ['तुम्हारे', 'साथ', 'कुछ', 'भी', 'है', '।']
# [['<end>', '.', 'beyond', 'count', 'not', 'did', 'you', '<start>']] [['आप', 'से', 'जादा', 'गिन', 'नहीं', 'पाती', '।']] ['आप', 'को', 'किसी', 'को', 'नहीं', 'होगा', '।']
# [['<end>', '.', 'now', 'kookaburras', 'the', 'hear', 'can', '<start>']] [['अब', 'कूकाबरा', 'की', 'आवाज़', 'सुनी', 'जा', 'सकती', 'है', '।']] ['अब', 'इस', 'साथ', 'कर', 'सकता', 'कर', 'रहा', 'है', '।']
# [['<end>', '.', 'realize', 'will', 'he', 'now', '<start>']] [['अब', 'वह', 'एहसास', 'होगा।']] ['वह', 'अब', 'वापस', 'आ', 'सकता', 'है', '।']
# [['<end>', ')', 'ringing', 'phone', '(mobile', '<start>']] [['(मोबाइल', 'फोन', 'बज', ')']] [')']
# [['<end>', '.', 'okay', 'is', 'it', ',', 'look', '<start>']] [[]] ['यह', 'सब', 'ठीक', 'है', '।']
# [['<end>', '?', 'long', 'so', 'you', 'took', 'what', '<start>']] [['क्या', 'आप', 'इतनी', 'देर', 'क्यों', 'लगी', '?']] ['तुम्हें', 'पता', 'है', 'कि', 'क्या', 'मतलब', 'है', '?']
# [['<end>', 'now', 'you', 'arrest', 'will', 'i', '<start>']] [['मैं', 'तुम्हें', 'अब', 'गिरफ्तार', 'करेगी']] ['मैं', 'तुम्हें', 'कुछ', 'पसंद', 'था', '।']
# [['<end>', '!', 'kongstrup', ',', 'bottle', 'that', 'me', 'give', '<start>']] [['वह', 'बोतल', 'मुझे', 'दे', 'दो', ',', 'काँगस्ट्रप', '!']] ['मुझे', 'लगता', 'है', ',', 'मुझे', 'दो', 'और', '!']
# [['<end>', '?', 'huh', ',', 'politician', 'the', 'quite', '<start>']] [['क्या', 'राजनीतिज्ञ', 'हो', '!']] ['क्या', 'कर', 'रहा', 'है', ',', 'लेकिन', '?']
# [['<end>', '.', 'child', 'only', 'the', 'are', 'you', '<start>']] [['आप', 'ही', 'बच्चा', 'हो।']] ['आप', 'हैं।']
# [['<end>', '.', 'earth', 'and', 'heaven', 'of', 'joy', '<start>']] [['स्वर्ग', 'और', 'पृथ्वी', 'के', 'जोय', '।']] ['और', 'हमारे', 'और', 'हैं', '।']
# [['<end>', '.', 'mind', 'your', 'calm', ',', 'erik', ',', 'please', '<start>']] [['कृपया,एरिक', '!', 'अपने', 'मन', 'को', 'शांत', '।']] ['ओह', ',', 'मेरे', 'अपनी', ',', 'मुझे', 'दो', '।']
# [['<end>', '.', 'healing', 'of', 'place', 'ancient', 'an', '<start>']] [['चिकित्सा', 'की', 'एक', 'प्राचीन', 'जगह।']] ['एक', 'अच्छा', 'की', ',', 'तरह', '।']
# [['<end>', '!', 'parents', 'my', 'got', 'is', 'he', '<start>']] [['मम्मीपापा', 'को', 'कैद', 'कर', 'दिया', '!']] ['वह', 'अपने', 'मेरा', 'हैं', '!']
# [['<end>', '.', 'here', 'down', 'belong', 'not', 'do', 'they', '<start>']] [['वे', 'यहाँ', 'नीचे', 'ताल्लुक', 'नहीं', 'रखता।']] ['वे', 'नहीं', 'होना', 'चाहिए', '।']
# [['<end>', '.', 'maxwell', 'david', 'is', 'name', 'my', '<start>']] [['मेरा', 'नाम', 'दाऊद', 'मैक्सवेल', 'है', '।']] ['मेरा', 'नाम', 'पर', 'नाम', 'है', '।']
# [['<end>', '?', 'hat', 'foil', 'tin', 'a', '<start>']] [['एक', 'टिन', 'पत्र', 'टोपी', '?']] ['एक', 'कौन', '?']
# [['<end>', '.', 'thought', 'i', 'what', 'is', 'that', '<start>']] [['कि', 'मैं', 'क्या', 'सोचा', 'है', '।']] ['मुझे', 'है', 'कि', 'मैं', 'क्या', 'कर', 'रहा', 'हूँ', '।']
# [['<end>', ')', 'noises', 'chittering', '(', '<start>']] [['(chittering', 'शोर', ')']] [')']
# [['<end>', '?', 'here', 'on', 'going', 'is', 'what', ',', 'so', '<start>']] [['तो', ',', 'क्या', 'हो', 'रहा', 'है', 'यहाँ', '?']] ['नहीं', ',', 'क्या', 'है', '?']
# [['<end>', '.', 'here', 'welcome', 'not', 'are', 'you', '<start>']] [['आप', 'यहाँ', 'स्वागत', 'नहीं', 'कर', 'रहे', 'हैं', '।']] ['तुम', 'हमारे', 'हमारे', 'नहीं', 'कर', 'रहे', 'हैं', '।']
# [['<end>', '?', 'that', 'understand', 'you', 'do', '<start>']] [['आप', 'समझते', 'हैं', 'कि', 'क्या', 'है', '?']] ['आप', 'एक', 'पसंद', 'है', '?']
# [['<end>', '.', 'curious', 'just', 'was', 'i', 'umm', '<start>']] [['मैं', 'बस', 'थोड़ा', 'व्याकुल', 'हूँ', '।']] ['मैंने', 'बस', 'कहा', 'कि', 'मैं', 'तुम्हें', 'मार', '।']
# [['<end>', '.', 'slippage', 'time', 'the', 'of', 'because', '<start>']] [['समय', 'अंतराल', 'के', 'कारण', '।']] ['समय', 'में', 'समय', '।']
# [['<end>', '!', 'di', 'lady', ',', 'di', 'lady', '<start>']] [['lady', 'diana', ',', 'lady', 'diana', '!']] ['एक', 'और', 'दाँत', ',', 'बदल', 'रहे', 'हैं', '!']
# [['<end>', '.', 'reasonable', 'be', 'is', 'let', '<start>']] [['हमें', 'थोड़ा', 'तर्कसंगत', 'होना', 'होगा', '।']] ['चलो', 'चलो', 'चलो', '।']
# [['<end>', '!', 'bitch', 'a', 'of', 'son', '<start>']] [['एक', 'कुतिया', 'की', 'बेटा', '!']] ['एक', 'बेटा', '!']
# [['<end>', '!', 'goa', 'entire', 'you', 'show', 'ill', '<start>']] [['मैं', 'तुम्हें', 'पूरा', 'गोवा', 'दिखाऊँगी', '।']] ['मैं', 'तुम्हें', 'कुछ', 'भी', 'करेंगे', '!']
# [['<end>', '.', 'hear', 'to', 'good', 'very', 'is', 'that', '<start>']] [['यही', 'कारण', 'है', 'कि', 'बहुत', 'सुनने', 'के', 'लिए', 'अच्छा', 'है।']] ['यह', 'बहुत', 'अच्छा', 'है']
# [['<end>', '.', 'here', 'in', 'smoky', 'so', 'is', 'it', '<start>']] [['यहाँ', 'बड़ा', 'धुआँ', 'है।']] ['यहाँ', 'यहाँ', 'से', 'बहुत', 'है', '।']
# [['<end>', '.', 'spaces', 'the', 'counted', 'i', '<start>']] [['मैं', 'गिनती', 'कर', 'रही', 'हूँ', 'बीच', 'की', 'खाली', 'जगहों', 'की', '।']] ['मैं', 'हूँ', 'से', 'शादी', '।']
# [['<end>', ')', 'urdu', 'in', 'shouting', '(men', '<start>']] [['(मर्दोंउर्दूमेंचिल्ला', ')']] ['क्या', 'में', ')']
# [['<end>', '?', 'it', 'steal', 'they', 'did', 'where', '<start>']] [['कहाँ', 'से', 'चुराया', '?']] ['वे', 'कहाँ', 'कर', 'रहे', 'हैं', '?']
# [['<end>', '.', 'fulfilled', 'now', 'is', 'life', 'your', '<start>']] [['अपने', 'जीवन', 'अब', 'पूरी', 'हो', 'जाती', 'है।']] ['अब', 'बहुत', 'बहुत', 'है', ',', 'हम', 'है', '।']
# [['<end>', '?', 'correct', ',', 'employer', 'current', 'your', 'is', 'that', '<start>']] [['तुम', 'उन्हीं', 'के', 'लिए', 'काम', 'करते', 'हो', 'न', '?']] ['क्या', 'यह', 'बहुत', 'चाहिए', ',', 'है', 'ना', '।']
# [['<end>', '.', 'bark', 'some', 'you', 'got', 'i', '<start>']] [['मैं', 'तुम्हें', 'कुछ', 'छाल', 'मिला', '।']] ['मैं', 'तुम्हें', 'कुछ', 'ही', 'आप', 'की', 'जरूरत', 'है', '।']
# [['<end>', '.', 'you', 'with', 'nothing', 'take', '<start>']] [['तुम्हारे', 'साथ', 'कुछ', 'भी', 'नहीं', 'ले', 'लो', '।']] ['कोई', 'के', 'साथ', 'कुछ', 'भी', 'नहीं', 'था।']
# [['<end>', '.', 'go', 'him', 'let', ',', 'wait', '<start>']] [['रुको', ',', 'उसे', 'जाने', 'दिया', 'जाए', '।']] ['उसे', 'उसे', 'जाओ', '।']
# [['<end>', '.', 'hot', 'is', 'key', '<start>']] [['कुंजी', 'गर्म', 'है।']] ['खैर', '।', '।', '।']
# [['<end>', '.', 'minutes', 'three', 'got', 'ive', '<start>']] [['मैं', 'तीन', 'मिनट', 'मिल', 'गया', 'है', '।']] ['मैं', 'एक', 'मिनट', 'से', 'शादी', 'है', '।']
# [['<end>', '?', 'work', 'it', 'does', 'how', '<start>']] [['इसे', 'कैसे', 'इस्तेमाल', 'करें', '?']] ['ये', 'यह', 'क्या', 'है', '?']
# [['<end>', '.', 'jack', ',', 'one', 'be', 'there', 'but', '<start>']] [['लेकिन', 'एक', 'नाव', ',', 'जैक', 'है', '।', '।', '।']] ['लेकिन', 'सिर्फ', 'एक', 'समय', ',', 'कोई', 'भी', 'है', '।']
# [['<end>', '.', 'while', 'a', 'been', 'is', 'it', '<start>']] [['यह', 'एक', 'समय', 'हो', 'गया', 'है', '।']] ['यह', 'एक', 'बहुत', 'है', '।']
# [['<end>', '.', 'this', 'me', 'gave', 'you', '<start>']] [['तुम', 'मुझे', 'इस', 'दे', 'दी', 'है।']] ['तुम', 'मुझे', 'यह', 'कर', 'दिया', 'चाहिए', '।']
# [['<end>', '.', 'it', 'handled', 'i', 'and', '<start>']] [['और', 'मैं', 'इसे', 'संभाला', '।']] ['और', 'मैं', 'इसे', 'जानते', 'हैं', '।']
# [['<end>', '.', 'there', 'us', 'take', ',', 'solomon', 'hey', '<start>']] [['ए', 'सालमन', ',', 'हमे', 'वहाँ', 'ले', 'चलो', '।']] ['अरे', ',', 'तुम', 'और', 'देखो', '।']
# [['<end>', '.', 'you', 'for', 'one', 'plain', 'and', '<start>']] [['आप', 'के', 'लिए', 'और', 'सादे', 'एक।']] ['और', 'एक', 'और', 'आप', 'से', 'एक', '।']
# [['<end>', '?', 'ender', ',', 'doing', 'you', 'are', 'what', '<start>']] [['आप', ',', 'एंडर', 'क्या', 'कर', 'रहे', 'हो', '?']] ['क्या', 'कर', 'रहे', 'हो', ',', 'तुम', '?']
# [['<end>', '?', 'please', ',', 'available', 'hanson', 'andrew', 'is', '<start>']] [['क्या', 'एंड्रयू', 'hanson', ',', 'उपलब्ध', 'है', 'कृपया', '?']] ['क्या', 'के', 'साथ', ',', 'क्या', '?']
# [['<end>', '.', 'all', 'them', 'got', 'maria', '<start>']] [['मारिया', 'उन्हें', 'वह', 'सब', 'मिला', '।']] ['हमारे', 'साथ', 'हमारे', 'सकते', 'हैं', '।']
# [['<end>', '?', 'going', 'you', 'are', 'where', ',', 'malcolm', '<start>']] [['तुम', 'कहाँ', 'जा', 'रहे', 'हो', '?']] ['अरे', ',', 'तुम', 'कहाँ', 'हो', '?']
# [['<end>', '.', 'saraswati', 'is', 'name', 'her', '<start>']] [['उसका', 'नाम', 'सरस्वती', 'है।']] ['अच्छा', 'नाम', 'है।']
# [['<end>', 'yasuyoshi', 'tokuma', 'producer', 'executive', 'chief', '<start>']] [['मुख्यकार्यकारीनिर्माता', 'tokuma', 'yasuyoshi']] ['हमारे', 'साथ', 'कुछ', 'का', 'उपयोग', 'है', '।']
# [['<end>', '.', 'sure', ',', 'plans', 'our', 'make', 'we', '<start>']] [['हमें', 'यकीन', 'है', 'कि', ',', 'हमारी', 'योजना', 'बनाते', 'हैं', '।']] ['हम', 'हम', 'वापस', ',', 'श्री', 'जल्दी', '।']
# [['<end>', '.', '.', '.', 'again', 'it', 'did', 'he', '.', '.', '.', 'look', '<start>']] [['देखो', '।', '।', '।', 'वह', 'इसे', 'फिर', 'से', 'किया', 'है', '।', '।', '।']] ['तो', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।']
# [['<end>', '.', 'john', ',', 'please', 'off', 'it', 'turn', '<start>']] [['जॉन', ',', 'कृपया', 'इसे', 'बंद', 'कर', 'दो।']] ['मैं', 'तीन', 'वापस', ',', 'कृपया', '।']
# [['<end>', '?', 'song', 'special', 'my', 'just', '<start>']] [['बस', 'मेरा', 'स्पेशल', 'गाना', '?']] ['बस', 'बस', 'अपने', 'नाम', 'में', '?']
# [['<end>', '?', 'soon', 'too', 'i', 'am', '<start>']] [['मैं', 'भी', 'जल्द', 'ही', 'हूँ', '?']] ['मैं', 'भी', 'जा', 'रहा', 'हूँ', '?']
# [['<end>', 'now', 'dance', 'everybody', ']', 'speakers', '[on', '<start>']] [['[पर', 'वक्ताओं', ']', 'सब', 'लोग', 'अब', 'नृत्य']] ['अब', 'इस', 'साथ', 'पर', 'जानते', 'हैं', '?']
# [['<end>', '.', 'jay', ',', 'god', 'my', ',', 'oh', '<start>']] [['हे', 'भगवान', ',', 'जे।']] ['ओह', ',', 'मेरी', 'भगवान', ',', 'चलो', '।']
# [['<end>', '?', 'too', 'cricketer', 'a', 'she', 'is', '<start>']] [['वह', 'एक', 'क्रिकेटर', 'भी', 'है', '?']] ['क्या', 'वह', 'कुछ', 'भी', 'नहीं', 'है', '?']
# [['<end>', '.', 'condition', 'critical', 'a', 'is', 'it', '<start>']] [['यह', 'एक', 'की', 'हालत', 'गंभीर', 'है।']] ['यह', 'एक', 'बार', 'है।']
# [['<end>', '.', 'go', 'and', 'money', 'your', 'take', '<start>']] [['अपने', 'पैसे', 'ले', 'लो', 'और', 'जाओ', '।']] ['हमें', 'हमें', 'करने', 'के', 'लिए', 'धन्यवाद', '।']
# [['<end>', '.', 'corn', 'of', 'acres', 'had', 'we', '<start>']] [['हमारे', 'पास', 'काफी', 'मकाई', 'थी', '।']] ['हम', 'खैर', 'से', 'प्राप्त']
# [['<end>', '.', 'here', 'down', 'good', 'all', 'is', 'it', '<start>']] [['यहाँ', 'रास्ता', '।']] ['यह', 'बहुत', 'और', 'है', 'और', 'यह', 'बहुत', 'है', '।']
# [['<end>', '.', 'trappers', 'were', 'guys', 'these', '<start>']] [['वे', 'लोग', 'बहेलिए', 'थे।']] ['वहाँ', 'ने', '।']
# [['<end>', '.', 'sons', '.', '.', '.', 'your', 'than', 'more', '<start>']] [['अपने', 'बेटों', 'से', 'भी', '।', '।', '।', 'ज़्यादा।']] ['तुम्हारी', 'नाम', 'नाम', '।', '।', '।']
# [['<end>', '.', 'time', 'long', 'a', 'is', 'it', '<start>']] [['यह', 'एक', 'लंबा', 'समय', 'है', '।']] ['यह', 'एक', 'समय', 'है', '।']
# [['<end>', '?', 'in', 'me', 'clue', 'wanna', 'you', '<start>']] [['तुम्हें', 'सुराग', 'मुझ', 'में', '?']] ['तुम', 'मुझे', 'मेरे', 'लिए', 'क्यों', '?']
# [['<end>', '!', 'done', 'they', 'what', 'is', 'it', '<start>']] [['यह', 'किया', 'है', '!']] ['ये', 'क्या', 'है', '?']
# [['<end>', '.', 'something', 'do', ',', 'urgent', 'is', 'it', '<start>']] [['यह', 'अति', 'आवश्यक', 'है', ',', 'कुछ', 'करो।']] ['यह', 'अच्छा', 'है', ',', 'यह', 'एक', 'है', '।']
# [['<end>', '.', 'hair', 'her', 'took', 'you', '<start>']] [['आप', 'उसके', 'बाल', 'लिया', '।']] ['तुम', 'और', 'पिता', 'की', 'तरह', '।']
# [['<end>', '.', 'kdk', 'calling', 'kdk', '<start>']] [['के', 'डी', 'के', 'बुला', 'रहा', 'है', 'के', 'डी', 'के', 'को', '।']] ['के', 'लिए', 'बाहर', 'बताओ', '।']
# [['<end>', '.', 'here', 'im', 'knows', 'he', '<start>']] [['उन्होंने', 'कहा', 'कि', 'मैं', 'यहाँ', 'हूँ', 'जानता', 'है', '।']] ['मैं', 'यहाँ', 'भी', 'आ', 'रहा', 'हूँ', '।']
# [['<end>', '.', 'bhairava', ',', 'answer', 'an', 'need', 'i', '<start>']] [['मुझे', 'जवाब', 'चाहिये', ',', 'भैरवा', '।']] ['मैं', 'एक', 'और', 'की', ',', 'मैं', 'एक', 'था', '।']
# [['<end>', '.', 'christian', ',', 'dad', 'elias', 'is', 'it', '<start>']] [['मैं', 'एलियास', 'का', 'पिताजी', 'हूं', ',', 'क्रिस्चियन', '।']] ['यह', 'सब', 'हो', 'गया', ',', 'श्री', '।', '।', '।']
# [['<end>', '.', 'red', 'code', 'a', 'got', 'we', '<start>']] [['हमें', 'लाल', 'को़ड', 'मिला', 'है।']] ['हम', 'एक', 'एक', 'हम', 'की', 'जरूरत', 'है', '।', '।', '।']
# [['<end>', '.', 'you', 'with', 'was', 'she', '<start>']] [['वह', 'तुम्हारे', 'साथ', 'था।']] ['वह', 'अपने', 'आप', 'के', 'लिए', 'मिला', 'है', '।']
# [['<end>', '.', 'terms', 'my', 'are', 'these', '<start>']] [['ये', 'मेरे', 'शब्द', 'हैं', '।']] ['तो', 'मेरे', 'पिता', 'में', 'हैं', '।']
# [['<end>', '.', '.', '.', 'bankrupt', 'went', 'aig', 'when', '<start>']] [['एआईजीदिवालियाहो', 'गयाजब', '।', '।', '।', '/मैं']] ['अब', 'यह', 'कर', 'रहा', 'था', '।', '।', '।']
# [['<end>', '?', 'money', 'for', 'asking', 'he', 'is', '<start>']] [['क्या', 'वह', 'पैसे', 'मांग', 'रहा', 'है', '?']] ['वह', 'कुछ', 'के', 'लिए', 'है', '?']
# [['<end>', '.', 'it', 'get', 'can', 'we', '<start>']] [['हम', 'इसे', 'प्राप्त', 'कर', 'सकते', 'हैं', '।']] ['हम', 'यह', 'कर', 'रहे', 'हैं', '।']
# [['<end>', '?', 'at', 'me', 'remember', 'you', '<start>']] [['तुम', 'मुझे', 'में', 'याद', 'है', '?']] ['तुम', 'मेरे', 'लिए', 'है', '?']
# [['<end>', 'may', 'you', 'while', 'roses', 'gather', '<start>']] [['गुलाब', 'इकट्ठा', 'जबकि', 'आप', 'कर', 'सकते', 'हैं']] ['तुम्हारे', 'साथ', 'वह', 'आप', 'को', 'मार', 'सकती', 'हो', '?']
# [['<end>', '.', 'can', 'you', 'if', 'see', 'you', '<start>']] [['यदि', 'आप', 'कर', 'सकते', 'आप', 'देखते', 'हैं', '।']] ['आप', ',', 'आप', 'को', 'कर', 'रहे', 'हैं']
# [['<end>', '.', 'teresa', 'mother', 'at', 'look', '<start>']] [['जैसे', 'के', 'मदर', 'टेरेसा']] ['वह', 'किसी', 'पर', 'वहाँ', 'था', '।']
# [['<end>', '?', 'gold', 'for', 'digging', 'you', 'are', '<start>']] [['आप', 'सोने', 'के', 'लिए', 'खुदाई', 'कर', 'रहे', 'हैं', '?']] ['आप', 'के', 'लिए', 'कुछ', 'पर', 'हैं', '?']
# [['<end>', '?', 'tomans', 'in', 'much', 'how', '<start>']] [['कितने', 'तोमंस', '?']] ['क्या', 'में', 'क्या', '?']
# [['<end>', '.', 'surrender', 'to', 'you', 'forbid', 'i', '<start>']] [['मैं', 'तुम्हें', 'समर्पण', 'के', 'लिए', 'मना', 'करता', 'हूं', '।']] ['मैं', 'तुम्हें', 'भी', 'करने', 'के', 'लिए', 'धन्यवाद', 'है', '।']
# [['<end>', 'problem', 'my', 'not', 'is', 'it', '<start>']] [['मुझे', 'नहीं', 'पता']] ['यह', 'कोई', 'मेरी', 'नहीं', 'है']
# [['<end>', '!', 'him', 'got', 'i', '<start>']] [['मैंने', 'पकड़', 'लिया', '!']] ['मैं', 'उसे', 'नहीं', 'कर', 'रहे', 'हैं', '!']
# [['<end>', '.', 'late', 'too', 'not', 'is', 'it', ',', 'well', '<start>']] [['खैर', ',', 'यह', 'भी', 'देर', 'नहीं', 'हुई', 'है।']] ['खैर', ',', 'यह', 'नहीं', 'है', '।']
# [['<end>', 'peter', 'to', 'hookers', 'sends', 'he', '<start>']] [['वह', 'पीटर', 'करने', 'के', 'लिए', 'भेजता', 'है', 'वेश्यांए']] ['वह', 'उसे', 'मदद', 'होगा', '।']
# [['<end>', '.', 'now', 'here', 'in', 'get', '<start>']] [['अब', 'यहाँ', 'से', 'जाओ', '।']] ['यहाँ', 'पर', 'यहाँ', 'पर', '।']
# [['<end>', 'queen', 'the', 'be', 'ill', 'and', '<start>']] [['और', 'मैं', 'रानी', 'हो', 'जाएगा']] ['और', 'मैं', 'हूँ', '!']
# [['<end>', '?', 'you', 'choking', 'was', 'he', '<start>']] [['वह', 'तुम्हारा', 'गला', 'घोट', 'रहा', 'था', '?']] ['वह', 'तुम्हें', 'मार', 'जाएगा', '?']
# [['<end>', '?', 'about', 'it', 'was', 'what', 'well', '<start>']] [['अच्छा', 'है', 'कि', 'इसके', 'बारे', 'में', 'क्या', 'था', '?']] ['क्या', 'कहा', 'कि', 'क्या', 'कहा', '?']
# [['<end>', '.', 'b', 'staircase', 'on', 'was', 'brossard', '<start>']] [['b', 'नंबर', 'की', 'सीढ़ी']] ['कुछ', 'पर', 'पर', 'की', 'जरूरत', 'है', '।']
# [['<end>', '.', 'much', 'very', 'you', 'thank', '<start>']] [['बहुत', ',', 'बहुत', 'शुक्रिया।']] ['बहुत', 'बहुत', 'धन्यवाद', '।']
# [['<end>', '.', 'friend', 'best', 'my', 'was', 'he', '<start>']] [['वह', 'मेरा', 'सबसे', 'अच्छा', 'दोस्त', 'था']] ['वह', 'सिर्फ', 'मुझे', 'कुछ', 'नहीं', 'था', '।']
# [['<end>', '.', 'up', 'all', 'them', 'round', '<start>']] [['ले', 'आओ', 'सबको।']] ['वे', 'सभी', 'दे', '।']
# [['<end>', '.', 'way', 'my', 'of', 'out', 'stay', '<start>']] [['मेरे', 'रास्ते', 'में', 'मत', 'आओ।']] ['मेरे', 'मेरे', 'लिए', 'बाहर', 'कर', 'रहा', 'है', '।']
# [['<end>', '.', 'by', 'near', 'hospital', 'a', 'is', 'there', '<start>']] [['यहाँ', 'सामने', 'एक', 'हॉस्पिटल', 'है']] ['एक', 'miller', 'का', 'एक', 'होगा।']
# [['<end>', '.', 'it', 'got', 'i', ',', 'no', '<start>']] [['नहीं', ',', 'मुझे', 'मिल', 'गया', '।']] ['नहीं', ',', 'मैं', 'यह', 'किया', '।']
# [['<end>', '.', 'him', 'with', 'go', 'will', 'i', '<start>']] [['मैं', 'उसके', 'साथ', 'जाना', 'होगा।']] ['मैं', 'उसे', 'मार', 'दिया']
# [['<end>', '!', 'man', ',', 'bullshit', 'is', 'this', '<start>']] [['यार', '!']] ['यह', 'सब', 'हैं', ',', 'है', 'ना', '!']
# [['<end>', '?', 'happen', 'this', 'can', 'how', '<start>']] [['ये', 'केसे', 'हो', 'सकता', 'हे', '?']] ['क्या', 'यह', 'कर', 'रहे', 'हैं', '?']
# [['<end>', '.', 'fury', 'night', 'a', 'is', 'that', '<start>']] [['यह', 'ड्रैगन', 'तो', 'एक', 'नाइट', 'फ़्यूरी', 'है।']] ['कि', 'एक', 'इस', 'वाला', 'पर', '।']
# [['<end>', '.', '.', '.', 'design', 'the', 'based', 'i', '<start>']] [['मैं', 'डिजाइन', 'आधारित', '।', '।', '।']] ['मैं', 'अपने', 'पिता', 'का', 'श्री', 'जानते', 'हो', '।', '।', '।']
# [['<end>', '?', 'darling', ',', 'name', 'your', 'is', 'what', '<start>']] [['आपका', 'नाम', 'जान', ',', 'क्या', 'है', '?']] ['क्या', 'का', 'क्या', 'है', ',', '?']
# [['<end>', '.', 'warriors', 'monkey', 'the', 'assemble', '<start>']] [['इकट्ठा', 'बंदर', 'योद्धाओं', '।']] ['।', '।', '।']
# [['<end>', '.', '.', '.', 'in', 'collisions', '<start>']] [['में', 'टक्कर', '।', '।', '।']] ['लेकिन', '।', '।', '।']
# [['<end>', '.', 'time', 'good', 'very', 'is', 'that', '<start>']] [['यह', 'बहुत', 'अच्छा', 'समय', 'है', '।']] ['यह', 'बहुत', 'अच्छा', 'है', '।']
# [['<end>', '.', 'worn', 'bit', 'a', 'are', 'they', 'though', '<start>']] [['हालांकि', 'वे', 'थोड़ा', 'फटे', 'हुए', 'हैं', '।']] ['वे', 'वे', 'रहे', 'हैं']
# [['<end>', 'signatures', 'two', 'got', 'just', 'i', '<start>']] [['अभूतपूर्व', 'फैलाव', ',', 'meter', 'कीलें']] ['मैं', 'बस', 'बस', 'को', 'मार', 'रहे', 'हैं']
# [['<end>', '.', 'thing', 'same', 'the', 'seeing', 'are', 'we', '<start>']] [['हम', 'एक', 'ही', 'बात', 'देख', 'रहे', 'हैं']] ['हम', 'बहुत', 'बहुत', 'ही', 'नहीं', 'कर', 'रहे', 'हैं', '।']
# [['<end>', '.', 'jammed', 'be', 'to', 'seems', 'it', '<start>']] [['कुछ', 'अटक', 'गया', 'है']] ['यह', 'दूर', 'हो', 'गया', 'है', '।']
# [['<end>', '.', 'resignation', 'my', 'this', 'consider', '<start>']] [['इसे', 'मेरा', 'इस्तीफ़ा', 'मान', 'लीजिए', '!']] ['यह', 'मेरा', 'अच्छा', 'आज', 'हैं', '।']
# [['<end>', '?', 'for', 'those', 'are', 'what', '<start>']] [['के', 'लिए', 'वो', 'क्या', 'है', '?']] ['क्या', 'तुम', 'पर', 'हैं', '?']
# [['<end>', '.', 'wrong', 'too', 'is', 'nothing', '<start>']] [['कुछ', 'भी', 'गलत', 'है', '।']] ['कोई', 'भी', 'नहीं', 'है', '।']
# [['<end>', '!', 'is', 'she', 'happy', 'how', ',', 'look', '<start>']] [['देखिये', ',', 'वो', 'कितनी', 'खुश', 'है', '!']] ['वह', ',', 'वह', 'वापस', 'हो', '!']
# [['<end>', '.', 'resterilized', 'wanna', 'not', 'do', 'i', '<start>']] [['मैं', 'resterilized', 'नहीं', 'चाहता', '।']] ['मैं', 'परवाह', 'नहीं', 'है', '।']
# [['<end>', '.', 'love', 'unconditional', 'hence', 'is', 'that', '<start>']] [['इसलिए', 'कि', 'बिना', 'शर्त', 'प्यार', 'है', '।']] ['वह', 'सब', 'एक', 'और', 'है', '।']
# [['<end>', '.', 'me', 'hurt', 'never', 'would', 'you', '<start>']] [['तुम', 'मुझे', 'कभी', 'चोट', 'नहीं', 'पहुँचा', 'सकते।']] ['तुम', 'मुझे', 'एक', 'पसंद', 'कर', 'रहे', 'हैं', '।']
# [['<end>', '.', 'store', 'jewelry', 'a', 'is', 'it', '<start>']] [['यह', 'एक', 'गहने', 'की', 'दुकान', 'है', '।']] ['यह', 'एक', 'अच्छा', 'है', '।']
# [['<end>', '.', 'up', 'shut', 'gonna', 'im', '<start>']] [['मैं', 'चुप', 'रहा', 'हूँ', '।']] ['मैं', 'यह', 'नहीं', 'हूँ।']
# [['<end>', '.', 'club', 'fan', 'swan', 'vincent', 'the', '<start>']] [['विन्सेंट', 'स्वान', 'के', 'प्रशंसक।']] ['मेरे', 'पास', 'को', 'माध्यम', 'से', 'को', 'मार', 'रहा']
# [['<end>', '!', 'go', ',', 'go', '!', 'down', 'rope', 'fast', '<start>']] [['चलो', '!']] ['वे', 'का', 'उपयोग', '!']
# [['<end>', '.', '.', '.', 'take', 'i', 'breath', 'every', '"with', '<start>']] [['"हर', 'सांस', 'मैं', 'ले', 'के', 'साथ', '।', '।', '।']] ['हाँ', ',', 'मैं', 'तुम्हारे', 'साथ', 'नहीं', 'कर', 'सकते', '।', '।', '।']
# [['<end>', '.', 'tonight', ',', 'cash', ',', 'it', 'make', '<start>']] [['यह', 'बनाओ', ',', 'नकद', ',', 'आज', 'की', 'रात', '।']] ['यह', 'आ', ',', ',', 'यह', 'है', '।']
# [['<end>', '.', 'counting', 'and', 'minute', 'one', '<start>']] [['एक', 'मिनट', 'और', 'गिनती', 'शुरू।']] ['आपकी', '"']
# [['<end>', '?', 'someone', 'for', 'looking', 'you', '<start>']] [['किसी', 'को', 'खोज', 'रहे', 'हो', '?']] ['आप', 'को', 'क्यों', 'क्यों', 'दिया', '?']
# [['<end>', '!', 'alone', 'hat', 'my', 'leave', ',', 'hey', '<start>']] [['ऐ', ',', 'मेरा', 'टोप', 'छोड़ो', '!']] ['पर', ',', 'मेरे', 'अपने', 'से', 'से', '!']
# [['<end>', '!', 'hurry', '.', 'boats', 'bringing', 'are', 'they', '<start>']] [['मैं', 'वापस', 'हो', 'जाएगा', '!']] ['वे', 'वे', 'कर', 'रहे', 'हैं', '।', '।', '।']
# [['<end>', '.', 'decision', 'my', 'made', 'i', '<start>']] [['मैं', 'अपने', 'निर्णय', 'लिया', '।']] ['मैं', 'मेरे', 'साथ', 'को', 'सकते', 'हैं', '।']
# [['<end>', '?', 'anything', 'do', 'it', 'does', '<start>']] [['क्या', 'यह', 'कुछ', 'करती', 'है', '?']] ['यह', 'कुछ', 'क्यों', 'है', '?']
# [['<end>', '.', 'know', 'not', 'do', 'i', '<start>']] [['मुझे', 'नहीं', 'पता।']] ['मैं', 'नहीं', 'नहीं', '।']
# ...
# [['<end>', '.', 'bike', 'the', 'take', 'is', 'let', '<start>']] [['चलो', 'साइकिल', 'से', 'चलें।']] ['चलो', 'चलो', '।']
# [['<end>', '?', 'here', 'live', 'caesar', 'did', '<start>']] [['क्या', 'कैसर', 'यहाँ', 'रहते', 'हैं', '?']] ['हमारे', 'साथ', 'ही', 'का', 'सकता', 'है', '?']
# [['<end>', '.', 'done', 'is', 'life', 'old', 'our', '<start>']] [['हमारी', 'पुरानी', 'जिंदगी', 'से', 'किया', 'जाता', 'है', '।']] ['हमारे', 'इस', 'डर', 'के', 'रहा', 'है', '।']
# [['<end>', '.', 'want', 'not', 'do', 'i', ',', 'no', '<start>']] [['नहीं', ',', 'मैं', 'नहीं', 'चाहती', '।']] ['नहीं', ',', 'मैं', 'नहीं', 'करना', '।']
# [['<end>', '.', 'murph', ',', 'me', 'was', 'it', '<start>']] [['वो', 'मैं', 'था', ',', 'murph', '।']] ['यह', 'है', ',', 'मुझे', 'था', '।']
# [['<end>', '.', 'meeting', 'the', 'to', 'over', 'come', '<start>']] [['मीटींग', 'में', 'आओ', '।']] ['चलो', 'चलो', 'चलो', '।']
# [['<end>', '.', 'home', 'it', 'take', 'is', 'let', '<start>']] [['के', 'घर', 'ले', 'चलो', '।']] ['चलो', 'घर', 'करने', 'के', 'लिए', '।']
# [['<end>', '?', 'about', 'running', 'out', 'he', 'is', '<start>']] [['वे', 'बाहर', 'इधरउधर', 'घूम', 'रहे', 'हैं', '?']] ['वह', 'उसके', 'बारे', 'में', 'जा', 'रहा', 'है', '?']
# [['<end>', '.', 'mate', ',', 'now', 'you', 'telling', 'im', '<start>']] [['मैं', ',', 'अब', 'मेट', 'तुम्हें', 'बता', 'रहा', 'हूँ', '।']] ['मैं', 'तुम्हें', 'भी', ',', 'बहुत', 'प्यार', 'कर', 'रहा', 'हूँ', '।']
# [['<end>', '.', 'cows', 'live', ',', 'mean', 'i', '<start>']] [['मतलब', ',', 'ज़िंदा', 'गायों', 'पर।']] ['मैं', 'क्या', 'है', ',', 'वो', 'अपनी', '!']
# [['<end>', '?', 'more', 'miss', 'you', 'do', 'who', '<start>']] [['तुम्हें', 'किसकी', 'याद', 'ज़्यादा', 'आती', 'है', '?']] ['आप', 'इस', 'कुछ', 'का', 'आप', 'की', '?']
# [['<end>', '.', 'level', 'that', 'at', 'not', '<start>']] [['मैं', 'ऐसा', 'नहीं', 'है', 'कि', 'स्तर', 'पर']] ['ऐसा', 'है', 'कि', 'कि', 'एक', 'में', 'नहीं', 'है।']
# [['<end>', '.', 'me', 'shitting', 'be', 'gotta', 'you', '<start>']] [['हद', 'हो', 'गई।']] ['तुम', 'मुझे', 'अभी', 'हो', ',', 'कोशिश', 'है।']
# [['<end>', '.', ',', ',', ',', '<start>']] [[',', ',', ',', '।']] [',', ',', ',', '।', '।', '।']
# [['<end>', '!', 'handsome', 'is', 'he', '<start>']] [['वह', 'सुंदर', 'है', '!']] ['वह', 'एक', 'कोई', 'सुनो', 'है', '!']
# [['<end>', '.', 'cheese', 'making', ',', 'cow', 'a', 'milking', '<start>']] [['एक', 'खेत', 'में', '?']] ['एक', 'एक', ',', 'आदमी', 'आदमी', 'है', '।']
# [['<end>', '.', 'ya', 'meet', 'to', 'nice', '<start>']] [['फिर', 'से', 'मिलकर', 'अच्छा', 'लगा।']] ['तुमने', 'देखो', 'के', 'लिए', '।', '।']
# [['<end>', '?', 'treasure', 'same', 'the', 'chasing', '<start>']] [['क्यों', 'हम', 'समुद्र', 'के', 'मध्य', 'में', 'बाँट', 'रहे', 'हैं', '।', '।', '।']] ['उसके', 'लिए', 'कुछ', 'पर', '।']
# [['<end>', '!', 'that', 'do', 'not', 'ca', 'you', '<start>']] [['तुम', 'ऐसा', 'नहीं', 'कर', 'सकते', '!']] ['तुम', 'ऐसा', 'नहीं', 'कर', 'सकते', '!']
# [['<end>', '.', 'surprise', 'pleasant', 'a', 'what', '<start>']] [['कितना', 'सुखद', 'आश्चर्य', 'है', '।']] ['एक', 'और', 'एक', 'मेरा', 'की', 'हमें', 'दे', '।']
# [['<end>', '?', 'jaye', ',', 'got', 'we', 'do', 'what', '<start>']] [['हम', 'जाये', ',', 'क्या', 'मिला', '?']] ['हम', 'क्या', 'हो', ',', 'क्या', 'है', '?']
# [['<end>', '.', 'five', 'are', 'there', 'now', '<start>']] [['अब', 'वहाँ', 'पाँच', 'रहे', 'हैं।']] ['वे', 'कर', 'रहे', 'हैं', '।']
# [['<end>', '.', 'did', 'he', ',', 'course', 'of', '<start>']] [['बेशक', 'गया', 'होगा।']] ['वह', ',', 'वह', 'हो', 'गया', 'है', '।']
# [['<end>', '.', 'kang', 'yeonsak', 'is', 'name', 'his', '<start>']] [['उसका', 'नाम', 'yeonsak', 'कांग', 'है', '।']] ['तुम्हारी', 'नाम', 'नाम', 'हो', 'नाम', 'है', '।']
# [['<end>', '.', 'mine', 'is', 'girl', 'the', '<start>']] [['लड़की', 'मेरी', 'है', '।']] ['समय', '।', '।', '।']
# [['<end>', '.', 'shot', 'are', 'cannons', 'plasma', 'both', '<start>']] [['दोनों', 'प्लाज्मा', 'तोपों', 'गोली', 'मार', 'दी', 'हैं', '।']] ['वे', 'अपने', 'पिता', 'कर', 'रहे', 'हैं']
# [['<end>', '.', 'something', 'do', 'to', 'have', 'we', '<start>']] [['तो', 'फिर', 'somthing', ',', 'करते', 'हैं', '!']] ['हम', 'सब', 'अच्छा', 'है', '।']
# [['<end>', '.', 'sure', 'so', 'not', 'im', '<start>']] [['मुझे', 'इतना', 'यकीन', 'नहीं', 'है', '।']] ['मैं', 'भी', 'नहीं', 'हूँ', '।']
# [['<end>', '.', 'him', 'help', 'not', 'ca', 'we', '<start>']] [['हम', 'उसकी', 'मदद', 'नहीं', 'कर', 'सकते।']] ['हम', 'उसे', 'उसे', 'नहीं', 'किया', '।']
# [['<end>', '!', 'car', 'is', 'mom', 'my', 'is', 'that', '<start>']] [['यह', 'मेरी', 'माँ', 'की', 'कार', 'है', '!']] ['यही', 'कारण', 'है', 'कि', 'कि', '!']
# [['<end>', '.', '.', '.', 'fight', 'a', 'into', 'got', 'we', '<start>']] [['हम', 'एक', 'लड़ाई', 'में', 'मिला', '।', '।', '।']] ['हम', 'एक', 'और', 'होने', 'मिल', '।']
# [['<end>', '.', 'clear', 'not', 'is', 'face', 'his', '<start>']] [['उसका', 'चेहरा', 'साफ़', 'नहीं', 'दिखा', '।']] ['हमारे', 'साथ', 'समय', 'नहीं', 'कर', 'सकते', '।']
# [['<end>', '.', 'up', 'it', 'picked', 'you', '<start>']] [['आप', 'इसे', 'उठाया', '।']] ['आप', 'इसे', 'चाहिए', '।']
# [['<end>', '.', 'five', 'in', 'there', 'be', 'ill', '<start>']] [['मैं', 'पांच', 'में', 'नहीं', 'होगा', '।']] ['मैं', 'वहाँ', 'वहाँ', 'जा', 'रहा', 'हूँ।']
# [['<end>', ']', 'sighs', 'man', '[', '<start>']] [['[मैन', 'आह', ']']] ['बस', 'की', 'थी']
# [['<end>', '?', 'there', 'over', 'get', 'to', 'how', '<start>']] [['हम', 'वहाँ', 'कैसे', 'जायेंगे', '?']] ['क्या', 'के', 'उसे', 'करने', 'के', 'लिए', 'तैयार', 'हैं', '?']
# [['<end>', '?', 'doing', 'you', 'are', 'what', ',', 'hey', '<start>']] [['अरे', 'तुम', 'क्या', 'कर', 'रहे', 'हो', '?']] ['अरे', ',', 'तुम', 'क्या', 'कर', 'रहे', 'हो', '?']
# [['<end>', '?', 'that', 'want', 'you', 'did', '<start>']] [['यह', 'वाली', 'तुम्हें', 'चाहिए', 'थी', 'क्या', '?']] ['तुम', 'कैसे', 'जानते', 'हो', '?']
# [['<end>', '.', 'no', 'me', 'tell', 'nobody', 'not', 'ai', '<start>']] [['नहीं', 'कोई', 'भी', 'मुझे', 'बता', 'नहीं', 'है।']] ['कोई', 'नहीं', 'है', ',', 'मुझे', 'नहीं', 'कर', 'रहे', 'हैं', '।']
# [['<end>', '?', 'right', ',', 'off', 'it', 'cut', 'you', '<start>']] [['तुम', 'सही', 'हो', ',', 'इसे', 'काट', '?']] ['तुम', ',', 'यह', 'सही', 'किया', '?']
# [['<end>', '?', 'doing', 'you', 'are', 'what', '<start>']] [['क्या', 'कर', 'रहे', 'हो', '?']] ['तुम', 'क्या', 'कर', 'रहे', 'हो', '?']
# [['<end>', '.', 'again', 'you', 'bother', 'to', 'sorry', '<start>']] [['फिर', 'आपको', 'परेशान', 'के', 'लिए', 'खेद', 'है']] ['आप', 'के', 'लिए', 'आप', 'की', 'तरह', 'होगा', '।']
# [['<end>', '.', 'one', 'that', 'take', 'you', ',', 'okay', '<start>']] [['ठीक', 'है', ',', 'तुम', 'एक', 'है', 'कि', 'ले', '।']] ['ठीक', 'है', ',', 'तुम', 'एक', 'अच्छा', 'थे', '।']
# [['<end>', '?', 'okay', ',', 'cokes', 'two', 'the', 'just', '<start>']] [['बस', 'दो', 'cokes', ',', 'ठीक', 'है', '?']] ['मेरे', 'भी', 'भी', 'हो', ',', 'यह', 'करते', 'हैं', '?']
# [['<end>', '.', 'is', 'year', 'new', 'almost', 'is', 'it', '<start>']] [['यह', 'लगभग', 'नए', 'साल', 'की', 'है', '।']] ['यह', 'सिर्फ', 'कि', 'की', 'है', '।']
# [['<end>', '.', 'this', 'about', 'sorry', 'im', ',', 'look', '<start>']] [['मैं', 'इस', 'बारे', 'में', 'माफी', 'चाहता', 'हूँ', ',', 'देखो।']] ['मैं', ',', 'मैं', 'कुछ', 'पर', 'हूँ', '।']
# [['<end>', '.', 'peace', 'wants', 'world', 'the', '<start>']] [['दुनिया', 'को', 'अमन', 'की', 'ज़रूरत', 'है।']] ['उसके', 'लिए', 'पर', '।']
# [['<end>', '.', 'time', 'some', 'it', 'give', ',', 'just', '<start>']] [['बस', ',', 'यह', 'कुछ', 'समय', 'दे', '।']] ['खैर', ',', 'यह', 'एक', 'समय', 'नहीं', 'है।']
# [['<end>', '.', 'pulse', 'his', 'find', 'not', 'ca', 'i', '<start>']] [['मैं', 'नहीं', 'मिल', 'सकता', 'है', 'उसकी', 'नब्ज', '।']] ['मैं', 'अपने', 'नहीं', 'कर', 'सकते', 'हैं', '।']
# [['<end>', '.', 'start', 'to', 'about', 'im', '<start>']] [['मैं', 'शुरू', 'करने', 'के', 'बारे', 'में', 'हूँ', '।']] ['मैं', 'कर', 'रहा', 'हूँ', 'कि', 'मैं']
# [['<end>', '.', 'everybody', ',', 'tight', 'it', 'keep', '<start>']] [['यह', 'तंग', 'रखें', ',', 'सब', 'लोग', '।']] ['यह', ',', 'आप', 'के', 'लिए', 'नहीं', 'कर', 'चाहिए', '!']
# [['<end>', '.', 'off', 'yourself', 'dry', 'just', ',', 'there', '<start>']] [['अब', ',', 'बस', 'अपने', 'को', 'सुखा', 'लो', '।']] ['है', ',', 'मैं', 'कुछ', 'बहुत', 'उस', 'हैं', '।']
# [['<end>', '.', 'that', 'was', 'there', ',', 'yeah', '<start>']] [['हाँ', ',', 'वह', 'कारण', 'भी', 'था।']] ['हाँ', ',', 'वह', ',', 'यह', 'कुछ', 'नहीं', 'है।']
# [['<end>', '.', 'rules', 'the', 'not', 'is', 'that', '<start>']] [['यही', 'नियम', 'नहीं', 'है।', 'न', 'पैसा', 'न', 'माशूका।']] ['ये', 'बहुत', 'नहीं', 'है', '।']
# [['<end>', '™', 'mnköö', 'nder', '!', 'prm', '©', '<start>']] [['©', 'पीआर', 'एम', 'nderएम', 'nköö', '\x99']] ['©', 'पीआर', 'एम', 'nderएम', 'nköö', '\x99']
# [['<end>', '.', 'alive', 'left', 'last', 'the', 'im', '<start>']] [['मैं', 'जिंदा', 'छोड़ा', 'पिछले', 'हूँ', '/', 'मैं']] ['मैं', 'बहुत', 'ही', 'से', 'कर', 'रहा', 'हूँ', '।']
# [['<end>', '?', 'doing', 'you', 'are', 'what', '<start>']] [['तुम', 'क्या', 'कर', 'रहे', 'हो', '?']] ['तुम', 'क्या', 'कर', 'रहे', 'हो', '?']
# [['<end>', '.', 'any', 'them', 'give', 'not', 'do', '<start>']] [['उनको', 'मत', 'देना', '।']] ['तुम्हारे', 'समय', 'मत', 'करो', '।']
# [['<end>', '.', 'detail', 'protection', 'his', 'on', ',', 'actually', '<start>']] [['अपनी', 'ही', 'सुरक्षा', 'में।']] ['अब', ',', 'बहुत', 'देखो', '।']
# [['<end>', '.', 'survive', 'to', 'adapt', 'i', ',', 'well', '<start>']] [[',', 'क्या', 'मैं', 'जीवित', 'करने', 'के', 'लिए', 'अनुकूलित', '!']] ['खैर', ',', 'मैं', 'उसे', 'ही', 'हूँ।']
# [['<end>', '!', 'incoming', 'bogey', 'a', 'have', 'i', '<start>']] [['मैं', 'आने', 'वाले', 'एक', 'दलदली', 'है', '!']] ['मुझे', 'एक', 'नहीं', 'है', '!']
# [['<end>', '?', 'saying', 'you', 'are', 'what', '<start>']] [['हाँ', ',', 'मैं', 'एक', 'भूत', 'देखा', 'है', '?']] ['तुम', 'क्या', 'कह', 'रहे', 'हो', '?']
# [['<end>', '.', 'bars', 'candy', 'love', 'i', '<start>']] [['मैं', 'कैंडी', 'बार', 'प्यार', '।']] ['मैं', 'अपने', 'ही', 'प्यार', 'कर', 'सकते', 'हैं', '।']
# [['<end>', '.', 'teaching', 'master', 'you', 'after', '<start>']] [['शिक्षण', 'में', 'महारत', 'हासिल', 'करने', 'के', 'बाद।']] ['आप', 'को', 'ही', 'से', 'कर', 'दिया', '।']
# [['<end>', '?', 'usual', 'the', ',', 'fellas', 'hey', '<start>']] [['अरे', 'दोस्तों', ',', 'हमेशा', 'की', 'तरह', '?']] ['अरे', ',', 'यह', 'क्या', 'है', '?']
# [['<end>', '.', 'man', 'a', 'im', 'because', ',', 'yes', '<start>']] [['हां', ',', 'क्\u200dयोंकि', 'मैं', 'पुरुष', 'हूं', '।']] ['हाँ', ',', 'मैं', 'एक', 'बहुत', 'हूँ', '।']
# [['<end>', '?', 'you', 'with', 'wrong', 'is', 'what', '<start>']] [['तुम्हें', 'क्या', 'हुआ', '?']] ['तुम्हारे', 'साथ', 'क्या', 'हुआ', 'है', '?']
# [['<end>', '.', 'ruth', ',', 'order', 'an', 'is', 'that', '<start>']] [['कि', 'रुथ', ',', 'एक', 'आदेश', 'है', '।']] ['वह', ',', 'यह', 'एक', 'श्री', 'हुआ', 'है', '।']
# [['<end>', '.', 'is', 'she', 'how', 'wonder', '<start>']] [['आश्चर्य', 'है', 'कि', 'वह', 'कैसे', 'होता', 'है।']] ['वह', 'कैसे', 'कैसे', 'है', '।']
# [['<end>', '?', 'them', 'collect', 'you', '<start>']] [['तुम्हें', 'इनका', 'शौक', 'है', '?']] ['आप', 'भी', 'क्यों', 'से', 'तरह', '?']
# [['<end>', '.', 'out', 'me', 'help', 'laughing', 'stop', '<start>']] [['हँसना', 'बंद', 'करो', 'और', 'इसे', 'बाहर', 'निकालने', 'मे', 'मेरी', 'मदद', 'करो', '।']] ['मुझे', 'उसे', 'मदद', 'दे', 'दो।']
# [['<end>', '.', 'aunty', ',', 'start', 'just', 'you', '<start>']] [['तुम', 'बस', 'शुरू', ',', 'चाची।']] ['आप', 'सिर्फ', ',', 'श्री', 'श्री', 'थे', '।']
# [['<end>', '.', 'yet', 'over', 'not', 'is', 'this', '<start>']] [['ये', 'अभी', 'ख़त्म', 'नहीं', 'हुआ', 'है।']] ['यह', 'बहुत', 'भी', 'नहीं', 'है', '।']
# [['<end>', '.', 'away', 'are', 'we', 'like', 'not', 'is', 'it', '<start>']] [['ऐसा', 'नहीं', 'है', 'कि', 'हम', 'दूर', 'हैं', '।']] ['यह', 'इस', 'भी', 'भी', 'से', 'मैं', 'नहीं', 'जा', 'सकते', 'हो', '।']
# [['<end>', '.', 'man', 'family', 'a', 'not', 'im', '<start>']] [['मैं', 'पारिवारिक', 'आदमी', 'नहीं', 'हूँ।']] ['मैं', 'एक', 'एक', 'बात', 'हूँ', '।']
# [['<end>', '!', 'demon', 'a', 'into', 'turn', 'not', 'do', '<start>']] [['एक', 'राक्षस', 'में', 'बदल', 'मत', 'करो', '!']] ['एक', 'एक', 'पैसा', 'नहीं', 'है', '!']
# [['<end>', '.', '.', 'me', 'with', 'here', 'is', 'she', '<start>']] [['वो', 'यहां', 'ओवल', 'ऑफ़िस', 'में']] ['वह', 'यहाँ', 'भी', 'आ', 'रहा', 'है', '।']
# [['<end>', '!', 'are', 'there', 'many', 'how', 'look', '<start>']] [['देखो', 'यहां', 'कितने', 'हैं', '!']] ['आप', 'वहाँ', 'के', 'लिए', 'कर', 'रहे', 'हैं', '!']
# [['<end>', '.', 'me', 'with', 'was', 'brother', 'my', '<start>']] [['मेरा', 'भाई', 'मेरे', 'साथ', 'था', '।']] ['मेरे', 'मेरे', 'साथ', 'प्यार', ',']
# [['<end>', '?', 'you', 'are', 'where', ',', 'daddy', '<start>']] [['डैडी', ',', 'जहां', 'आप', 'कर', 'रहे', 'हैं', '?']] ['अरे', ',', 'तुम', 'कहाँ', 'हो', '?']
# [['<end>', '.', 'change', 'sex', 'a', 'be', 'please', '<start>']] [['तुम', 'शारीरिक', 'बदलाव', 'कर', 'डालो', '।']] ['एक', 'वहाँ', 'का', 'वापस', 'हो', 'रही']
# [['<end>', '.', 'puppies', 'love', 'i', '<start>']] [['मैं', 'पिल्लों', 'से', 'प्यार', 'हूं।']] ['मुझे', 'सब', 'प्यार', 'है', '।']
# [['<end>', '.', 'tried', 'already', 'he', '<start>']] [['वह', 'पहले', 'से', 'ही', 'करने', 'की', 'कोशिश', 'की', '।']] ['वह', 'वह', 'से', 'ही', 'मार', 'रहा', 'है', '।']
# [['<end>', 'again', 'up', 'him', 'tie', '<start>']] [['उसे', 'फिर', 'से', 'टाई']] ['उसे', 'उसे', 'दे', 'चाहिए', '!']
# [['<end>', '?', 'papers', 'got', 'you', 'have', '<start>']] [['क्या', 'आपके', 'पास', 'कागज़ात', 'हैं', '?']] ['क्या', 'तुमने', 'हो', '?']
# [['<end>', '.', 'woods', 'these', 'from', 'not', 'are', 'they', '<start>']] [['इन', 'जंगल', 'से', 'नहीं', 'कर', 'रहे', 'हैं', '।']] ['वे', 'तो', 'नहीं', 'से', 'नहीं', 'कर', 'रहे', 'हैं', '।']
# [['<end>', '.', 'camera', 'the', 'for', 'smile', '<start>']] [['फ़ोटो', 'खिंचवाने', 'के', 'लिए', 'मुस्कुराओ।']] ['के', 'घर', 'के', 'लिए', '।']
# [['<end>', '?', 'you', 'tell', 'i', 'did', 'what', '<start>']] [['मैं', 'तुम्हें', 'क्या', 'बताया', '?']] ['मैं', 'तुम', 'क्या', 'मिल', 'रहा', 'है', '?']
# [['<end>', '?', 'doing', 'you', 'are', 'what', '<start>']] [['आप', 'क्या', 'कर', 'रहे', 'हो', '?']] ['तुम', 'क्या', 'कर', 'रहे', 'हो', '?']
# [['<end>', '?', 'tickets', 'airline', 'what', '<start>']] [['~', 'क्या', '?']] ['क्या', 'तुमने', 'क्या', 'कहा', '?']
# [['<end>', '.', 'second', 'one', 'for', 'not', '<start>']] [['पल', 'भर', 'के', 'लिए', 'भी', 'नहीं।']] ['एक', 'वहाँ', 'के', 'लिए', 'कोई', 'नहीं', 'है।']
# [['<end>', '.', 'it', 'got', 'i', ',', 'okay', '<start>']] [['ठीक', 'है', ',', 'मैं', 'समझ', 'गया', '।']] ['ठीक', 'है', ',', 'मैं', 'यह', 'किया', '।']
# [['<end>', '.', 'president', '.', 'mr', ',', 'you', 'thank', '<start>']] [['मि', '।', 'प्रेज़ीडेंट।']] ['धन्यवाद', ',', 'धन्यवाद', '।', '।', '।']
# [['<end>', '.', 'exit', 'another', 'not', 'is', 'there', '<start>']] [['और', 'कोई', 'निकास', 'नहीं', 'है।']] ['वहाँ', 'पर', 'कोई', 'नहीं', 'है', '!']
# [['<end>', '.', 'dad', 'meet', 'come', 'will', 'i', '<start>']] [['मैं', 'देख', 'पिता', 'आ', 'जाएगा।']] ['मैं', 'घर', 'के', 'लिए', 'बात', 'कर', 'रहा', 'हूँ', '।']
# [['<end>', '?', 'heart', 'your', 'of', 'all', '<start>']] [['पूरे', 'दिल', 'से', '?']] ['के', 'पिता', 'का', 'नाम', 'करना', 'चाहिए', '?']
# [['<end>', '.', 'hell', 'fucking', ')', 'groans', '(', '<start>']] [['(कराहना', ')', 'कमबख्त', 'नरक', '।']] ['समय', 'मत', 'करो', ',', ')']
# [['<end>', '?', 'there', 'get', 'gonna', 'you', 'are', 'how', '<start>']] [['कैसी', 'हो', 'तुम', 'वहाँ', 'मिलने', 'वाला', 'है', '?']] ['तुम', 'कैसे', 'कौन', 'हो', '?']
# [['<end>', '.', 'do', 'i', '.', 'no', ',', 'no', '<start>']] [['मुझे', 'क्या', 'करना', 'है', '।']] ['नहीं', ',', 'नहीं', '।']
# [['<end>', '.', 'oclock', 'two', 'is', 'it', ',', 'friis', 'master', '<start>']] [['मास्टर', 'फ्रिईस', '।', 'दो', 'बजे', 'गये', 'है', '।']] ['ठीक', 'है', ',', 'यह', 'अच्छा', 'है', '।']
# [['<end>', '.', 'grateful', 'be', 'hell', 'sure', 'im', '<start>']] [['मुझे', 'यकीन', 'है', 'कि', 'वह', 'आभारी', 'रहेगा', '।']] ['मैं', 'अभी', 'भी', 'आ', 'रहा', 'हूँ', '।']
# [['<end>', '.', 'not', 'you', 'told', 'i', '<start>']] [['मैं', 'तुम्हें', 'नहीं', 'बताया', '।']] ['मैं', 'तुम्हें', 'नहीं', 'चाहता', '।']
# [['<end>', '<start>']] [[]] ['से', 'मेरी', 'रहे', 'हैं']
#
# 0.30644074122915
# 0.3157127776198691

# %% [markdown]
# #try

# %%
import pandas as pd
df = pd.read_pickle('en_hi.pkl')
train, validate, test = np.split(df.sample(frac=1), [int(.7*len(df)), int(.8*len(df))])
print(train.shape, validate.shape, test.shape)
# Out:
# (7000, 2) (1000, 2) (2000, 2)

# %%
with open('/content/drive/My Drive/NeuralMT/data/dev.en', 'w') as writefile:
    writefile.write(('').join(validate['english']))
with open('/content/drive/My Drive/NeuralMT/data/dev.hi', 'w') as writefile:
    writefile.write(('').join(validate['hindi']))
with open('/content/drive/My Drive/NeuralMT/data/test.en', 'w') as writefile:
    writefile.write(('').join(test['english']))
with open('/content/drive/My Drive/NeuralMT/data/test.hi', 'w') as writefile:
    writefile.write(('').join(test['hindi']))
with open('/content/drive/My Drive/NeuralMT/data/train.en', 'w') as writefile:
    writefile.write(('').join(train['english']))
with open('/content/drive/My Drive/NeuralMT/data/train.hi', 'w') as writefile:
    writefile.write(('').join(train['hindi']))

# %%
data_folder = "data"
files = os.listdir(data_folder)
source_files = [os.path.join(data_folder, file) for file in files if ".en" in file]
target_files = [os.path.join(data_folder, file) for file in files if ".hi" in file]
print(source_files)

def generate_vocab(filenames):
    vocab = set()
    # no_words = 0
    for file in filenames:
        content = open(file).read()
        sentences = [sentence.split() for sentence in content.split('\n')]
        for sentence in sentences:
            for word in sentence:
                if word.lower() not in vocab:
                    vocab.add(word.lower())
                    # no_words += 1
    vocab = {word: num for num, word in enumerate(vocab)}
    return vocab

def parse_files_to_indices(filename, vocab):
    content = open(filename).read()
    return [[vocab[word] for word in sentence.split() if word in vocab] for sentence in content.split('\n')]

class Dataset:
    def __init__(self, source_files, target_files, batch_size=10):
        self.source_vocab = generate_vocab(source_files) #for entire lang
        self.target_vocab = generate_vocab(target_files) #for entire lang
        
        self.len_source = len(self.source_vocab.keys())
        self.source_pad, self.source_start, self.source_end = self.len_source + 2, self.len_source + 1, self.len_source
        self.len_target = len(self.target_vocab.keys())
        self.target_pad, self.target_start, self.target_end = self.len_target + 2, self.len_target + 1, self.len_target
        
        self.source_vocab['<pad>'], self.source_vocab['<start>'], self.source_vocab['<end>'] = [self.source_pad, 
                                                                                                self.source_start, 
                                                                                                self.source_end]
        self.target_vocab['<pad>'], self.target_vocab['<start>'], self.target_vocab['<end>'] = [self.target_pad,
                                                                                                self.target_start, 
                                                                                                self.target_end]
                                                                                              
        ##created indices for <pad>, <start> and <end> tokens
        self.len_source = len(self.source_vocab.keys())
        self.len_target = len(self.target_vocab.keys())
        
        ##inverse vocab for entire lang
        self.source_vocab_inv = {value:key for key, value in self.source_vocab.items()}
        self.target_vocab_inv = {value:key for key, value in self.target_vocab.items()}
        
        ##parsing files into indices
        for filename in source_files:
            if 'train' in filename:
                self.source_train = parse_files_to_indices(filename, self.source_vocab)
            if 'test' in filename:
                self.source_test = parse_files_to_indices(filename, self.source_vocab)
            if 'dev' in filename:
                self.source_dev = parse_files_to_indices(filename, self.source_vocab)
                
        for filename in target_files:
            if 'train' in filename:
                self.target_train = parse_files_to_indices(filename, self.target_vocab)
            if 'test' in filename:
                self.target_test = parse_files_to_indices(filename, self.target_vocab)
            if 'dev' in filename:
                self.target_dev = parse_files_to_indices(filename, self.target_vocab)
                
        ##random shuffling of training data before splitting into batches    
        self.indices = list(range(len(self.source_train)))
        random.shuffle(self.indices)
        self.current = -batch_size
        self.batch_size = batch_size
        
    def __get_batch_input(self, indices):
        source, target_input, target_target = [], [], []
        
        # padding length of sentence
        source_max_len = max(len(self.source_train[i]) for i in indices)
        target_max_len = max(len(self.target_train[i]) for i in indices)
        
        for i in indices:
            length = len(self.source_train[i])
            # reverse_source_sentences and pad at beginning
            sentence = [self.source_pad for _ in range(source_max_len - length)] + [self.source_end] + self.source_train[i][::-1] + [self.source_start]
            source.append(sentence)
            
            length = len(self.target_train[i])
            # padding at end for target
            sentence = [self.target_start] + self.target_train[i] + [self.target_end] + [self.target_pad for _ in range(target_max_len - length)]
            target_input.append(sentence)
            #removed <sos> and put <pad> at end
            target_target.append(sentence[1:] + [self.target_pad])
            
        return np.array(source), np.array(target_input), np.array(target_target)
    
    def get_batch_input(self):
        if self.current > len(self.indices) - self.batch_size:
            self.current = 0
            return None, None, None
        self.current += self.batch_size
        return self.__get_batch_input(self.indices[self.current: self.current + self.batch_size])
    
    def convert_indices_to_words(self, indices):
        output = []
        for sentence in indices:
            s = []
            for word in sentence:
                s.append(self.target_vocab_inv[word])
            output.append(s)
        return output


# ```
# %run seq2seq.ipynb
# 
# d = Dataset(source_files, target_files, 10)
# m = Seq2Seq(d.len_source, d.len_target, 9, 7)
# m.cuda()
# 
# a, b = d.get_batch_input()
# source, target = torch.cuda.LongTensor(a), torch.cuda.LongTensor(b)
# 
# # For teacher forcing:
# m(source, target)
# 
# # Using model's own predictions:
# m(source)
# ```

# In[37]:


def train(model, dataset, coverage=False, coverage_type="linguistic", iterations=1, use_teacher_forcing=True, log=True):
    # TODO: attention error
    loss_func = nn.NLLLoss()
    attn_loss_func = nn.MSELoss()
    
    optimizer = optim.Adagrad(model.parameters()) 
    
    for i in range(iterations):
        while True:
            optimizer.zero_grad() #set the gradients to zero before starting to do backpropragation because PyTorch accumulates the gradients on subsequent backward passes.
            source, target_input, target_output = d.get_batch_input() #sentences made into indices and padded to sentence lenght 

            if source is None: # end of current iteration
                break

            source, target_input, target_output = [torch.cuda.LongTensor(source), 
                                                   torch.cuda.LongTensor(target_input), 
                                                   torch.cuda.LongTensor(target_output)]
            
            source_mask = torch.ones(source.shape).cuda()
            source_mask[source == dataset.source_pad] = 0
            
            if use_teacher_forcing:
                pred, attn = model(source, target_input, source_mask=source_mask)
                # mask whatevers after <stop> 
                target_mask = torch.ones(target_output.shape).cuda()
                target_mask[target_output == dataset.target_pad] = 0
                pred = pred * target_mask.unsqueeze(-1)
                target_output = target_output * target_mask.long()
            else:
                pred, attn_weights = model(source)
                
            no_words = pred.shape[0] * pred.shape[1]
            pred = pred.reshape(no_words, -1)
            target_output = target_output.reshape(no_words)

            pred_error = loss_func(pred, target_output)
            attn_error = None
            
            if coverage:
                # if coverage type is linguistic, ignore fertility
                attn_weights, fertility = attn
                if coverage_type == "linguistic":
                    fertility = torch.ones(fertility.shape).cuda()
                attn_error = attn_loss_func(torch.sum(attn_weights, dim=-1) * source_mask, fertility * source_mask)
                pred_error += attn_error
                
            pred_error.backward() #backward prop
            optimizer.step()
            
            if log:
                print(d.current/d.batch_size, pred_error, end='\r')


# In[38]:


def convert_pred_to_indices(pred):
    return torch.max(pred, dim=-1)[1]


# In[39]:


def eval(model, dataset, log=False, source_test=None, target_test=None):
    scores = []
    if source_test is None:
        source_test = dataset.source_test
        target_test = dataset.target_test
        
    for sentence, target in zip(source_test, target_test):
        input = torch.cuda.LongTensor([[dataset.source_end] + sentence[::-1] + [dataset.source_start]])
        pred, _ = model(input)
        pred_words = convert_pred_to_indices(pred).cpu().numpy()
        predicted_target = dataset.convert_indices_to_words(pred_words)
        target = dataset.convert_indices_to_words([target])
        if log:
            print(target, predicted_target[0])
        scores.append(sentence_bleu(target, predicted_target[0], weights=(1, 0, 0, 0)))
    return sum(scores)/len(scores)
# Out:
# ['data/dev.en', 'data/test.en', 'data/train.en']

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import numpy as np


# In[2]:


import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as f


# In[3]:


class Encoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.encoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        
    def forward(self, input):
        '''
        input dim => 2d no_sentences * no_words
        make sure that the input is in reverse
        
        Outputs:
        output, h, c
        
        output => dim: (num_sentences * num_words * hidden_dim)
        h => (num_layers * num_sentences * hidden_dim)
        c => (num_layers * num_sentences * hidden_dim)
        '''
        embeddings = self.embedding(input)
        output, (h, c) = self.encoder(embeddings)
        
        return output, h, c


# In[4]:


class Decoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0, start_dim=1):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.decoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        self.word_predictor = nn.Linear(hidden_dim, num_embeddings)
        self.start_dim = start_dim
        
    def forward(self, output, h, c, input=None, max_sen_len=20):
        '''
        Output:
        pred: (no_sentences * no_words * no_embeddings)
        **Note: if input is not None, log_softmax is returned
        else, input is returned without softmax**
        '''
        
        if input is not None: # training with teacher forcing
            
            embeddings = self.embedding(input)
            yts, _ = self.decoder(embeddings, (h, c))
            orig_shape = yts.shape
            pred = self.word_predictor(yts.reshape(orig_shape[0]*orig_shape[1], -1)).reshape(*orig_shape[:-1], -1)
            return torch.log_softmax(pred, dim=-1), None
        
        else: # training using the decoders' own predictions
            
            num_sentences = output.shape[0]
            words_selected = torch.cuda.LongTensor([[self.start_dim] for _ in range(num_sentences)])
            pred = []
            for i in range(max_sen_len):
                embeddings = self.embedding(words_selected)
                y_t, (h, c) = self.decoder(embeddings, (h, c))
                orig_shape = y_t.shape
                pred_t = self.word_predictor(y_t.reshape(orig_shape[0]*orig_shape[1], 
                                                         -1)).reshape(*orig_shape[:-1], -1).squeeze(1)
                pred.append(pred_t)
                words_selected = torch.max(pred_t, dim=1)[1].unsqueeze(1)
            
            pred = torch.stack(pred, dim=1)
            return torch.log_softmax(pred, dim=-1), None


# In[5]:


class Seq2Seq(nn.Module):
    def __init__(self, source_vocab_len, target_vocab_len, embedding_dim, hidden_dim, num_layers=1,
                       padding_dim_source=0, start_dim_target=1, padding_dim_target=0):
        super().__init__()
        self.encoder = Encoder(source_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_source)
        self.decoder = Decoder(target_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_target, start_dim_target)
        
    def forward(self, source_input, target_input=None, source_mask=None):
        output, h, c = self.encoder(source_input)
        return self.decoder(output, h, c, target_input)


# **Without teacher forcing**
# ```
# input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s = Seq2Seq(10, 12, 9, 7)
# s.cuda()
# pred = s(input)
# ```

# **With teacher forcing**
# 
# ```
# tar_input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s(input, tar_input).shape
# ```

# In[ ]:

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cpu

# %%
#!/usr/bin/env python
# coding: utf-8

# In[30]:


# get_ipython().run_line_magic('run', 'utils.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq_with_attention.ipynb')
# get_ipython().run_line_magic('run', 'effective_approaches.ipynb')
# get_ipython().run_line_magic('run', 'coverage.ipynb')


# In[4]:

# device = 'cuda' if torch.cuda.is_available() else 'cpu'
# m.to(device)
torch.cuda.set_device(0)
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# In[24]:


d = Dataset(source_files, target_files, batch_size=10)
embedding_dim = 50
hidden_dim = 100
num_layers = 2


# In[25]:


def train_and_save(m, d, str_, coverage=False, coverage_type="linguistic", log=False):
    prev_score = -1
    for i in range(20):
        train(m, d, coverage, coverage_type, log=log)
        score = eval(m, d)
        best_state = None
        print()
        print(score)
        if score > prev_score:
            #torch.save(m.state_dict(), str_ + str(score)[:4] + ".params_")
            best_state = m.state_dict()
            prev_score = score
            
    torch.save(best_state, str_ + str(prev_score)[:4] + ".params")
    print(prev_score)


# In[26]:

m = Seq2Seq(d.len_source, d.len_target, embedding_dim, hidden_dim, num_layers=2, 
            padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
#print(m.cuda())
train_and_save(m, d, "seq2seq_")


# In[ ]:


# m = Seq2SeqWithAttention(d.len_source, d.len_target, embedding_dim, hidden_dim, num_layers=2, 
#             padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
# print(m.cuda())
# train_and_save(m, d, "attention_")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-2817b5358971> in <module>()
#      16 # device = 'cuda' if torch.cuda.is_available() else 'cpu'
#      17 # m.to(device)
# ---> 18 torch.cuda.set_device(0)
#      19 # device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#      20
#
# /usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py in set_device(device)
#     279     device = _get_device_index(device)
#     280     if device >= 0:
# --> 281         torch._C._cuda_setDevice(device)
#     282
#     283
#
# /usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     188             raise AssertionError(
#     189                 "libcudart functions unavailable. It looks like you have a broken build?")
# --> 190         torch._C._cuda_init()
#     191         # Some of the queued calls may reentrantly call _lazy_init();
#     192         # we need to just return without initializing in that case.
#
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47

# %% [markdown]
# #utils

# %%
data_folder = "data"
files = os.listdir(data_folder)
source_files = [os.path.join(data_folder, file) for file in files if ".en" in file]
target_files = [os.path.join(data_folder, file) for file in files if ".hi" in file]
#print(source_files)

def generate_vocab(filenames):
    vocab = set()
    no_words = 0
    for file in filenames:
        content = open(file).read()
        sentences = [sentence.split() for sentence in content.split('\n')]
        for sentence in sentences:
            for word in sentence:
                if word.lower() not in vocab:
                    vocab.add(word.lower())
                    no_words += 1
    vocab = {word: num for num, word in enumerate(vocab)}
    return vocab

def parse_files_to_indices(filename, vocab):
    content = open(filename).read()
    return [[vocab[word] for word in sentence.split() if word in vocab] for sentence in content.split('\n')]

class Dataset:
    def __init__(self, source_files, target_files, batch_size=10):
        self.source_vocab = generate_vocab(source_files)
        self.target_vocab = generate_vocab(target_files)
        
        self.len_source = len(self.source_vocab.keys())
        self.source_pad, self.source_start, self.source_end = self.len_source + 2, self.len_source + 1, self.len_source
        self.len_target = len(self.target_vocab.keys())
        self.target_pad, self.target_start, self.target_end = self.len_target + 2, self.len_target + 1, self.len_target
        
        self.source_vocab['<pad>'], self.source_vocab['<start>'], self.source_vocab['<end>'] = [self.source_pad, 
                                                                                                self.source_start, 
                                                                                                self.source_end]
        self.target_vocab['<pad>'], self.target_vocab['<start>'], self.target_vocab['<end>'] = [self.target_pad,
                                                                                                self.target_start, 
                                                                                                self.target_end]
        self.len_source = len(self.source_vocab.keys())
        self.len_target = len(self.target_vocab.keys())
        
        self.source_vocab_inv = {value:key for key, value in self.source_vocab.items()}
        self.target_vocab_inv = {value:key for key, value in self.target_vocab.items()}


        for filename in source_files:
            if 'train' in filename:
                self.source_train = parse_files_to_indices(filename, self.source_vocab)
            if 'test' in filename:
                self.source_test = parse_files_to_indices(filename, self.source_vocab)
            if 'dev' in filename:
                self.source_dev = parse_files_to_indices(filename, self.source_vocab)
                
        for filename in target_files:
            if 'train' in filename:
                self.target_train = parse_files_to_indices(filename, self.target_vocab)
            if 'test' in filename:
                self.target_test = parse_files_to_indices(filename, self.target_vocab)
            if 'dev' in filename:
                self.target_dev = parse_files_to_indices(filename, self.target_vocab)
                
            
        self.indices = list(range(len(self.source_train)))
        random.shuffle(self.indices)
        self.current = -batch_size
        self.batch_size = batch_size
        
    def __get_batch_input(self, indices):
        source, target_input, target_target = [], [], []
        
        # padding length
        source_max_len = max(len(self.source_train[i]) for i in indices)
        target_max_len = max(len(self.target_train[i]) for i in indices)
        
        for i in indices:
            length = len(self.source_train[i])
            # reverse_source_sentences and pad at beginning
            sentence = [self.source_pad for _ in range(source_max_len - length)] + [self.source_end] + self.source_train[i][::-1] + [self.source_start]
            source.append(sentence)
            
            length = len(self.target_train[i])
            # padding at end for target
            sentence = [self.target_start] + self.target_train[i] + [self.target_end] + [self.target_pad for _ in range(target_max_len - length)]
            target_input.append(sentence)
            target_target.append(sentence[1:] + [self.target_pad])
            
        return np.array(source), np.array(target_input), np.array(target_target)
    
    def get_batch_input(self):
        if self.current > len(self.indices) - self.batch_size:
            self.current = 0
            return None, None, None
        self.current += self.batch_size
        return self.__get_batch_input(self.indices[self.current: self.current + self.batch_size])
    
    def convert_indices_to_words(self, indices):
        output = []
        for sentence in indices:
            s = []
            for word in sentence:
                s.append(self.target_vocab_inv[word])
            output.append(s)
        return output


# ```
# %run seq2seq.ipynb
# 
# d = Dataset(source_files, target_files, 10)
# m = Seq2Seq(d.len_source, d.len_target, 9, 7)
# m.cuda()
# 
# a, b = d.get_batch_input()
# source, target = torch.cuda.LongTensor(a), torch.cuda.LongTensor(b)
# 
# # For teacher forcing:
# m(source, target)
# 
# # Using model's own predictions:
# m(source)
# ```

# In[37]:


def train(model, dataset, coverage=False, coverage_type="linguistic", iterations=1, use_teacher_forcing=False, log=True):
    # TODO: attention error
    loss_func = nn.NLLLoss()
    attn_loss_func = nn.MSELoss()
    
    optimizer = optim.Adagrad(model.parameters())
    
    for i in range(iterations):
        while True:
            optimizer.zero_grad()
            source, target_input, target_output = d.get_batch_input()

            if source is None: # end of current iteration
                break

            source, target_input, target_output = [torch.cuda.LongTensor(source), 
                                                   torch.cuda.LongTensor(target_input), 
                                                   torch.cuda.LongTensor(target_output)]
            
            source_mask = torch.ones(source.shape).cuda()
            source_mask[source == dataset.source_pad] = 0
            
            if use_teacher_forcing:
                pred, attn = model(source, target_input, source_mask=source_mask)
                # mask whatevers after <stop> 
                target_mask = torch.ones(target_output.shape).cuda()
                target_mask[target_output == dataset.target_pad] = 0
                pred = pred * target_mask.unsqueeze(-1)
                target_output = target_output * target_mask.long()
            else:
                pred, attn_weights = model(source.cuda())
                
            no_words = pred.shape[0] * pred.shape[1]
            pred = pred.reshape(no_words, -1)
            target_output = target_output.reshape(no_words)

            pred_error = loss_func(pred, target_output)
            attn_error = None
            
            if coverage:
                # if coverage type is linguistic, ignore fertility
                attn_weights, fertility = attn
                if coverage_type == "linguistic":
                    fertility = torch.ones(fertility.shape).cuda()
                attn_error = attn_loss_func(torch.sum(attn_weights, dim=-1) * source_mask, fertility * source_mask)
                pred_error += attn_error
                
            pred_error.backward()
            optimizer.step()
            
            if log:
                print(d.current/d.batch_size, pred_error, end='\r')


# In[38]:


def convert_pred_to_indices(pred):
    return torch.max(pred, dim=-1)[1]


# In[39]:


def eval(model, dataset, log=False, source_test=None, target_test=None):
    scores = []
    if source_test is None:
        source_test = dataset.source_test
        target_test = dataset.target_test
        
    for sentence, target in zip(source_test, target_test):
        input = torch.cuda.LongTensor([[dataset.source_end] + sentence[::-1] + [dataset.source_start]])
        pred, _ = model(input)
        pred_words = convert_pred_to_indices(pred).cpu().numpy()
        predicted_target = dataset.convert_indices_to_words(pred_words)
        target = dataset.convert_indices_to_words([target])
        if log:
            print(target, predicted_target[0])
        scores.append(sentence_bleu(target, predicted_target[0], weights=(1, 0, 0, 0)))
    return sum(scores)/len(scores)


# In[ ]:





# In[ ]:

# %% [markdown]
# #seq2seq

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as f

class Encoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.encoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        
    def forward(self, input):
        '''
        input dim => 2d no_sentences * no_words
        make sure that the input is in reverse
        
        Outputs:
        output, h, c
        
        output => dim: (num_sentences * num_words * hidden_dim)
        h => (num_layers * num_sentences * hidden_dim)
        c => (num_layers * num_sentences * hidden_dim)
        '''
        embeddings = self.embedding(input)
        output, (h, c) = self.encoder(embeddings)
        
        return output, h, c

class Decoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0, start_dim=1):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.decoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        self.word_predictor = nn.Linear(hidden_dim, num_embeddings)
        self.start_dim = start_dim
        
    def forward(self, output, h, c, input=None, max_sen_len=20):
        '''
        Output:
        pred: (no_sentences * no_words * no_embeddings)
        **Note: if input is not None, log_softmax is returned
        else, input is returned without softmax**
        '''
        
        if input is not None: # training with teacher forcing
            
            embeddings = self.embedding(input)
            yts, _ = self.decoder(embeddings, (h, c))
            orig_shape = yts.shape
            pred = self.word_predictor(yts.reshape(orig_shape[0]*orig_shape[1], -1)).reshape(*orig_shape[:-1], -1)
            return torch.log_softmax(pred, dim=-1), None
        
        else: # training using the decoders' own predictions
            
            num_sentences = output.shape[0]
            words_selected = torch.cuda.LongTensor([[self.start_dim] for _ in range(num_sentences)])
            pred = []
            for i in range(max_sen_len):
                embeddings = self.embedding(words_selected)
                y_t, (h, c) = self.decoder(embeddings, (h, c))
                orig_shape = y_t.shape
                pred_t = self.word_predictor(y_t.reshape(orig_shape[0]*orig_shape[1], 
                                                         -1)).reshape(*orig_shape[:-1], -1).squeeze(1)
                pred.append(pred_t)
                words_selected = torch.max(pred_t, dim=1)[1].unsqueeze(1)
            
            pred = torch.stack(pred, dim=1)
            return torch.log_softmax(pred, dim=-1), None


# In[5]:


class Seq2Seq(nn.Module):
    def __init__(self, source_vocab_len, target_vocab_len, embedding_dim, hidden_dim, num_layers=1,
                       padding_dim_source=0, start_dim_target=1, padding_dim_target=0):
        super().__init__()
        self.encoder = Encoder(source_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_source)
        self.decoder = Decoder(target_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_target, start_dim_target)
        
    def forward(self, source_input, target_input=None, source_mask=None):
        output, h, c = self.encoder(source_input)
        return self.decoder(output, h, c, target_input)


# **Without teacher forcing**
# ```
# input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s = Seq2Seq(10, 12, 9, 7)
# s.cuda()
# pred = s(input)
# ```

# **With teacher forcing**
# 
# ```
# tar_input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s(input, tar_input).shape
# ```

# In[ ]:

# %% [markdown]
# #seg2seq - attention

# %%
#!/usr/bin/env python
# coding: utf-8

# In[5]:


# get_ipython().run_line_magic('run', 'seq2seq.ipynb')


# In[2]:


class Attention(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.layer1 = nn.Linear(dim * 2, dim)
        self.layer2 = nn.Linear(dim, 1)
        
    def forward(self, source_h, target_h, source_mask=None):
        
        num_sentences, num_words = source_h.shape[:-1]
        target_h = target_h.repeat(1, num_words).reshape(num_words * num_sentences, -1)
        mlp_input = torch.cat((target_h, source_h.reshape(num_words * num_sentences, -1)
                              ), dim=1).reshape(num_words * num_sentences, -1)
        
        h1 = torch.tanh(self.layer1(mlp_input))
        h2 = self.layer2(h1)
        
        raw_weights = h2.reshape(num_sentences, num_words)
        
        if source_mask is not None:
            raw_weights = source_mask * raw_weights
        weights = torch.softmax(f.relu(raw_weights), dim=1)
        
        return torch.sum(weights.unsqueeze(-1) * source_h, dim=1)


# ```
# source_h = torch.Tensor(np.random.randint(0, 10, (2, 4, 10)))
# target_h = torch.Tensor(np.random.randint(0, 10, (2, 10)))
# a = Attention(10)
# a(source_h, target_h)
# ```

# In[11]:


class DecoderAttention(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0, start_dim=1):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.decoder = nn.LSTM(embedding_dim + hidden_dim, hidden_dim, num_layers, batch_first=True)
        self.word_predictor = nn.Linear(hidden_dim, num_embeddings)
        self.start_dim = start_dim
        
        self.attention = Attention(hidden_dim)
        
    def forward(self, output, h, c, input=None, max_sen_len=20, source_mask=None):
        
        source_h = output
        num_sentences, num_words, hidden_dim = output.shape
        words_selected = torch.cuda.LongTensor([[self.start_dim] for _ in range(num_sentences)])

        decoder_context = torch.zeros(num_sentences, hidden_dim).cuda()
        pred = []
        
        if input is not None:
            max_sen_len = input.shape[1]
            teacher_words = input.t()
        
        for i in range(max_sen_len):
            embeddings = self.embedding(words_selected)
            decoder_input = torch.cat((embeddings, decoder_context.unsqueeze(1)), dim=-1)
            y_t, (h, c) = self.decoder(decoder_input, (h, c))
            orig_shape = y_t.shape
            pred_t = self.word_predictor(y_t.reshape(orig_shape[0]*orig_shape[1], 
                                                     -1)).reshape(*orig_shape[:-1], -1).squeeze(1)
            pred.append(pred_t)
            decoder_context = self.attention(source_h, h[-1], source_mask)
            
            if input is None:
                words_selected = torch.max(pred_t, dim=1)[1].unsqueeze(1)
            else:
                words_selected = teacher_words[i].unsqueeze(1)


        pred = torch.stack(pred, dim=1)
        return torch.log_softmax(pred, dim=-1), None


# In[28]:


class Seq2SeqWithAttention(nn.Module):
    def __init__(self, source_vocab_len, target_vocab_len, embedding_dim, hidden_dim, num_layers=1,
                       padding_dim_source=0, start_dim_target=1, padding_dim_target=0):
        super().__init__()
        self.encoder = Encoder(source_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_source)
        self.decoder = DecoderAttention(target_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_target, start_dim_target)
        
    def forward(self, source_input, target_input=None, source_mask=None):
        output, h, c = self.encoder(source_input)
        return self.decoder(output, h, c, target_input, source_mask=source_mask)


# ```
# s = Seq2SeqWithAttention(10, 12, 9, 8)
# s.cuda()
# input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# target = torch.cuda.LongTensor(np.random.randint(0, 12, (3, 10))
# 
# # without teacher forcing
# s(input)
# 
# # with teacher forcing
# ```
# Out:
# ERROR:root:File `'seq2seq.ipynb.py'` not found.

# %% [markdown]
# #train&test

# %%
#!/usr/bin/env python
# coding: utf-8

# In[30]:


# get_ipython().run_line_magic('run', 'utils.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq_with_attention.ipynb')
# get_ipython().run_line_magic('run', 'effective_approaches.ipynb')
# get_ipython().run_line_magic('run', 'coverage.ipynb')


# In[4]:


torch.cuda.set_device(0)

# In[24]:


d = Dataset(source_files, target_files, batch_size=10)
embedding_dim = 50
hidden_dim = 100
num_layers = 2


# In[25]:


def train_and_save(m, d, str_, coverage=False, coverage_type="linguistic", log=False):
    prev_score = -1
    for i in range(20):
        train(m, d, coverage, coverage_type, log=log).cuda()
        score = eval(m, d)
        best_state = None
        print()
        print(score)
        if score > prev_score:
            #torch.save(m.state_dict(), str_ + str(score)[:4] + ".params_")
            best_state = m.state_dict()
            prev_score = score
            
    torch.save(best_state, str_ + str(prev_score)[:4] + ".params")
    print(prev_score)


# In[26]:


m = Seq2Seq(d.len_source, d.len_target, embedding_dim, hidden_dim, num_layers=2, 
            padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
#print(m.cuda())
train_and_save(m, d, "seq2seq_")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-2805b0465dfc> in <module>()
#      52             padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
#      53 #print(m.cuda())
# ---> 54 train_and_save(m, d, "seq2seq_")
#
# <ipython-input-14-2805b0465dfc> in train_and_save(m, d, str_, coverage, coverage_type, log)
#      32     prev_score = -1
#      33     for i in range(20):
# ---> 34         train(m, d, coverage, coverage_type, log=log)
#      35         score = eval(m, d)
#      36         best_state = None
#
# <ipython-input-12-ac4886a94d35> in train(model, dataset, coverage, coverage_type, iterations, use_teacher_forcing, log)
#     156                 target_output = target_output * target_mask.long()
#     157             else:
# --> 158                 pred, attn_weights = model(source.cuda())
#     159
#     160             no_words = pred.shape[0] * pred.shape[1]
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# <ipython-input-13-9c6481183ac7> in forward(self, source_input, target_input, source_mask)
#      81
#      82     def forward(self, source_input, target_input=None, source_mask=None):
# ---> 83         output, h, c = self.encoder(source_input)
#      84         return self.decoder(output, h, c, target_input)
#      85
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# <ipython-input-13-9c6481183ac7> in forward(self, input)
#      23         c => (num_layers * num_sentences * hidden_dim)
#      24         '''
# ---> 25         embeddings = self.embedding(input)
#      26         output, (h, c) = self.encoder(embeddings)
#      27
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/sparse.py in forward(self, input)
#     124         return F.embedding(
#     125             input, self.weight, self.padding_idx, self.max_norm,
# --> 126             self.norm_type, self.scale_grad_by_freq, self.sparse)
#     127
#     128     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    1812         # remove once script supports set_grad_enabled
#    1813         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 1814     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    1815
#    1816
#
# RuntimeError: Expected object of device type cuda but got device type cpu for argument #1 'self' in call to _th_index_select
