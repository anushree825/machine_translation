# %%
# %autosave 10
# Out:
# Autosaving every 10 seconds

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import random
import numpy as np
import re
import string
from string import digits
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
from nltk.translate.bleu_score import sentence_bleu

# %%
os.chdir("/content/drive/My Drive/NeuralMT")
os.listdir()
# Out:
# ['en_hi.pkl',
#  'data',
#  'cc.en.300.vec.gz',
#  'cc.hi.300.vec.gz',
#  'seq2seq_0.02.params',
#  'seq2seq_0.01.params',
#  'seq2seq_0.04.params',
#  'seq2seq_0.0.params',
#  'seq2seq_0.19.params',
#  'seq2seq_0.25.params',
#  'seq2seq_0.24.params',
#  'seq2seq_0.31.params',
#  'seq2seq_0.23.params',
#  'seq2seq_0.11.params',
#  'data_small']

# %% [markdown]
# #try cuda

# %%
data_folder = "data"
files = os.listdir(data_folder)
source_files = [os.path.join(data_folder, file) for file in files if ".en" in file]
target_files = [os.path.join(data_folder, file) for file in files if ".hi" in file]
print(source_files)

def generate_vocab(filenames):
    vocab = set()
    # no_words = 0
    for file in filenames:
        content = open(file).read()
        sentences = [sentence.split() for sentence in content.split('\n')]
        for sentence in sentences:
            for word in sentence:
                if word.lower() not in vocab:
                    vocab.add(word.lower())
                    # no_words += 1
    vocab = {word: num for num, word in enumerate(vocab)}
    return vocab

def parse_files_to_indices(filename, vocab):
    content = open(filename).read()
    return [[vocab[word] for word in sentence.split() if word in vocab] for sentence in content.split('\n')]

class Dataset:
    def __init__(self, source_files, target_files, batch_size=10):
        self.source_vocab = generate_vocab(source_files) #for entire lang
        self.target_vocab = generate_vocab(target_files) #for entire lang
        
        self.len_source = len(self.source_vocab.keys())
        self.source_pad, self.source_start, self.source_end = self.len_source + 2, self.len_source + 1, self.len_source
        self.len_target = len(self.target_vocab.keys())
        self.target_pad, self.target_start, self.target_end = self.len_target + 2, self.len_target + 1, self.len_target
        
        self.source_vocab['<pad>'], self.source_vocab['<start>'], self.source_vocab['<end>'] = [self.source_pad, 
                                                                                                self.source_start, 
                                                                                                self.source_end]
        self.target_vocab['<pad>'], self.target_vocab['<start>'], self.target_vocab['<end>'] = [self.target_pad,
                                                                                                self.target_start, 
                                                                                                self.target_end]
                                                                                              
        ##created indices for <pad>, <start> and <end> tokens
        self.len_source = len(self.source_vocab.keys())
        self.len_target = len(self.target_vocab.keys())
        
        ##inverse vocab for entire lang
        self.source_vocab_inv = {value:key for key, value in self.source_vocab.items()}
        self.target_vocab_inv = {value:key for key, value in self.target_vocab.items()}
        
        ##parsing files into indices
        for filename in source_files:
            if 'train' in filename:
                self.source_train = parse_files_to_indices(filename, self.source_vocab)
            if 'test' in filename:
                self.source_test = parse_files_to_indices(filename, self.source_vocab)
            if 'dev' in filename:
                self.source_dev = parse_files_to_indices(filename, self.source_vocab)
                
        for filename in target_files:
            if 'train' in filename:
                self.target_train = parse_files_to_indices(filename, self.target_vocab)
            if 'test' in filename:
                self.target_test = parse_files_to_indices(filename, self.target_vocab)
            if 'dev' in filename:
                self.target_dev = parse_files_to_indices(filename, self.target_vocab)
                
        ##random shuffling of training data before splitting into batches    
        self.indices = list(range(len(self.source_train)))
        random.shuffle(self.indices)
        self.current = -batch_size
        self.batch_size = batch_size
        
    def __get_batch_input(self, indices):
        source, target_input, target_target = [], [], []
        
        # padding length of sentence
        source_max_len = max(len(self.source_train[i]) for i in indices)
        target_max_len = max(len(self.target_train[i]) for i in indices)
        
        for i in indices:
            length = len(self.source_train[i])
            # reverse_source_sentences and pad at beginning
            sentence = [self.source_pad for _ in range(source_max_len - length)] + [self.source_end] + self.source_train[i][::-1] + [self.source_start]
            source.append(sentence)
            
            length = len(self.target_train[i])
            # padding at end for target
            sentence = [self.target_start] + self.target_train[i] + [self.target_end] + [self.target_pad for _ in range(target_max_len - length)]
            target_input.append(sentence)
            #removed <sos> and put <pad> at end
            target_target.append(sentence[1:] + [self.target_pad])
            
        return np.array(source), np.array(target_input), np.array(target_target)
    
    def get_batch_input(self):
        if self.current > len(self.indices) - self.batch_size:
            self.current = 0
            return None, None, None
        self.current += self.batch_size
        return self.__get_batch_input(self.indices[self.current: self.current + self.batch_size])
    
    def convert_indices_to_words(self, indices):
        output = []
        for sentence in indices:
            s = []
            for word in sentence:
                s.append(self.target_vocab_inv[word])
            output.append(s)
        return output


# ```
# %run seq2seq.ipynb
# 
# d = Dataset(source_files, target_files, 10)
# m = Seq2Seq(d.len_source, d.len_target, 9, 7)
# m.cuda()
# 
# a, b = d.get_batch_input()
# source, target = torch.cuda.LongTensor(a), torch.cuda.LongTensor(b)
# 
# # For teacher forcing:
# m(source, target)
# 
# # Using model's own predictions:
# m(source)
# ```

# In[37]:


def train(model, dataset, coverage=False, coverage_type="linguistic", iterations=1, use_teacher_forcing=True, log=True):
    # TODO: attention error
    loss_func = nn.NLLLoss()
    attn_loss_func = nn.MSELoss()
    
    optimizer = optim.Adagrad(model.parameters()) 
    
    for i in range(iterations):
        while True:
            optimizer.zero_grad() #set the gradients to zero before starting to do backpropragation because PyTorch accumulates the gradients on subsequent backward passes.
            source, target_input, target_output = d.get_batch_input() #sentences made into indices and padded to sentence lenght 

            if source is None: # end of current iteration
                break

            source, target_input, target_output = [torch.LongTensor(source), 
                                                   torch.LongTensor(target_input).cuda, 
                                                   torch.LongTensor(target_output).cuda]
            
            source_mask = torch.ones(source.shape).cuda()
            source_mask[source == dataset.source_pad] = 0
            
            if use_teacher_forcing:
                pred, attn = model(source, target_input, source_mask=source_mask)
                # mask whatevers after <stop> 
                target_mask = torch.ones(target_output.shape).cuda()
                target_mask[target_output == dataset.target_pad] = 0
                pred = pred * target_mask.unsqueeze(-1)
                target_output = target_output * target_mask.long()
            else:
                pred, attn_weights = model(source)
                
            no_words = pred.shape[0] * pred.shape[1]
            pred = pred.reshape(no_words, -1)
            target_output = target_output.reshape(no_words)

            pred_error = loss_func(pred, target_output)
            attn_error = None
            
            if coverage:
                # if coverage type is linguistic, ignore fertility
                attn_weights, fertility = attn
                if coverage_type == "linguistic":
                    fertility = torch.ones(fertility.shape).cuda()
                attn_error = attn_loss_func(torch.sum(attn_weights, dim=-1) * source_mask, fertility * source_mask)
                pred_error += attn_error
                
            pred_error.backward() #backward prop
            optimizer.step()
            
            if log:
                print(d.current/d.batch_size, pred_error, end='\r')


# In[38]:


def convert_pred_to_indices(pred):
    return torch.max(pred, dim=-1)[1]


# In[39]:


def eval(model, dataset, log=False, source_test=None, target_test=None):
    scores = []
    if source_test is None:
        source_test = dataset.source_test
        target_test = dataset.target_test
        
    for sentence, target in zip(source_test, target_test):
        input = torch.LongTensor([[dataset.source_end] + sentence[::-1] + [dataset.source_start]]).cuda
        pred, _ = model(input).cuda()
        pred_words = convert_pred_to_indices(pred).cpu().numpy()
        predicted_target = dataset.convert_indices_to_words(pred_words)
        target = dataset.convert_indices_to_words([target])
        if log:
            print(target, predicted_target[0])
        scores.append(sentence_bleu(target, predicted_target[0], weights=(1, 0, 0, 0)))
    return sum(scores)/len(scores)
# Out:
# ['data/dev.en', 'data/test.en', 'data/train.en']

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import numpy as np


# In[2]:


import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as f


# In[3]:


class Encoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.encoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        
    def forward(self, input):
        '''
        input dim => 2d no_sentences * no_words
        make sure that the input is in reverse
        
        Outputs:
        output, h, c
        
        output => dim: (num_sentences * num_words * hidden_dim)
        h => (num_layers * num_sentences * hidden_dim)
        c => (num_layers * num_sentences * hidden_dim)
        '''
        embeddings = self.embedding(input)
        output, (h, c) = self.encoder(embeddings)
        
        return output, h, c


# In[4]:


class Decoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0, start_dim=1):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.decoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        self.word_predictor = nn.Linear(hidden_dim, num_embeddings)
        self.start_dim = start_dim
        
    def forward(self, output, h, c, input=None, max_sen_len=20):
        '''
        Output:
        pred: (no_sentences * no_words * no_embeddings)
        **Note: if input is not None, log_softmax is returned
        else, input is returned without softmax**
        '''
        
        if input is not None: # training with teacher forcing
            
            embeddings = self.embedding(input)
            yts, _ = self.decoder(embeddings, (h, c))
            orig_shape = yts.shape
            pred = self.word_predictor(yts.reshape(orig_shape[0]*orig_shape[1], -1)).reshape(*orig_shape[:-1], -1)
            return torch.log_softmax(pred, dim=-1), None
        
        else: # training using the decoders' own predictions
            
            num_sentences = output.shape[0]
            words_selected = torch.LongTensor([[self.start_dim] for _ in range(num_sentences)]).cuda
            pred = []
            for i in range(max_sen_len):
                embeddings = self.embedding(words_selected)
                y_t, (h, c) = self.decoder(embeddings, (h, c))
                orig_shape = y_t.shape
                pred_t = self.word_predictor(y_t.reshape(orig_shape[0]*orig_shape[1], 
                                                         -1)).reshape(*orig_shape[:-1], -1).squeeze(1)
                pred.append(pred_t)
                words_selected = torch.max(pred_t, dim=1)[1].unsqueeze(1)
            
            pred = torch.stack(pred, dim=1)
            return torch.log_softmax(pred, dim=-1), None


# In[5]:


class Seq2Seq(nn.Module):
    def __init__(self, source_vocab_len, target_vocab_len, embedding_dim, hidden_dim, num_layers=1,
                       padding_dim_source=0, start_dim_target=1, padding_dim_target=0):
        super().__init__()
        self.encoder = Encoder(source_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_source)
        self.decoder = Decoder(target_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_target, start_dim_target)
        
    def forward(self, source_input, target_input=None, source_mask=None):
        output, h, c = self.encoder(source_input)
        return self.decoder(output, h, c, target_input)


# **Without teacher forcing**
# ```
# input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s = Seq2Seq(10, 12, 9, 7)
# s.cuda()
# pred = s(input)
# ```

# **With teacher forcing**
# 
# ```
# tar_input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s(input, tar_input).shape
# ```

# In[ ]:

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cuda:0

# %%
#!/usr/bin/env python
# coding: utf-8

# In[30]:


# get_ipython().run_line_magic('run', 'utils.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq_with_attention.ipynb')
# get_ipython().run_line_magic('run', 'effective_approaches.ipynb')
# get_ipython().run_line_magic('run', 'coverage.ipynb')


# In[4]:

# device = 'cuda' if torch.cuda.is_available() else 'cpu'
# m.to(device)
# torch.cuda.set_device(0)
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# In[24]:


d = Dataset(source_files, target_files, batch_size=10)
embedding_dim = 50
hidden_dim = 100
num_layers = 2


# In[25]:


def train_and_save(m, d, str_, coverage=False, coverage_type="linguistic", log=False):
    prev_score = -1
    for i in range(20):
        train(m, d, coverage, coverage_type, log=log)
        score = eval(m, d)
        best_state = None
        print()
        print(score)
        if score > prev_score:
            #torch.save(m.state_dict(), str_ + str(score)[:4] + ".params_")
            best_state = m.state_dict()
            prev_score = score
            
    torch.save(best_state, str_ + str(prev_score)[:4] + ".params")
    print(prev_score)


# In[26]:

m = Seq2Seq(d.len_source, d.len_target, embedding_dim, hidden_dim, num_layers=2, 
            padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
#print(m.cuda())
train_and_save(m, d, "seq2seq_")


# In[ ]:


# m = Seq2SeqWithAttention(d.len_source, d.len_target, embedding_dim, hidden_dim, num_layers=2, 
#             padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
# print(m.cuda())
# train_and_save(m, d, "attention_")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-a2e13d2680a4> in <module>()
#      53             padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start).cuda()
#      54 #print(m.cuda())
# ---> 55 train_and_save(m, d, "seq2seq_")
#      56
#      57
#
# <ipython-input-12-a2e13d2680a4> in train_and_save(m, d, str_, coverage, coverage_type, log)
#      34     prev_score = -1
#      35     for i in range(20):
# ---> 36         train(m, d, coverage, coverage_type, log=log)
#      37         score = eval(m, d)
#      38         best_state = None
#
# <ipython-input-10-27ac5ca06b99> in train(model, dataset, coverage, coverage_type, iterations, use_teacher_forcing, log)
#     153
#     154             if use_teacher_forcing:
# --> 155                 pred, attn = model(source, target_input, source_mask=source_mask)
#     156                 # mask whatevers after <stop>
#     157                 target_mask = torch.ones(target_output.shape).cuda()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# <ipython-input-11-640a51409340> in forward(self, source_input, target_input, source_mask)
#     100
#     101     def forward(self, source_input, target_input=None, source_mask=None):
# --> 102         output, h, c = self.encoder(source_input)
#     103         return self.decoder(output, h, c, target_input)
#     104
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# <ipython-input-11-640a51409340> in forward(self, input)
#      38         c => (num_layers * num_sentences * hidden_dim)
#      39         '''
# ---> 40         embeddings = self.embedding(input)
#      41         output, (h, c) = self.encoder(embeddings)
#      42
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/sparse.py in forward(self, input)
#     124         return F.embedding(
#     125             input, self.weight, self.padding_idx, self.max_norm,
# --> 126             self.norm_type, self.scale_grad_by_freq, self.sparse)
#     127
#     128     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    1812         # remove once script supports set_grad_enabled
#    1813         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 1814     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    1815
#    1816
#
# RuntimeError: Expected object of device type cuda but got device type cpu for argument #3 'index' in call to _th_index_select

# %% [markdown]
# #try cpu

# %%
import re
import string
from string import digits

# %%
# import pandas as pd
df = pd.read_pickle('en_hi.pkl')[:100]

# %%
df.head(20)
# Out:
#                               english                           hindi
# 57382              Who is this man?\n             -ये आदमी कौन है ?\n
# 28149        And the other brother?\n                 और दूसरे भाई?\n
# 80284  - Greetings, Mustakeen bhai.\n        नमस्ते, Mustakeen भाई।\n
# 63596     Please, reason with them.\n  कृपया, उन लोगों के साथ कारण.\n
# 9459        There's a howling gale.\n             तेज़ हवा आ रही है।\n
# 67410              - No, you don't.\n           - नहीं , कभी नहीं .\n
# 89506       the violence, the rage.\n              हिंसा, स्पूर्ति।\n
# 71637        Signal decoy in place.\n         सिग्नल जगह में लूभाव।\n
# 66488           You guys come with?\n    तुम लोग इसे ले तो आये हो ?\n
# 52809         How long you staying?\n                 तुम कब तक रह?\n
# 81442              Who is this now?\n                 अब यह कौन है?\n
# 59132       How's Rosie doing, Jim?\n     कैसे रोजी, जिम कर रहा है?\n
# 46795       100 feet radius, clear.\n     100 फुट त्रिज्या, स्पष्ट.\n
# 66121              - It's not safe.\n                 वहाँ खतरा है।\n
# 19491        TREVOR: No, no, don't.\n    नहीं, नहीं नहीं करते हैं,.\n
# 75022       Your passport is ready.\n       आपका पासपोर्ट तैयार है।\n
# 74177            Come on, let's go.\n                 चलो चलते हैं।\n
# 9285           "fruit of thy womb".\n         "तुम्हारे पेट का फल".\n
# 61090           Agh, that is tight.\n                तंग है कि आह,.\n
# 52338               - Is this wool?\n                   - यह ऊन है?\n

# %%
lines = df.copy()
# general
lines['english']=lines['english'].apply(lambda x: re.sub(r"n\'t", " not", x))
lines['english']=lines['english'].apply(lambda x: re.sub(r"\'re", " are", x))
lines['english']=lines['english'].apply(lambda x: re.sub(r"\'s", " is", x))
lines['english']=lines['english'].apply(lambda x: re.sub(r"n\'d", " would", x))
lines['english']=lines['english'].apply(lambda x: re.sub(r"n\'ll", " will", x))
lines['english']=lines['english'].apply(lambda x: re.sub(r"n\'ve", " have", x))
lines['english']=lines['english'].apply(lambda x: re.sub(r"n\'m", " am", x))

lines['hindi'] = lines['hindi'].apply(lambda x: x.replace('.',' ।'))
# lines['hindi'] = lines['hindi'].apply(lambda x: x.replace('।',' ।'))

# lines['english']=lines['english'].apply(lambda x: re.sub(r"n\in'", "ing", x))

# Lowercase all characters
lines['english']=lines['english'].apply(lambda x: x.lower())
lines['hindi']=lines['hindi'].apply(lambda x: x.lower())


exclude = set(['$','&','+',':',';','=','@','|','<','>','^','*','%','-','#','\'']) # Set of all special characters
# Remove all the special characters
lines['english']=lines['english'].apply(lambda x: ''.join(ch for ch in x if ch not in exclude))
lines['hindi']=lines['hindi'].apply(lambda x: ''.join(ch for ch in x if ch not in exclude))

# Remove all numbers from text
remove_digits = str.maketrans('', '', digits)
lines['english']=lines['english'].apply(lambda x: x.translate(remove_digits))
lines['hindi']=lines['hindi'].apply(lambda x: x.translate(remove_digits))

lines['hindi'] = lines['hindi'].apply(lambda x: re.sub("[२३०८१५७९४६]", "", x))

# Remove extra spaces
lines['english']=lines['english'].apply(lambda x: x.strip())
lines['hindi']=lines['hindi'].apply(lambda x: x.strip())
lines['english']=lines['english'].apply(lambda x: re.sub(" +", " ", x))
lines['hindi']=lines['hindi'].apply(lambda x: re.sub(" +", " ", x))

# Add start and end tokens to target sequences
lines['hindi'] = lines['hindi'].apply(lambda x :  x + '\n')

lines['english'] = lines['english'].apply(lambda x : x + '\n')
lines.head(20)
# Out:
#                             english                            hindi
# 57382            who is this man?\n               ये आदमी कौन है ?\n
# 28149      and the other brother?\n                  और दूसरे भाई?\n
# 80284  greetings, mustakeen bhai.\n         नमस्ते, mustakeen भाई।\n
# 63596   please, reason with them.\n  कृपया, उन लोगों के साथ कारण ।\n
# 9459     there is a howling gale.\n              तेज़ हवा आ रही है।\n
# 67410             no, you do not.\n              नहीं , कभी नहीं ।\n
# 89506     the violence, the rage.\n               हिंसा, स्पूर्ति।\n
# 71637      signal decoy in place.\n          सिग्नल जगह में लूभाव।\n
# 66488         you guys come with?\n     तुम लोग इसे ले तो आये हो ?\n
# 52809       how long you staying?\n                  तुम कब तक रह?\n
# 81442            who is this now?\n                  अब यह कौन है?\n
# 59132    how is rosie doing, jim?\n      कैसे रोजी, जिम कर रहा है?\n
# 46795         feet radius, clear.\n         फुट त्रिज्या, स्पष्ट ।\n
# 66121             it is not safe.\n                  वहाँ खतरा है।\n
# 19491      trevor no, no, do not.\n    नहीं, नहीं नहीं करते हैं, ।\n
# 75022     your passport is ready.\n        आपका पासपोर्ट तैयार है।\n
# 74177         come on, let is go.\n                  चलो चलते हैं।\n
# 9285         "fruit of thy womb".\n         "तुम्हारे पेट का फल" ।\n
# 61090         agh, that is tight.\n                तंग है कि आह, ।\n
# 52338               is this wool?\n                      यह ऊन है?\n

# %%
# for index,row in lines[:10].iterrows():
#   # for lan in ['english','hindi']:
  
#     ret = [re.sub(fr'([{string.punctuation}])\B', r' \1', row[lan]).split() for lan in ['english','hindi']]
#     print(ret)

# %%
train, validate, test = np.split(lines.sample(frac=1), [int(.7*len(df)), int(.8*len(df))])
print(train.shape, validate.shape, test.shape)
# Out:
# (70, 2) (10, 2) (20, 2)

# %%
# for index,row in train[:10].iterrows():
#   # for lan in ['english','hindi']:
  
#     ret = [re.sub(fr'([{string.punctuation  }])\B', r' \1', str(row)).split()]
#     print(ret)
#     print(index,row)

# %%
# with open('/content/drive/My Drive/NeuralMT/data/dev.en', 'w') as writefile:
#     writefile.write(('').join(validate['english']))
# with open('/content/drive/My Drive/NeuralMT/data/dev.hi', 'w') as writefile:
#     writefile.write(('').join(validate['hindi']))
# with open('/content/drive/My Drive/NeuralMT/data/test.en', 'w') as writefile:
#     writefile.write(('').join(test['english']))
# with open('/content/drive/My Drive/NeuralMT/data/test.hi', 'w') as writefile:
#     writefile.write(('').join(test['hindi']))
# with open('/content/drive/My Drive/NeuralMT/data/train.en', 'w') as writefile:
#     writefile.write(('').join(train['english']))
# with open('/content/drive/My Drive/NeuralMT/data/train.hi', 'w') as writefile:
#     writefile.write(('').join(train['hindi']))

with open('/content/drive/My Drive/NeuralMT/data_small/dev.en', 'w') as writefile:
    writefile.write(('').join(validate['english']))
with open('/content/drive/My Drive/NeuralMT/data_small/dev.hi', 'w') as writefile:
    writefile.write(('').join(validate['hindi']))
with open('/content/drive/My Drive/NeuralMT/data_small/test.en', 'w') as writefile:
    writefile.write(('').join(test['english']))
with open('/content/drive/My Drive/NeuralMT/data_small/test.hi', 'w') as writefile:
    writefile.write(('').join(test['hindi']))
with open('/content/drive/My Drive/NeuralMT/data_small/train.en', 'w') as writefile:
    writefile.write(('').join(train['english']))
with open('/content/drive/My Drive/NeuralMT/data_small/train.hi', 'w') as writefile:
    writefile.write(('').join(train['hindi']))

# %%
data_folder = "data"
files = os.listdir(data_folder)
source_files = [os.path.join(data_folder, file) for file in files if ".en" in file]
target_files = [os.path.join(data_folder, file) for file in files if ".hi" in file]
print(source_files)

def generate_vocab(filenames):
    vocab = set()
    # no_words = 0
    for file in filenames:
        content = open(file).read()
        sentences = [re.sub(fr'([{string.punctuation}])\B', r' \1', sentence).split() for sentence in content.split('\n')]
        for sentence in sentences:
            for word in sentence:
                if word not in vocab:
                    vocab.add(word)
                    # no_words += 1

    vocab = {word: num for num, word in enumerate(vocab)}
    return vocab

def parse_files_to_indices(filename, vocab):
    content = open(filename).read()
    return [[vocab[word] for word in re.sub(fr'([{string.punctuation}])\B', r' \1', sentence).split() if word in vocab] for sentence in content.split('\n')]

class Dataset:
    def __init__(self, source_files, target_files, batch_size=10):
        self.source_vocab = generate_vocab(source_files) #for entire lang
        self.target_vocab = generate_vocab(target_files) #for entire lang
        
        self.len_source = len(self.source_vocab.keys())
        self.source_pad, self.source_start, self.source_end = self.len_source + 2, self.len_source + 1, self.len_source
        self.len_target = len(self.target_vocab.keys())
        self.target_pad, self.target_start, self.target_end = self.len_target + 2, self.len_target + 1, self.len_target
        
        self.source_vocab['<pad>'], self.source_vocab['<start>'], self.source_vocab['<end>'] = [self.source_pad, 
                                                                                                self.source_start, 
                                                                                                self.source_end]
        self.target_vocab['<pad>'], self.target_vocab['<start>'], self.target_vocab['<end>'] = [self.target_pad,
                                                                                                self.target_start, 
                                                                                                self.target_end]
                                                                                              
        ##created indices for <pad>, <start> and <end> tokens
        self.len_source = len(self.source_vocab.keys())
        self.len_target = len(self.target_vocab.keys())
        
        ##inverse vocab for entire lang
        self.source_vocab_inv = {value:key for key, value in self.source_vocab.items()}
        self.target_vocab_inv = {value:key for key, value in self.target_vocab.items()}
        
        ##parsing files into indices
        for filename in source_files:
            if 'train' in filename:
                self.source_train = parse_files_to_indices(filename, self.source_vocab)
            if 'test' in filename:
                self.source_test = parse_files_to_indices(filename, self.source_vocab)
            if 'dev' in filename:
                self.source_dev = parse_files_to_indices(filename, self.source_vocab)
                
        for filename in target_files:
            if 'train' in filename:
                self.target_train = parse_files_to_indices(filename, self.target_vocab)
            if 'test' in filename:
                self.target_test = parse_files_to_indices(filename, self.target_vocab)
            if 'dev' in filename:
                self.target_dev = parse_files_to_indices(filename, self.target_vocab)
                
        ##random shuffling of training data before splitting into batches    
        self.indices = list(range(len(self.source_train)))
        random.shuffle(self.indices)
        self.current = -batch_size
        self.batch_size = batch_size
        
    def __get_batch_input(self, indices):
        source, target_input, target_target = [], [], []
        
        # padding length of sentence
        source_max_len = max(len(self.source_train[i]) for i in indices)
        target_max_len = max(len(self.target_train[i]) for i in indices)
        
        for i in indices:
            length = len(self.source_train[i])
            # reverse_source_sentences and pad at beginning
            sentence = [self.source_pad for _ in range(source_max_len - length)] + [self.source_end] + self.source_train[i][::-1] + [self.source_start]
            source.append(sentence)
            
            length = len(self.target_train[i])
            # padding at end for target
            sentence = [self.target_start] + self.target_train[i] + [self.target_end] + [self.target_pad for _ in range(target_max_len - length)]
            target_input.append(sentence)
            #removed <sos> and put <pad> at end
            target_target.append(sentence[1:] + [self.target_pad])
            
        return np.array(source), np.array(target_input), np.array(target_target)
    
    def get_batch_input(self):
        if self.current > len(self.indices) - self.batch_size:
            self.current = 0
            return None, None, None
        self.current += self.batch_size
        return self.__get_batch_input(self.indices[self.current: self.current + self.batch_size])
    
    def convert_indices_to_words(self, indices):
        output = []
        for sentence in indices:
            s = []
            for word in sentence:
                if word == self.target_end:
                  break
                s.append(self.target_vocab_inv[word])
            output.append(s)
        return output

    def convert_indices_to_words_eng(self, indices):
        output = []
        for sentence in indices:
            s = []
            for word in sentence:
                s.append(self.source_vocab_inv[word])
            output.append(s)
        return output


# ```
# %run seq2seq.ipynb
# 
# d = Dataset(source_files, target_files, 10)
# m = Seq2Seq(d.len_source, d.len_target, 9, 7)
# m.cuda()
# 
# a, b = d.get_batch_input()
# source, target = torch.cuda.LongTensor(a), torch.cuda.LongTensor(b)
# 
# # For teacher forcing:
# m(source, target)
# 
# # Using model's own predictions:
# m(source)
# ```

# In[37]:


def train(model, dataset, coverage=False, coverage_type="linguistic", iterations=1, use_teacher_forcing=True, log=True):
    # TODO: attention error
    loss_func = nn.NLLLoss()
    attn_loss_func = nn.MSELoss()
    
    optimizer = optim.Adagrad(model.parameters()) 
    
    for i in range(iterations):
        iter_loss = 0
        while True:
            
            optimizer.zero_grad() #set the gradients to zero before starting to do backpropragation because PyTorch accumulates the gradients on subsequent backward passes.
            source, target_input, target_output = d.get_batch_input() #sentences made into indices and padded to sentence lenght 

            if source is None: # end of current iteration
                break

            source, target_input, target_output = [torch.LongTensor(source), 
                                                   torch.LongTensor(target_input), 
                                                   torch.LongTensor(target_output)]
            
            source_mask = torch.ones(source.shape)
            source_mask[source == dataset.source_pad] = 0
            
            if use_teacher_forcing:
                pred, attn = model(source, target_input, source_mask=source_mask)
                # mask whatevers after <stop> 
                target_mask = torch.ones(target_output.shape)
                target_mask[target_output == dataset.target_pad] = 0
                pred = pred * target_mask.unsqueeze(-1)
                target_output = target_output * target_mask.long()
            else:
                pred, attn_weights = model(source)
                
            no_words = pred.shape[0] * pred.shape[1]
            pred = pred.reshape(no_words, -1)
            target_output = target_output.reshape(no_words)

            pred_error = loss_func(pred, target_output)
            iter_loss += pred_error
            # print("loss ", pred_error)
            attn_error = None

                
            pred_error.backward() #backward prop
            optimizer.step()
            
            if log:
                print(d.current/d.batch_size, pred_error, end='\r')
        print("loss ", iter_loss)


# In[38]:


def convert_pred_to_indices(pred):
    # print('pred',pred.shape)
    # print('pred_ideal',torch.max(pred, dim=-1)[1].shape)
    # print(torch.max(pred, dim=-1)[1])
    return torch.max(pred, dim=-1)[1]


# In[39]:


def eval(model, dataset, log=False, source_test=None, target_test=None):
    scores = []
    if source_test is None:
        source_test = dataset.source_test
        target_test = dataset.target_test
        
    for sentence, target in zip(source_test, target_test):
        input_text = dataset.convert_indices_to_words_eng([sentence[::-1]] )
        input = torch.LongTensor([[dataset.source_end] + sentence[::-1] + [dataset.source_start]])

        pred, _ = model(input)
        pred_words = convert_pred_to_indices(pred).cpu().numpy()
        
        predicted_target = dataset.convert_indices_to_words(pred_words)
        target = dataset.convert_indices_to_words([target])
        if log:
            print(input_text,target, predicted_target[0])
        scores.append(sentence_bleu(target, predicted_target[0], weights=(1, 0, 0, 0)))
    return sum(scores)/len(scores)
# Out:
# ['data/dev.en', 'data/test.en', 'data/train.en']

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import numpy as np


# In[2]:


import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as f


# In[3]:


class Encoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.encoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        
    def forward(self, input):
        '''
        input dim => 2d no_sentences * no_words
        make sure that the input is in reverse
        
        Outputs:
        output, h, c
        
        output => dim: (num_sentences * num_words * hidden_dim)
        h => (num_layers * num_sentences * hidden_dim)
        c => (num_layers * num_sentences * hidden_dim)
        '''
        embeddings = self.embedding(input)
        output, (h, c) = self.encoder(embeddings)
        
        return output, h, c


# In[4]:


class Decoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0, start_dim=1):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.decoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        self.word_predictor = nn.Linear(hidden_dim, num_embeddings)
        self.start_dim = start_dim
        
    def forward(self, output, h, c, input=None, max_sen_len=20):
        '''
        Output:
        pred: (no_sentences * no_words * no_embeddings)
        **Note: if input is not None, log_softmax is returned
        else, input is returned without softmax**
        '''
        
        if input is not None: # training with teacher forcing
            
            embeddings = self.embedding(input)
            yts, _ = self.decoder(embeddings, (h, c))
            orig_shape = yts.shape
            # print("orig_shape",orig_shape, orig_shape[:-1],"nfk ", *orig_shape[:-1])
            pred = self.word_predictor(yts.reshape(orig_shape[0]*orig_shape[1], -1)).reshape(*orig_shape[:-1], -1)
            return torch.log_softmax(pred, dim=-1), None
        
        else: # training using the decoders' own predictions
            
            num_sentences = output.shape[0]
            words_selected = torch.LongTensor([[self.start_dim] for _ in range(num_sentences)])
            pred = []
            for i in range(max_sen_len):
                embeddings = self.embedding(words_selected)
                y_t, (h, c) = self.decoder(embeddings, (h, c))
                orig_shape = y_t.shape
                pred_t = self.word_predictor(y_t.reshape(orig_shape[0]*orig_shape[1], 
                                                         -1)).reshape(*orig_shape[:-1], -1).squeeze(1)

                pred.append(pred_t)
                words_selected = torch.max(pred_t, dim=1)[1].unsqueeze(1)
            
            pred = torch.stack(pred, dim=1)
            return torch.log_softmax(pred, dim=-1), None


# In[5]:


class Seq2Seq(nn.Module):
    def __init__(self, source_vocab_len, target_vocab_len, embedding_dim, hidden_dim, num_layers=1,
                       padding_dim_source=0, start_dim_target=1, padding_dim_target=0):
        super().__init__()
        self.encoder = Encoder(source_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_source)
        self.decoder = Decoder(target_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_target, start_dim_target)
        
    def forward(self, source_input, target_input=None, source_mask=None):
        output, h, c = self.encoder(source_input)
        return self.decoder(output, h, c, target_input)


# **Without teacher forcing**
# ```
# input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s = Seq2Seq(10, 12, 9, 7)
# s.cuda()
# pred = s(input)
# ```

# **With teacher forcing**
# 
# ```
# tar_input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s(input, tar_input).shape
# ```

# In[ ]:

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cpu

# %%
#!/usr/bin/env python
# coding: utf-8

# In[30]:


# get_ipython().run_line_magic('run', 'utils.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq_with_attention.ipynb')
# get_ipython().run_line_magic('run', 'effective_approaches.ipynb')
# get_ipython().run_line_magic('run', 'coverage.ipynb')


# In[4]:

# device = 'cuda' if torch.cuda.is_available() else 'cpu'
# m.to(device)
# torch.cuda.set_dezce(0)
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# In[24]:


d = Dataset(source_files, target_files, batch_size=10)
embedding_dim = 50
hidden_dim = 100
num_layers = 2


# In[25]:


def train_and_save(m, d, str_, coverage=False, coverage_type="linguistic", log=False):
    prev_score = -1
    for i in range(20):
        train(m, d, coverage, coverage_type, log=log)
        score = eval(m, d, log=True)
        best_state = None
        print()
        print(score)
        if score > prev_score:
            #torch.save(m.state_dict(), str_ + str(score)[:4] + ".params_")
            best_state = m.state_dict()
            prev_score = score
            
    torch.save(best_state, str_ + str(prev_score)[:4] + ".params")
    print(prev_score)


# In[26]:

m = Seq2Seq(d.len_source, d.len_target, embedding_dim, hidden_dim, num_layers=2, 
            padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
#print(m.cuda())
train_and_save(m, d, "seq2seq_")


# In[ ]:


# m = Seq2SeqWithAttention(d.len_source, d.len_target, embedding_dim, hidden_dim, num_layers=2, 
#             padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
# print(m.cuda())
# train_and_save(m, d, "attention_")
# Out:
# loss  tensor(2243.2874, grad_fn=<AddBackward0>)
# [['.', 'speak', 'to', 'not', 'try']] [['बोलो', 'मत।']] ['मैं', 'एक', 'को', 'में']
# [['?', 'po', 'seen', 'you', 'have']] [['तुमने', 'पो', 'को', 'देखा', '?']] ['आप', 'क्या', 'क्या', 'है', '?']
# [['.', 'now', 'stop', 'can', 'you', ',', 'uh']] [['उह', ',', 'तुम', 'अब', 'बंद', 'कर', 'सकते', 'हैं', '।']] ['मैं', ',', 'मैं', 'नहीं', 'है', '।']
# [['!', 'him', 'for', 'going', 'im']] [['मैं', 'उसके', 'लिए', 'जा', 'रहा', 'हूँ', '!']] ['मैं', 'एक', 'एक', 'है', '?']
# [['.', 'down', 'is', 'oxygen', 'is', 'mako']] [['mako', 'की', 'ऑक्सीजन', 'नीचे', 'है', '।']] ['हम', 'एक', 'एक', 'में', 'है', '।']
# [['!', 'red', 'code', 'a', 'got', 'we']] [['हमें', 'लाल', 'कोड', 'मिला', 'है', '!']] ['हम', 'एक', 'एक', 'एक', 'है', '!']
# [['.', 'it', 'made', 'i']] [['~', '~', 'मैं', 'इसे', 'बनाया', 'है', '।']] ['मैं', 'मैं', 'नहीं', 'है', '।']
# [['?', 'mean', 'that', 'does', 'what']] [['कि', 'क्या', 'मतलब', 'है', '?']] ['क्या', 'क्या', 'क्या', 'है', '?']
# [['?', 'at', 'guy', 'this', 'is', 'where']] [['जहां', 'इस', 'आदमी', 'पर', 'है', '?']] ['यह', 'क्या', 'है', '?']
# [['.', 'game', 'stupid', 'a', 'playing']] [['एक', 'बेवकूफ', 'खेल', 'खेल', 'रहे', '।']] ['यह', 'एक', 'में', 'है', '।']
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# [['?', 'them', 'tell', 'you', 'would', 'what']] [['क्या', 'आप', 'उन्हें', 'बताना', 'होगा', '?']] ['आप', 'क्या', 'क्या', 'है', '?']
# [['.', 'type', 'her', 'for', ',', 'pretty']] [['ठीक', 'ठाक', 'सुंदर', 'है']] ['मैं', ',', 'एक', 'नहीं', 'है', '।']
# [['.', 'lebanon', 'west', ',', 'africa', 'central', ',', 'exmercenary']] [['पूर्व', 'भाड़े', ',', 'मध्य', 'अफ्रीका', ',', 'पश्चिम', 'लेबनान', '।']] [',', ',', ',', 'यह', 'एक', 'है', '।']
# [['?', 'available', 'trixie', 'mistress', 'is']] [['ट्रिक्सी', 'से', 'बात', 'हो', 'सकती', 'है', '?']] ['यह', 'क्या', 'है', '?']
# [['!', 'pressure', 'to', 'due', 'pressed', 'was']] [['दबाव', 'की', 'वजह', 'से', 'दबाया', 'गया', 'था', '!']] ['मैं', 'एक', 'एक', 'में', 'है', '।']
# [['?', 'bourbon', 'bulleit', 'carry', 'you']] [['आप', 'बुलेट', 'बोरबॉन', 'ले', '?']] ['आप', 'क्या', 'क्या', 'है', '?']
# [['.', 'shame', 'damn', 'a', 'is', 'that']] [['एक', 'बहुत', 'शर्म', 'की', 'बात', 'है', '।']] ['यह', 'एक', 'एक', 'है', '।']
# [['.', 'me', 'excuse', ',', 'sorry', 'so', 'im']] [['im', 'very', 'sorry', ',', 'im', 'sorry', '।']] ['मैं', ',', 'यह', 'एक', 'नहीं', 'है', '।']
# [['.', 'priya', 'daughter', 'my']] [['मेरी', 'बेटी', 'प्रिया']] ['मैं', 'एक', 'में']
# [[')', 'ricochet', 'bullets', '(']] [['(गोलियों', 'रिकोषेट', ')']] ['मैं', 'में']
# [['.', 'right', 'all', 'are', 'you', 'god', 'thank']] [['शुक्र', 'है', 'तुम', 'ठीक', 'हो।']] ['आप', 'आप', 'एक', 'नहीं', 'है', '।']
# [['.', 'things', 'these', 'understand', 'not', 'wo', 'you']] [['तुम', 'इन', 'बातों', 'को', 'नहीं', 'समझोगे', '।']] ['आप', 'आप', 'के', 'के', 'है', '।']
# [['!', 'door', 'the', 'to', 'head']] [['दरवाजे', 'के', 'लिए', 'सिर', '!']] ['मैं', 'एक', 'में']
# [['.', 'answer', 'no', 'is', 'that']] [['ये', 'कोई', 'जवाब', 'नहीं', 'है', '।']] ['यह', 'एक', 'एक', 'है', '।']
# [['.', 'found', 'i', 'who', 'look', '!', 'hey']] [['ऐ', '!']] ['मैं', 'एक', 'एक', 'एक', 'नहीं', 'है', '।']
# [['.', 'right', 'all', ',', 'right', 'all', ',', 'yeah']] [['यह', 'लो।']] [',', ',', ',', 'एक', 'एक', 'नहीं', 'है', '।']
# [['.', '.', '.', 'suggest', 'i', 'may', 'now']] [['अब', 'मैं', 'सुझाव', 'दे', 'सकते', 'हैं', '।', '।', '।']] ['मैं', 'मैं', 'नहीं', '।']
# [['.', 'it', 'make', 'can', 'we']] [['हम', 'यह', 'कर', 'सकते', 'हैं', '।']] ['यह', 'एक', 'एक', 'है', '।']
# [['.', 'map', 'the', 'on', 'not', 'was', 'this']] [['यह', 'सिर्फ', 'नक्शे', 'पर', 'नहीं', 'था', '।']] ['यह', 'एक', 'एक', 'है', '।']
# [['.', 'dad', ',', 'you', 'love', 'i']] [['मैं', 'आपको', 'प्यार', 'करता', 'हूं', 'डैड।']] ['मैं', 'मैं', 'नहीं', 'नहीं', 'है', '।']
# [['?', 'me', 'hear', 'you', 'do']] [['आप', 'मुझे', 'सुन', 'रहे', 'हो', '?']] ['आप', 'क्या', 'क्या', 'है', '?']
# [['.', 'futures', 'your', 'with', 'us', 'trust']] [['अपने', 'भविष्य', 'के', 'लिए', 'हमारी', 'सलाह', 'मानो', '।']] ['मैं', 'एक', 'एक', 'में', 'है', '।']
# [['?', 'you', 'know', 'i', 'do']] [['क्या', 'मैं', 'आपको', 'जानता', 'हूं', '?']] ['मैं', 'आप', 'क्या', 'है', '?']
# [['.', 'cry', 'me', 'makes', 'skin', 'your']] [['आपकी', 'त्वचा', 'मुझे', 'रुलाती', 'है', '।']] ['मैं', 'एक', 'एक', 'नहीं', 'है', '।']
# [['.', 'doug', ',', 'you', 'thank']] [['डौग', 'धन्यवाद', '।']] ['आप', ',', 'यह', 'नहीं', 'है', '।']
# [['.', 'something', 'was', 'definitely', 'there']] [['यक़ीनन', 'कोई', 'था।']] ['मैं', 'एक', 'को', '।']
# [['?', 'son', 'other', 'your', 'about', 'how']] [['दूसरे', 'लड़के', 'का', 'क्या', 'हुआ', '?']] ['हम', 'क्या', 'क्या', 'है', '?']
# [['.', 'out', 'this', 'check', 'come', ',', 'cale']] [['आकर', 'ये', 'देखो।']] ['हम', ',', 'एक', 'एक', 'है', '।']
# [['.', '.', '.', 'mind', 'not', 'wo', 'he', 'that']] [['कि', 'उसे', 'बुरा', 'नहीं', 'लगेगा', '।', '।', '।']] ['यह', 'एक', 'एक', 'है', '।']
# [['.', 'open', 'eyes', 'your', 'keep']] [['अपनी', 'आँखें', 'खुली', 'रखें', '।']] ['मैं', 'एक', 'को', 'में']
# [['!', 'restored', 'be', 'must', 'order']] [['शांति', 'बहाल', 'होनी', 'चाहिए', '!']] ['हम', 'एक', 'में', 'है', '।']
# [['.', 'to', 'have', 'not', 'did', 'i']] [['मुझे', 'ज़रूरत', 'नहीं', 'पड़ी।']] ['मैं', 'मैं', 'एक', 'को', 'है', '।']
# [['.', 'fish', 'the', 'want', 'they']] [['वे', 'मछली', 'चाहते', 'हैं', '।']] ['मैं', 'एक', 'को', '।']
# [['!', 'inside', 'move', 'anybody', 'not', 'do']] [['किसी', 'को', 'भी', 'अंदर', 'कदम', 'नहीं', 'है', '!']] ['हम', 'एक', 'एक', 'में', 'है', '।']
# [['.', 'authority', 'no', 'had', 'you']] [['तुम्हें', 'ऐसा', 'करने', 'का', 'कोई', 'अधिकार', 'न', 'था।']] ['आप', 'एक', 'नहीं', 'है', '।']
# [['.', 'korea', 'south', 'lost', 'just', 'we']] [['हम', 'सिर्फ', 'दक्षिण', 'कोरिया', 'को', 'खो', 'दिया', '।']] ['मैं', 'एक', 'एक', 'में', 'है', '।']
# [['.', 'height', 'the', 'me', 'tell']] [['कितना', 'ऊँचा', 'है', '।']] ['मैं', 'एक', 'को', '।']
# [['♪', 'in', 'trust', '♪']] [['♪मेंट्रस्ट', 'एक']] ['मैं', 'एक', 'में', 'है', '?']
# [['?', 'danny', 'about', 'was', 'it', 'maybe']] [['शायद', 'डैनी', 'के', 'बारे', 'में', 'था', '?']] ['यह', 'एक', 'एक', 'है', '?']
# [['.', 'again', 'down', 'back', 'go', 'is', 'let']] [['चलो', 'वापस', 'फिर', 'से', 'नीचे', '।']] ['यह', 'एक', 'एक', 'है', '।']
# [['?', 'why', 'say', 'he', 'did']] [['वह', 'क्यों', 'कहा', '?']] ['हम', 'क्या', 'है', '?']
# [[')', 'music', 'ominous', '(']] [['(अशुभ', 'संगीत', ')']] ['मैं', 'में']
# [['.', 'connected', 'all', 'are', 'we', ',', 'remember']] [['लेफ्टिनेंट', 'ठीक', 'है', '।']] ['यह', ',', 'एक', 'एक', 'है', '।']
# [['?', 'boss', ',', 'now', 'what', ',', 'so']] [['तो', 'अब', 'क्या', 'है', ',', 'मालिक', '?']] [',', ',', ',', ',', 'नहीं', 'है', '?']
# [['!', 'die', 'family', 'your', 'let', 'you']] [['आप', 'अपने', 'परिवार', 'के', 'मर', 'जाते', 'हैं', '!']] ['आप', 'एक', 'एक', 'नहीं', 'है', '?']
# [['.', 'fair', 'more', 'nothing', 'is', 'there']] [['वहाँ', 'अधिक', 'उचित', 'नहीं', 'है', '।']] ['यह', 'एक', 'एक', 'है', '।']
# [['.', 'pandu', ',', 'hurt', 'is', 'dad', 'my']] [['मेरे', 'पिताजी', 'की', 'चोट', ',', 'पांडु।']] ['यह', ',', 'एक', 'एक', 'है', ',', '।']
# [['.', 'arrested', 'prophet', 'some', 'had', 'caiphas']] [['कैफस', 'ने', 'किसी', 'नबी', 'को', 'गिरफ्तार', 'करवाया', 'था', '।']] ['हम', 'एक', 'में', 'है', '।']
# [['.', 'something', 'say', 'to', 'wanted', 'you']] [['तुम', 'कुछ', 'कहना', 'चाह', 'रही', 'थी', '।']] ['मैं', 'आप', 'को', 'को', '।']
# [['.', 'it', 'get', 'and', 'go']] [['जाओ', 'और', 'इसे', 'पाने', 'के', 'लिए', '।']] ['यह', 'एक', 'एक', 'है', '।']
# [['.', 'news', 'good', 'another', 'is', 'there', 'but']] [['लेकिन', 'वहाँ', 'एक', 'और', 'अच्छी', 'खबर', 'है।']] ['मैं', 'एक', 'एक', 'में', 'है', '।']
# [['.', 'voice', 'my', 'to', 'come', 'is', 'it']] [['यह', 'मेरी', 'आवाज', 'के', 'लिए', 'आ', 'रहा', 'है', '!']] ['यह', 'एक', 'एक', 'है', '।']
# [['.', 'man', 'old', ',', 'night', 'good']] [['शुभ', 'रात्रि', ',', 'बूढ़े', 'आदमी', '।']] ['वह', ',', 'यह', 'एक', 'है', '।']
# [['.', 'trunk', 'the', 'in', 'is', 'doug']] [['ट्रंक', 'में', 'है', 'डौग', '।']] ['यह', 'एक', 'में', 'है', '।']
# [['.', 'schist', 'this', 'all', 'at', 'look']] [['यह', 'सभी', 'प्रकार', 'की', 'शीस्ट', 'को', 'देखो', '।']] ['हम', 'एक', 'में', '।']
# [['.', 'okay', 'is', 'it', ',', 'okay', 'is', 'it']] [['यह', 'ठीक', 'है', ',', 'यह', 'ठीक', 'है', '।']] ['यह', ',', 'यह', 'एक', 'है', ',', '।']
# [['.', 'tale', 'a', 'just', 'is', 'it']] [['यह', 'सिर्फ', 'एक', 'कहानी', 'है']] ['यह', 'एक', 'एक', 'है', '।']
# [['.', 'it', 'do', 'is', 'let', ',', 'right', 'all']] [['all', 'right', ',', 'चलो', 'अब', 'करते', 'है', '।']] ['यह', ',', 'यह', 'एक', 'है', ',', '।']
# [['.', 'some', 'him', 'give', ',', 'on', 'go']] [['थोड़ी', 'सी', 'पिला', 'दो।']] ['वह', ',', 'यह', 'एक', 'है', '।']
# [['?', 'equals', ',', '£', ',', 'xbox', 'one', 'minus']] [['शून्य', 'से', 'एक', 'xbox', ',', '£', 'के', 'बराबर', 'होती', 'है', '?']] ['हम', ',', ',', 'यह', ',', 'नहीं', 'है', '?']
# [['?', 'right', ',', 'address', 'your', 'is', 'this']] [['यह', 'आपका', 'पता', 'है', ',', 'है', 'ना', '?']] ['यह', 'एक', 'है', ',', 'क्या', 'है', '?']
# [['.', 'here', 'are', 'friends', 'my']] [['मेरे', 'मित्र', 'यहां', 'है।']] ['हम', 'एक', 'एक', 'में', 'है', '।']
# [['.', 'wait', 'rather', 'id', ',', 'well']] [['खैर', ',', 'मैं', 'काफी', 'इंतजार', 'करना', 'चाहिये', '।']] ['मैं', ',', 'मैं', 'नहीं', 'है', '।']
# [['!', 'crowd', 'terrific', 'a', 'what']] [['शुक्रिया', '!', 'क्या', 'शानदार', 'लोग', 'हैं', '!']] ['यह', 'एक', 'एक', 'है', '?']
# [['.', 'guess', 'i', ',', 'right', 'all', 'is', 'it']] [['यह', 'सब', 'ठीक', 'है', ',', 'मुझे', 'लगता', 'है', '।']] ['यह', ',', 'यह', 'नहीं', 'है', ',', '।']
# [['.', 'cookie', 'good', 'a', 'makes', 'maman']] [['मा', 'आदमी', 'एक', 'अच्छा', 'कुकी', 'बनाता', 'है', '।']] ['हम', 'एक', 'एक', 'में', 'है', '।']
# [['.', 'you', 'to', 'talking', 'im']] [['मैं', 'आप', 'से', 'बात', 'कर', 'रहा', 'हूँ', '।']] ['मैं', 'मैं', 'नहीं', 'है', '।']
# [['.', 'friend', 'a', 'just', 'is', 'it']] [['बस', 'एक', 'दोस्त', 'है।']] ['यह', 'एक', 'एक', 'है', '।']
# [['.', 'hyderabad', 'from', 'am', 'i']] [['मैं', 'हैदराबाद', 'से', 'हूं।']] ['मैं', 'मैं', 'नहीं', 'है', '।']
# [['!', 'idea', 'terrible', 'a', 'is', 'that']] [['यह', 'बहुत', 'ही', 'खराब', 'आइडिया', 'है', '!']] ['यह', 'एक', 'एक', 'है', '!']
# [['.', 'on', 'come', ',', 'god', 'thank']] [['भगवान', 'का', 'शुक्र', 'है', ',', 'चलो।']] ['यह', ',', 'यह', 'नहीं', 'है', '।']
# [['.', 'there', 'good', 'are', 'we', 'so']] [['तो', 'हम', 'वहाँ', 'अच्छा', 'कर', 'रहे', 'हैं', '।']] ['हम', 'एक', 'एक', 'में', 'है', '।']
# [['.', 'here', 'got', 'just', 'we', 'but']] [['लेकिन', 'हम', 'यहाँ', 'सिर्फ', 'मिला', 'है', '।']] ['मैं', 'एक', 'एक', 'एक', 'है', '।']
# [['.', 'meeting', 'a', 'in', 'are', 'they']] [['वे', 'किसी', 'मीटिंग', 'में', 'हों।']] ['हम', 'एक', 'एक', 'में', 'है', '।']
# [['.', 'psychopath', 'a', 'me', 'calling', 'are', 'they']] [['वे', 'मुझे', 'मनोरोगी', 'बुलाते', 'हैं।']] ['हम', 'एक', 'एक', 'में', 'है', '।']
# [['.', 'incident', 'superman', 'the', 'in', 'fired']] [['सुपरमैन', 'घटना', 'में', 'गोली', 'चलाई।']] ['हम', 'एक', 'में']
# [['.', 'boy', 'nice', 'a', 'such', 'is', 'he']] [['उन्होंने', 'कहा', 'कि', 'इस', 'तरह', 'एक', 'अच्छा', 'लड़का', 'है।']] ['मैं', 'एक', 'एक', 'एक', 'है', '।']
# [['.', 'everybody', 'please', 'to', 'trying']] [['सबको', 'खुश', 'करने', 'की', 'कोशिश', 'कर', 'रहा', '।']] ['मैं', 'एक', 'में', 'है', '।']
# [['.', '.', '.', 'year', 'one', 'in', 'remember']] [['याद', 'रखो', 'एक', 'साल', 'में', '।', '।', '।']] ['मैं', 'एक', 'को', 'में', '।']
# [['!', 'out', 'coming', 'im', ',', 'right', 'all']] [['मैं', 'बाहर', 'आ', 'रहा', 'हूँ', '!']] ['मैं', ',', 'एक', 'एक', 'नहीं', 'है', '।']
# [['!', 'way', 'the', 'of', 'out']] [['रास्ते', 'से', 'बाहर', 'है', '!']] ['मैं', 'के', 'के', 'है', '।']
# [['.', 'otherjob', 'some', 'on', 'be', 'may']] [['शायद', 'किसी', 'और', 'काम', 'से', 'आया', 'होगा', '।']] ['मैं', 'एक', 'एक', 'में', 'है', '।']
# [['.', 'more', 'nothing', ',', 'dreams', 'are', 'these']] [['ये', 'सपने', ',', 'ज्यादा', 'कुछ', 'नहीं', 'कर', 'रहे', 'हैं।']] ['यह', ',', 'एक', 'एक', 'है', '।']
# [['.', 'person', 'a', 'not', 'is', 'it']] [['वह', 'कोई', 'इंसान', 'नहीं', 'है।']] ['यह', 'एक', 'एक', 'है', '।']
# [['?', 'blood', 'much', 'how', 'and']] [['और', 'कितना', 'खून', '?']] ['आप', 'क्या', 'क्या', 'है', '?']
# [['!', 'you', 'thank', ',', 'minutes', 'ten']] [['दस', 'मिनट', ',', 'शुक्रिया', '!']] ['मैं', ',', ',', 'एक', 'नहीं', 'है', '।']
# [['?', 'now', 'her', 'phone', 'we', 'can']] [['क्या', 'अब', 'हम', 'उसे', 'फ़ोन', 'कर', 'सकते', 'हैं', '?']] ['हम', 'क्या', 'क्या', 'है', '?']
# [['.', 'wonderful', 'absolutely', 'were', 'you']] [['आप', 'बिल्कुल', 'अद्भुत', 'थे', '।']] ['मैं', 'एक', 'को', 'में']
# [['.', 'hansen', 'hercules', 'marshal', 'is', 'this']] [['यह', 'मार्शल', 'हरक्यूलिस', 'हैनसेन', 'है', '।']] ['यह', 'एक', 'एक', 'है', '।']
# [['.', 'sweetie', ',', 'you', 'for', 'is', 'it']] [['यह', 'स्वीटी', ',', 'आप', 'के', 'लिए', 'है', '।']] ['यह', ',', 'यह', 'नहीं', 'है', '।']
# [['.', 'cool', 'pretty', 'is', 'it', 'but']] [['लेकिन', 'यह', 'बहुत', 'अच्छा', 'है', '।']] ['यह', 'एक', 'एक', 'है', '।']
# [['.', 'god', 'my', ',', 'oh', '/', '.', 'jesus', ',', 'oh']] [['ओह', 'भगवान', ',', '।', '/', 'ओह', ',', 'मेरे', 'भगवान', '।']] ['मैं', ',', ',', ',', ',', 'नहीं', 'है', '।']
# [['.', 'safe', 'not', 'its', ',', 'inside', 'get']] [[',', 'अंदर', 'उसके', 'सुरक्षित', 'नहीं', 'मिलता', 'है', '।']] ['यह', ',', 'यह', 'नहीं', 'है', '।']
# [['.', 'good', 'all', 'is', 'it']] [[',', 'यह', 'सब', 'अच्छा', 'है', '।']] ['यह', 'एक', 'में', 'है', '।']
# [['.', 'enough', 'clear', 'not', 'was', 'i', 'maybe']] [['शायद', ',', 'मैं', 'काफी', 'स्पष्ट', 'नहीं', 'था', '।']] ['मैं', 'मैं', 'एक', 'नहीं', 'है', '।']
# [['.', 'buddy', 'l', ',', 'luke', 'just']] [['बस', 'ल्यूक', ',', 'l', 'दोस्त', '।']] ['यह', ',', 'यह', 'नहीं', 'है', '।']
# [['.', 'thing', 'good', 'a', 'is', 'that']] [['यह', 'एक', 'अच्छी', 'बात', 'है', '।']] ['यह', 'एक', 'एक', 'है', '।']
# [['!', 'me', 'off', 'get', 'just']] [['सिर्फ', 'मुझसे', 'दूर', 'हो', 'जाओ', '!']] ['हम', 'एक', 'एक', 'में', 'है', '!']
# [['.', '.', '.', 'you', 'like', 'thief', 'a']] [['आप', 'जैसे', 'एक', 'चोर', '।', '।', '।']] ['मैं', 'तुम', 'नहीं', '।']
# [['!', 'me', 'leaving', 'not', 'are', 'you']] [['तुम', 'मुझे', 'नहीं', 'जा', 'रहे', 'हैं', '!']] ['आप', 'एक', 'एक', 'नहीं', 'है', '?']
# [['?', 'do', 'he', 'does', 'what', 'and']] [['और', 'वह', 'क्या', 'करता', 'है', '?']] ['आप', 'क्या', 'क्या', 'है', '?']
# [['.', 'porn', 'monkey', 'is', 'it']] [['यह', 'बंदर', 'अश्लील', 'है', '।']] ['यह', 'एक', 'है', '।']
# [['.', 'expensive', 'really', 'is', 'car', 'a']] [['कार', 'वास्तव', 'में', 'महंगी', 'होती', 'है', '।']] ['यह', 'एक', 'एक', 'है', '।']
# [['.', 'team', 'a', 'are', 'we', ',', 'no', ',', 'jack']] [['जैक', ',', 'नहीं', ',', 'हम', 'एक', 'टीम', 'हैं', '।']] ['यह', ',', ',', 'एक', 'एक', 'है', ',', '।']
# [['?', 'me', 'hear', 'anybody', 'can']] [['कोई', 'मुझे', 'सुन', 'पा', 'रहा', 'है', '?']] ['आप', 'क्या', 'है', '?']
# [['?', 'son', ',', 'business', 'your', 'this', 'is']] [['यह', 'आपके', 'व्यापार', ',', 'बेटा', 'है', '?']] ['यह', ',', 'क्या', 'है', '?']
# [['.', 'go', 'is', 'let', ',', 'go', 'is', 'let']] [['नहीं।', 'चलो।']] ['यह', 'एक', 'एक', 'है', ',', 'यह', 'है', '।']
# [['aliens', 'hates', 'god']] [['भगवान', 'एलियंस', 'नफरत', 'करता', 'है']] ['यह', 'है', '।']
# [['?', 'saying', 'are', 'you', 'what', 'that', 'is']] [['यही', 'कह', 'रहे', 'हो', '?']] ['आप', 'क्या', 'क्या', 'है', '?']
# [['.', 'hung', 'was', 'i', 'wish']] [['क्या', 'मैं', 'खत्म', 'कर', 'सकता', 'हूं', '?', 'नहीं', '।', '।', '।', 'आप', 'भाग्यशाली', 'हैं', '।', '।', '।']] ['मैं', 'मैं', 'नहीं', 'है', '।']
# [['"', '.', 'beloved', '.', '.', '.', 'photo', 'my', 'click', '"so']] [['"तो', 'मेरी', 'तस्वीर', 'पर', 'क्लिक', 'करें', '।', '।', '।', 'प्रिय', '"']] ['मैं', 'एक', 'एक', 'नहीं', 'है', '।']
# [['.', 'bastard', 'the', 'gets', 'that', 'anything']] [['कमीने', 'कि', 'कुछ', 'भी', '।']] ['हम', 'एक', 'में']
# [['!', 'things', 'these', 'fly', 'not', 'ca', 'we']] [['हम', 'इनको', 'नहीं', 'उड़ा', 'सकते', '!']] ['हम', 'एक', 'में', 'है', '।']
# [[']', 'tolling', 'bell', '[']] [['[घंटी', 'tolling', ']']] ['मैं', 'में']
# [['!', 'here', 'of', 'out', 'get']] [['यहां', 'से', 'निकलो', '!']] ['हम', 'एक', 'एक', 'में', 'है', '।']
# [['.', 'sir', ',', 'question', 'a', 'have', 'i']] [['मैं', 'एक', 'सवाल', 'है', ',', 'सर', 'है', '।']] ['मैं', ',', 'एक', 'एक', 'नहीं', 'है', '।']
# [['.', 'sec', 'a', 'be', 'just', 'ill']] [['मैं', 'अभी', 'लायी', '।']] ['मैं', 'एक', 'एक', 'में', 'है', '।']
# [['.', 'guy', 'great', 'a', 'is', 'he']] [['वह', 'एक', 'महान', 'आदमी', 'है', '।']] ['यह', 'एक', 'एक', 'है', '।']
# [['.', 'fella', 'big', ',', 'me', 'pardon']] [['माफ़', 'कर', 'देना', ',', 'बड़े', 'दोस्त।']] ['यह', ',', 'यह', 'नहीं', 'है', '।']
# [['.', 'earth', 'and', 'heaven', 'of', 'creator']] [['स्वर्ग', 'और', 'पृथ्वी', 'के', 'निर्माता।']] ['मैं', 'एक', 'एक', 'में', 'है', '।']
# [['!', 'anybody', 'not', ',', 'you', 'not']] [['तुम', 'नहीं', ',', 'कोई', 'भी', 'नहीं', '!']] ['आप', ',', 'यह', 'नहीं', 'है', '?']
# [['?', 'from', 'come', 'he', 'did', 'where']] [['यह', 'आया', 'कहाँ', 'से', '?']] ['हम', 'एक', 'एक', 'है', '?']
# [['?', 'plan', 'your', 'was', 'this']] [['यह', 'आपकी', 'योजना', 'थी', '?']] ['आप', 'एक', 'एक', 'है', '?']
# [['.', 'it', 'got', 'i', '?', 'what']] [['मैं', 'संभाल', 'रहा', 'हूं।']] ['मैं', 'मैं', 'एक', 'नहीं', 'है', '।']
# [['.', 'same', 'the', 'not', 'is', 'it']] [['एक', 'ही', 'बात', 'नहीं।']] ['यह', 'एक', 'है', '।']
# [['?', 'this', 'do', 'can', 'you']] [['आप', 'यह', 'कर', 'सकते', 'हैं', '?']] ['आप', 'क्या', 'क्या', 'है', '?']
# [['.', 'friends', 'my', 'are', 'they']] [['वे', 'मेरे', 'मित्र', 'है।']] ['हम', 'एक', 'में', 'है', '।']
# [['.', 'set', 'all', 'are', 'we', ',', 'right', 'all']] [['ठीक', 'है', ',', 'हम', 'सब', 'तैयार', 'हैं', '।']] ['यह', ',', 'एक', 'एक', 'नहीं', 'है', '।']
# [['.', 'fried', 'got', 'circuits', 'some']] [['कुछ', 'सर्किट', 'तला', 'हुआ', 'मिला।']] ['मैं', 'एक', 'एक', 'नहीं', 'है', '।']
# [['.', 'bed', 'to', 'going', 'im']] [['मैं', 'बिस्तर', 'पर', 'जा', 'रहा', 'हूँ', '।']] ['मैं', 'मैं', 'को', 'को']
# [['?', 'pay', 'about', 'ask', 'you', 'did']] [['क्या', 'वेतन', 'के', 'बारे', 'में', 'पूछा', '?']] ['आप', 'क्या', 'क्या', 'है', '?']
# [['?', 'think', 'fucking', 'you', 'do', 'what']] [['आपको', 'क्या', 'लगता', 'है', 'कि', 'बकवास', 'है', '?']] ['आप', 'क्या', 'क्या', 'है', '?']
# [[')', 'beeps', '(']] [['(बीप', ')']] ['मैं']
# [['!', 'her', 'of', 'go', 'let']] [['उसे', 'जाने', 'दो', '!']] ['हम', 'एक', 'एक', 'में', 'है', '।']
# [['.', 'eat', 'could', 'i', ',', 'yeah']] [['हाँ', ',', 'मैं', 'खा', 'सकता', 'है', '।']] ['मैं', ',', 'मैं', 'नहीं', 'है', '।']
# [[')', 'depart', 'footsteps', '(']] [['(नक्शेकदमरवाना', ')']] [')']
# [['.', 'friend', 'a', 'needed', 'hippopotamus', 'the']] [['दरियाई', 'घोड़ा', 'एक', 'दोस्त', 'की', 'जरूरत', 'है', '।']] ['हम', 'एक', 'में', 'है', '।']
# [['?', 'listen', 'you', 'not', 'did']] [['चुड़ैलों', 'पहले।']] ['आप', 'क्या', 'क्या', 'है', '?']
# [['?', 'you', 'with', 'wrong', 'is', 'what']] [['तुम्हें', 'क्या', 'हुआ', '?']] ['आप', 'क्या', 'क्या', 'है', '?']
# [[')', 'beeps', '(']] [['(बीप', ')']] ['मैं']
# [['.', 'count', 'lose', 'me', 'made', 'you']] [['तुम', 'मुझे', 'गिनती', 'खो', 'दिया', '।']] ['मैं', 'आप', 'एक', 'नहीं', 'है', '।']
# [['date', 'till', 'years']] [['आज', 'तक', 'साल']] ['मैं', 'के', 'है', '।']
# [['.', 'up', 'lined', 'are', 'we', ',', 'cooper']] [['cooper', ',', 'हम', 'बस', 'तैयार', 'है', '।']] ['यह', ',', 'एक', 'एक', 'है', '।']
# [['.', '.', 'ready', 'is', 'passport', 'the', 'if', ',', 'uncle']] [['चाचा', ',', 'पासपोर्ट', 'के', 'लिए', 'तैयार', 'है', '।', '।', 'यदि']] ['यह', ',', 'एक', 'एक', 'है', '।']
# [['.', 'time', 'some', 'buy', 'maybe']] [['शायद', 'कुछ', 'समय', 'मिल', 'सके।']] ['हम', 'एक', 'एक', 'में', 'है', '।']
# [['.', 'here', 'buried', 'is', 'child', 'the']] [['बच्चा', 'यहाँ', 'दफन', 'है', '।']] ['हम', 'एक', 'में', 'है', '।']
# [['.', 'money', 'for', 'father', 'ask']] [['पापा', 'से', 'पैसे', 'मांगो', 'न', '।']] ['मैं', 'एक', 'को', 'में']
# [['.', 'sam', ',', 'not', 'ca', 'i']] [['नहीं', 'कर', 'सकता', ',', 'सैम।']] ['मैं', ',', 'मैं', 'नहीं', 'है', '।']
# [['.', 'happen', 'mistakes', ',', 'understand', 'i']] [['समझती', 'हूँ', ',', 'ग़लतियाँ', 'हो', 'जाती', 'हैं।']] ['मैं', ',', 'मैं', 'नहीं', 'है', '।']
# [['.', 'land', 'of', 'piece']] [['यह', 'जमीन', 'पर', 'है', '!']] ['मैं', 'के', 'के', 'लिए', '।']
# [['.', '.', '.', 'like', 'not', 'is', 'it', ',', 'mate', ',', 'no']] [['नहीं', 'दोस्त', 'ऐसा', 'कुछ', 'नहीं', '।']] ['यह', ',', 'यह', ',', 'एक', 'नहीं', 'है', '।']
# [['!', 'right', 'feels', 'it', 'but']] [['लेकिन', 'यह', 'सही', 'लग', 'रहा', 'है', '!']] ['मैं', 'एक', 'एक', 'नहीं', 'है', '।']
# [['.', 'beautiful', 'really', 'are', 'these']] [['ये', 'वाकई', 'लाजवाब', 'हैं।']] ['हम', 'एक', 'में', 'है', '।']
# [['.', 'humiliating', 'so', 'is', 'this', ',', 'god']] [['भगवान', ',', 'यह', 'कितना', 'अपमानजनक', 'है।']] ['यह', ',', 'यह', 'एक', 'है', '।']
# [['.', 'room', 'battle', 'the', 'is', 'this']] [['इस', 'लड़ाई', 'कमरा', 'है', '।']] ['यह', 'एक', 'में', 'है', '।']
# [['.', 'that', 'know', 'i', '.', 'yes']] [['हा', ',', 'मैं', 'यह', 'जानता', 'हूँ।']] ['मैं', 'मैं', 'एक', 'नहीं', 'है', '।']
# [['.', 'here', 'belong', 'not', 'do', 'you']] [['तुम', 'यहाँ', 'के', 'नहीं', 'हैं', '।']] ['आप', 'आप', 'एक', 'के', 'है', '।']
# [['.', 'divide', 'must', 'one']] [['समुद्र', 'की', 'शक्ति', 'को', 'मुक्त', 'करने', 'के', 'लिए', '।', '।', '।']] ['मैं', 'एक', 'को']
# [['!', '?', 'oracle', 'is', 'where', '!', 'hurt', 'is', 'he']] [['तुम', 'सब', ',', 'वापस', 'रहना', '!']] ['हम', 'एक', 'एक', 'एक', 'नहीं', 'है', '?']
# [['.', 'on', 'seatbelt', 'your', 'put']] [['अपनी', 'सीट', 'बेल्ट', 'बांधो', '।']] ['मैं', 'एक', 'एक', 'में', 'है', '।']
# [['.', 'trappers', 'were', 'guys', 'these']] [['वे', 'लोग', 'बहेलिए', 'थे।']] ['हम', 'एक', 'में']
# [['.', 'buddhists', 'the', ',', 'hindus', 'the']] [['हिंदुओं', ',', 'बौद्धों', '।']] ['हम', ',', 'के', '।']
# [['.', 'susa', 'near', 'hills', 'the', 'from']] [['सुसा', 'के', 'पास', 'पहाड़ियों', 'से', '।']] ['हम', 'के', 'के']
# [['?', 'groom', 'the', 'is', 'where', ',', 'hello']] [['हैलो', ',', 'जहां', 'दूल्हे', 'की', '?']] ['हम', ',', 'यह', 'है', '?']
# [['!', 'immediately', 'backup', 'need', 'we']] [['हम', 'तुरंत', 'बैकअप', 'की', 'जरूरत', 'है', '!']] ['हम', 'एक', 'में', 'है', '?']
# [['.', 'stannis', 'like', 'looked', 'it']] [['यह', 'stannis', 'कैसा', 'दिखता', 'था।']] ['यह', 'एक', 'में', 'है', '।']
# [['?', 'wait', ',', 'wait', ',', 'wait', ',', 'wait']] [['रुको', ',', 'रुको', ',', 'रुको', ',', 'रुको', '।']] [',', ',', ',', ',', 'क्या', 'है', '?']
# [['.', '.', '.', 'goes', 'it', 'how', 'know', 'you']] [['आपको', 'पता', 'है', 'कि', 'यह', 'कैसे', 'होता', 'है', '।', '।', '।']] ['आप', 'आप', 'एक', 'के', 'नहीं', 'है', '।']
# [['?', 'did', 'she', 'what', 'know', 'you']] [['जानते', 'हैं', 'उन्होंने', 'क्या', 'किया', '?']] ['आप', 'क्या', 'क्या', 'है', '?']
# [['?', 'story', 'your', 'is', 'what', 'so']] [['तो', 'आपकी', 'कहानी', 'क्या', 'है', '?']] ['यह', 'क्या', 'है', '?']
# [['?', 'boy', ',', 'you', 'are', 'where']] [['कहां', 'तुम', 'लड़का', 'है', ',', 'कर', 'रहे', 'हैं', '?']] ['आप', ',', 'क्या', 'क्या', 'है', '?']
# /usr/local/lib/python3.6/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Streaming output truncated to the last 5000 lines.
# [['?', 'king', 'the', 'or', 'jack', 'the']] [['जैक', 'या', 'राजा', '?']] ['क्या', 'या', 'की', 'तरह', '?']
# [['.', 'brother', 'your', 'about', 'is', '"it']] [['"', 'यह', 'अपने', 'भाई', 'के', 'बारे', 'में', 'है', '।']] ['हमारे', 'बारे', 'के', 'बारे', 'में', 'क्या', 'अपनी', 'हैं', '।']
# [['?', 'sir', ',', 'do', 'we', 'can', 'what']] [['हम', 'श्रीमान', ',', 'क्या', 'कर', 'सकते', 'हैं', '?']] ['हम', 'सही', 'हो', 'सकता', 'है', '?']
# [['.', 'moment', 'my', 'is', 'this']] [['यह', 'मेरा', 'समय', 'है।']] ['यह', 'मेरा', 'मेरा', 'है', '।']
# [['?', 'me', 'kidding', 'fucking', 'you']] [['आप', 'मज़ाक', 'कर', 'रहे', 'हैं', '?']] ['मुझे', 'मुझे', 'खाता', 'है', '?']
# [['.', 'coming', 'not', 'were', 'you', 'thought', 'she']] [['उसे', 'लग', 'रहा', 'था', 'तुम', 'आओगे', 'ही', 'नहीं।']] ['वह', 'तुम्हें', 'नहीं', 'करना', 'चाहिए', '।']
# [['.', 'andrew', ',', 'this', 'about', 'sorry']] [['ऐंड्रऊ', 'इसके', 'लिए', 'माफ़', 'करना', '।']] ['इस', 'बारे', 'में', ',', 'एक', 'आया', '।']
# [['.', 'you', 'for', 'waiting', 'be', 'well']] [['हम', 'तुम्हारा', 'इंतज़ार', 'करेंगे।']] ['हम', 'आप', 'के', 'लिए', 'इंतजार', 'कर', 'रहे', 'हैं।']
# [['?', 'anomaly', 'of', 'sort', 'what']] [['कैसी', 'अजीब', 'तरह', 'की', 'गढ़बड़ी', 'से', '?']] ['क्या', 'की', 'तरह', '?']
# [['.', 'here', 'it', 'keep', 'not', 'should', 'we']] [['हमें', 'इसे', 'यहाँ', 'नहीं', 'रखना', 'चाहिए', '।']] ['हम', 'यहाँ', 'से', 'भी', 'नहीं', 'करना', 'चाहिए', '।']
# [['.', 'level', 'that', 'at', 'not']] [['मैं', 'ऐसा', 'नहीं', 'है', 'कि', 'स्तर', 'पर']] ['कि', 'कोई', 'नहीं', ',', 'तरह', '।']
# [['.', 'alike', 'all', 'are', 'men', 'you']] [['पुरुष', ',', 'वे', 'सभी', 'समान', 'हैं।']] ['आप', 'सब', 'के', 'लिए', 'हैं', '।']
# [['.', 'east', 'blocks', 'two', 'bravo', 'take']] [['ब्रावो', 'दो', 'ब्लॉकों', 'पूर्व', 'ले', 'लो।']] ['बस', 'को', 'लो', 'के', 'साथ', 'मत', 'देखो', '।']
# [[']', 'rumbling', '[thunder', ']', 'ringing', 'bells', '[animal']] [['[पशु', 'घंटियां', 'बजती', 'है', ']', '[तूफान', 'की', 'गड़गड़ाहट', ']']] ['[महिला', ']']
# [['.', 'shiva', ',', 'us', 'between', 'formalities', 'no']] [['हमारे', 'बीच', 'में', 'कोई', 'औपचारिकता', 'नहीं,शिवा', '।']] ['कोई', 'मदद', 'के', 'साथ', ',', 'कोई', ',', 'वहाँ']
# [['.', 'bavaria', 'to', 'regards', 'my', 'give']] [['बवेरिया', 'को', 'मेरी', 'शुभकामनाएँ', 'देना', '।']] ['मेरी', 'मेरी', 'के', 'के', 'के', 'बाद', 'आदमी', '।']
# [['.', 'minute', 'a', 'for', 'sit']] [['एक', 'मिनट', 'के', 'लिए', 'बैठ', 'लो', '।']] ['एक', 'के', 'लिए', 'धन्यवाद', '।']
# [['.', 'it', 'did', 'fucking', 'i']] [['मैं', 'कमबख्त', 'ऐसा', 'किया', 'था', '।']] ['मैं', 'इसे', 'यह', 'कर', 'रहा', 'हूँ', '।']
# [['?', 'eboshi', 'lady', 'is', 'where']] [['लेडी', 'eboshi', 'कहां', 'है', '?']] ['हम', 'कहाँ', 'से', 'कहाँ', 'है', '?']
# [['.', 'mouth', 'a', 'had', 'she']] [['वह', 'एक', 'मुँह', 'था।']] ['वह', 'एक', 'है।']
# [['.', 'tech', 'my', 'wanted', 'always', 'he']] [['वह', 'हमेशा', 'मेरी', 'तकनीक', 'चाहता', 'था।']] ['वह', 'यहाँ', 'से', 'के', 'साथ', '।']
# [['.', 'now', 'leave', 'take', 'ill']] [['मैं', 'अब', 'जाना', 'चाहूँगा', '।']] ['मैं', 'यहाँ', 'और', 'हूँ', '।']
# [['.', 'go', 'to', 'got', 'i']] [['जानाwot']] ['मैं', 'कुछ', 'जाना', 'होगा।']
# [['.', 'ronnie', 'definitely', 'was', 'it', ',', 'yeah']] [['हां।', 'वह', 'रॉनी', 'ही', 'था।']] ['हाँ', ',', 'वह', 'था', 'से', 'था', '।']
# [['.', 'j', '.', 'mr', 'from', 'is', 'it']] [['यह', 'श्री', 'जे', 'से', 'है']] ['यह', 'श्री', 'हैं', '।', '।', '।']
# [['?', 'it', 'not', 'does', ',', 'hurts', 'it']] [['दुख', 'होता', 'है', ',', 'है', 'न', '?']] ['यह', 'सही', 'नहीं', 'है', ',', 'यह', '?']
# [['.', 'that', 'do', 'totally', 'should', 'you']] [['आप', 'पूरी', 'तरह', 'से', 'है', 'कि', 'क्या', 'करना', 'चाहिए', '।']] ['आप', 'के', 'लिए', 'नहीं', 'है', '।']
# [['.', 'dancing', 'me', 'taking', 'is', 'he']] [['उसने', 'मुझे', 'नाच', 'ले', 'रहा', 'है।']] ['वह', 'बात', 'कहा', 'कि', 'है', '।']
# [['!', 'us', 'catch', 'never', 'youll']] [['तुम', 'हमें', 'कभी', 'नहीं', 'पकड़', 'पाओगी', '!']] ['और', 'फिर', 'कभी', 'कभी', 'नहीं', 'कभी', 'नहीं', '!']
# [['?', 'me', 'for', 'looking', 'were', 'you']] [['तुम', 'मुझे', 'देख', 'रहे', 'थे', '?']] ['तुम', 'बस', 'उसे', 'चाहते', 'हो', '?']
# [['.', 'ride', 'cannot', 'herc', ',', 'sir']] [['सर', ',', 'herc', 'सवारी', 'नहीं', 'कर', 'सकते', '।']] ['ठीक', 'है', ',', 'कोई', 'या', 'अच्छा', 'नहीं', 'है', '।']
# [['.', 'friends', 'not', 'are', 'we']] [['हम', 'दोस्त', 'नहीं', 'हैं', '।']] ['हम', 'यहाँ', 'नहीं', 'कर', 'रहे', 'हैं', '।']
# [['?', 'elbow', 'your', 'scrape', 'you', 'did']] [['आप', 'अपनी', 'कोहनी', 'परिमार्जन', 'था', '?']] ['आप', 'अपने', 'कैसे', 'को', 'करते', 'हो', '?']
# [['?', 'bell', 'a', 'want', 'you', 'not', 'do']] [['तुम्हें', 'घंटी', 'नहीं', 'चाहिए', 'क्या', '?']] ['क्या', 'तुम', 'एक', 'कुछ', 'नहीं', 'सकता', 'है', '?']
# [['.', 'friend', 'dear', 'a', 'was', 'she']] [['वह', 'एक', 'प्रिय', 'दोस्त', 'था', '।']] ['वह', 'एक', 'फिर', 'से', 'एक', 'थी', '।']
# [['.', 'anything', 'bring', 'not', 'did', 'i']] [['मैं', 'कुछ', 'भी', 'नहीं', 'लाई', '।']] ['मैं', 'कुछ', 'भी', 'नहीं', 'ले', 'सकता', 'है', '।']
# [['.', 'words', 'waste', 'to', 'want', 'never']] [['कभी', 'शब्द', 'बर्बाद', 'करना', 'चाहते', 'हैं।']] ['हम', 'फिर', 'से', 'कुछ', 'होगा', '।']
# [['.', 'workaholic', 'a', 'much', 'very']] [['बहुत', 'ज्यादा', 'एक', 'काम', '।']] ['बहुत', 'एक', 'हो', 'सकता', 'है', '।']
# [['.', 'pete', ',', 'better', 'fucking', 'never']] [['सब', 'बढ़िया', ',', 'विन्सेंट', '?', 'एकदम', 'बढ़िया', ',', 'पीट।']] ['कोई', 'फिर', 'नहीं', ',', 'श्री', 'सकता', 'है', '।']
# [['.', 'son', 'my', 'hit', 'bastard']] [['कमीने', 'मेरे', 'बेटे', 'को', 'मारा', '।']] ['मेरे', 'हाथ', 'से', 'बेटे', '।']
# [['.', 'land', 'my', 'love', 'i']] [['मुझे', 'अपनी', 'जमीन', 'से', 'प्यार', 'है', '।']] ['मैं', 'अपने', 'माँ', 'को', 'पता', 'है', '।']
# [['.', 'blood', 'same', 'the', 'have', 'we']] [['हम', 'में', 'एक', 'ही', 'खून', 'है', '।']] ['हमें', 'हमें', 'कुछ', 'की', 'जरूरत', 'है', '!']
# [['!', 'forever', 'need', 'not', 'do', 'we']] [['हम', 'हमेशा', 'के', 'िलए', 'जरूरत', 'नहीं', 'है', '!']] ['हम', 'उसे', 'काम', 'नहीं', 'हैं', '!']
# [['?', 'serious', 'you', 'are']] [['आप', 'गंभीर', 'हैं', '?']] ['तुम', 'कौन', 'हो', '?']
# [['?', 'himself', 'kills', 'he', 'if', 'what']] [['क्या', 'होगा', 'अगर', 'वह', 'खुद', 'को', 'मार', 'ले', '?']] ['वह', 'वहाँ', 'क्या', 'है', '?']
# [['.', 'home', 'at', 'yourself', 'make', 'just']] [['बिल्कुल', 'आराम', 'से', 'बैठो', '।']] ['मेरे', 'घर', 'से', 'साथ', 'हैं।']
# [['.', 'dream', 'this', 'had', 'i']] [['मैं', 'यह', 'सपना', 'था', '।']] ['मैं', 'इस', 'यह', 'हूँ', '।']
# [['.', 'say', 'readings', 'the', 'what', 'is', 'that']] [['आंकड़े', 'भी', 'यही', 'कहते', 'हैं।']] ['कि', 'क्या', 'कि', 'क्या', 'मतलब', 'है', '।']
# [['.', 'dance', 'not', 'do', 'i', ',', 'really', 'i']] [['मैं', 'वास्तवमें', ',', 'मैंनृत्य', 'नहींकरते']] ['मुझे', 'पता', 'है', ',', 'मैं', 'पता', 'है', '।']
# [['.', 'miracle', 'a', 'need', 'you']] [['आप', 'एक', 'चमत्कार', 'की', 'जरूरत', 'है।']] ['तुम', 'एक', 'और', 'तरह', 'हो।']
# [['?', 'around', 'you', 'introduce', 'ill']] [['मैं', 'तुमको', 'सबसे', 'मिलवा', 'दूंगा', '।']] ['मैं', 'तुम्हें', 'क्यों', 'लगा', '?']
# [['?', 'go', 'you', 'can', 'where', 'and']] [['और', 'तुम', 'कहाँ', 'जा', 'सकते', 'हो', '?']] ['और', 'तुम', 'कहाँ', '?']
# [['.', 'open', 'eyes', 'your', 'keep', ',', 'guys']] [['दोस्तों', ',', 'अपनी', 'आँखें', 'खुली', 'रखो', '।']] ['दिया', ',', 'अपने', 'बेटे', 'के', 'लिए', '।']
# [['.', 'scared', 'im', ',', 'dad']] [['पापा', ',', 'मुझे', 'डर', 'लग', 'रहा', 'है।']] ['मैं', ',', 'तुम्हें', 'मिल', 'गया', '।']
# [['.', 'always', 'you', 'with', 'be', 'ill']] [['मैं', 'हमेशा', 'तुम्हारे', 'साथ', 'होगा', '।']] ['मैं', 'तुम्हें', 'भी', 'और', 'याद', 'किया', '।']
# [['.', 'one', 'important', 'the', 'are', 'you']] [['तुम', 'महत्वपूर्ण', 'हो', '।']] ['आप', 'एक', 'हैं', '।']
# [['.', 'really', ',', 'nothing', 'is', 'this']] [['यह', 'कोई', 'बड़ी', 'बात', 'नहीं', 'है', ',', 'सच', 'में।']] ['यह', 'नहीं', 'है', ',', 'है।']
# [['?', 'matter', 'the', 'something', 'ls', ')', '(sighing']] [['(sighing', ')', 'रास', 'कुछ', 'बात', 'है', '?']] ['के', 'साथ', 'के', 'नीचे', 'को', 'आया', 'की', 'तरह', '?']
# [['?', 'you', 'treating', 'wife', 'the', 'is', 'how']] [['पत्नी', 'तुम्हारा', 'इलाज', 'कैसा', 'कर', 'रही', 'है', '?']] ['यहाँ', 'के', 'पिता', 'आप', 'के', 'बारे', 'में', 'क्या', 'है', '?']
# [['.', 'apartments', 'with', 'dealt', 'formerly', ',', 'calabrese']] [['calabrese', 'पहले', 'अपार्टमेंटों', 'का', 'इलाज', 'किया', '।']] ['सेना', ',', 'सेना', 'के', 'साथ', 'गया', 'है', '।']
# [['.', 'this', 'believe', 'not', 'ca', 'i']] [['मैं', 'नहीं', 'मान', 'सकता', '।']] ['मुझे', 'यह', 'नहीं', 'लगता', 'है', '।']
# [['.', 'die', 'just', 'almost', 'we']] [['हम', 'लगभग', 'बस', 'मर', 'जाते', 'हैं', '।']] ['हम', 'बस', 'की', 'जरूरत', 'है', '।']
# [['.', 'sister', 'my', 'was', 'she']] [['वह', 'मेरी', 'बहन', 'थी।']] ['वह', 'मेरी', 'माँ', 'था', '।']
# [['!', 'doors', 'new', 'opens', 'it']] [['उससे', 'नए', 'रास्ते', 'खुल', 'जाएँगे', '!']] ['यह', '!']
# [['.', 'bet', 'rich', 'a', 'is', 'that']] [['यह', 'एक', 'बड़ा', 'दांव', 'है', '।']] ['यही', 'कारण', 'है', 'कि', 'एक', 'और', 'बहुत', 'है।']
# [['?', 'there', 'over', 'get', 'to', 'how']] [['हम', 'वहाँ', 'कैसे', 'जायेंगे', '?']] ['वहाँ', 'वहाँ', 'क्या', 'है', '?']
# [[')', 'chirping', 'birds', '(']] [['(चहकतीपक्षियों', ')']] ['पांडा', ')']
# [['!', 'leaving', 'is', 'truck', 'the', '!', 'up', 'hurry']] [['जल्दी', 'करो', 'ट्रक', 'छूट', 'रहा', 'है']] ['रहे', 'गंदा', 'नहीं', 'तुम्हारा', '!']
# [['"', '.', '"hat', 'said', 'i', '?', 'language', 'what']] [['कौनसी', 'भाषा', 'मैंने', 'कहा', ',', '"टोपी।', '"', '?']] ['क्या', 'मुझे', 'क्या', 'किया', '।', '।', '।']
# [['.', 'same', 'the', 'do', 'would', 'i']] [['मैं', 'भी', 'ऐसा', 'ही', 'होगा', 'मुझे', 'क्या', 'करना', 'होगा', '।']] ['मैं', 'नहीं', '।']
# [['!', 'have', 'you', 'confidence', 'great', 'what']] [['क्या', 'आत्मविश्वास', 'है', 'तुम्हारा', '!']] ['तुम्हें', 'पता', 'है', 'क्या', 'मतलब', 'है', '?']
# [['.', 'accomplice', 'an', 'not', 'im']] [['मैं', 'एक', 'सहअपराधी', 'नहीं', 'हूँ', '।']] ['मैं', 'इस', 'नहीं', 'हूँ', '।']
# [['.', 'life', 'my', 'want', 'l']] [['मैं', 'अपनी', 'जान', 'चाहता', 'हूँ', '।']] ['मेरे', 'पिता', 'और', 'मैं', 'है।']
# [['"', '.', 'air', 'the', 'in', 'hands']] [['हाथ', 'उपर', '।', '"']] ['क्या', 'करने', 'के', 'लिए', 'में', '।', '।', '।']
# [['.', 'leonard', ',', 'story', 'your', 'tell']] [['अपनी', 'कहानी', ',', 'लियोनार्ड', 'बताओ', '।']] ['अपनी', 'अपनी', 'के', 'बारे', 'में', ',', 'जा', 'रहा', 'हूँ', '।']
# [['.', 'hell', 'in', 'belong', 'you']] [['तुम्हें', 'नरक', 'में', 'हैं', '।']] ['तुम', 'में', 'में', 'में', 'देखो', '।']
# [['.', 'side', 'that', 'turn', ',', 'then']] [['तब,उस', 'ओर', 'मुड़', 'जाओ', '।']] ['तो', ',', 'यह', 'एक', 'और', 'तरह', 'नहीं', 'है।']
# [['.', 'dead', 'is', 'arryn', 'jon']] [['जॉन', 'arryn', 'मर', 'चुका', 'है।']] ['पुरुष', 'की', 'की', 'तरह', 'की', 'है', 'है।']
# [['?', 'right', ',', 'dollar', 'a', 'for', 'anything']] [['एक', 'डॉलर', 'के', 'लिए', 'कुछ', 'भी', 'है', ',', 'है', 'ना', '?']] ['एक', 'है', 'की', ',', 'हमेशा', 'के', 'बारे', 'की', '?']
# [[')', 'clamoring', ',', 'drumming', '(']] [['(ढोल', ',', 'clamoring', ')']] ['नहीं', ',', 'संगीत', 'के', 'लिए', ')']
# [['.', 'it', 'take', 'will', 'we']] [['हम', 'इसे', 'ज़ब्त', 'कर', 'लेंगे', '।']] ['हम', 'इस', 'की', 'जरूरत', 'है', '।']
# [['.', 'busy', 'very', 'is', 'marwood', '.', 'mr']] [['श्री', 'marwood', 'बहुत', 'व्यस्त', 'है', '।']] ['अब', 'बहुत', 'वह', 'रहे', 'हैं', '।']
# [['.', 'you', 'with', 'wrong', 'something', 'is', 'there']] [['तुम्हारे', 'साथ', 'कुछ', 'तो', 'गड़बड़', 'है।']] ['कोई', 'भी', 'और', 'कुछ', 'भी', 'नहीं', 'है', '।']
# [['.', 'before', 'one', 'used', 'never', 'ive']] [['मैं', 'पहले', 'एक', 'का', 'इस्तेमाल', 'नहीं', 'किया', '।']] ['उन्होंने', ',', 'कभी', 'कभी', 'नहीं', 'था', '।']
# [['?', 'right', 'all', 'she', 'is', '.', '.', '.', 'ssansa']] [['एस', 'sansa', '।', '।', '।', 'वह', 'सब', 'सही', 'है', '?']] ['और', '।', '।', '।', 'कि', 'एक', 'बात', 'मिल', 'गया', 'है', '?']
# [[']', 'chatter', 'dispatch', 'police', '[']] [['[पुलिस', 'प्रेषण', 'बकवास', ']']] ['आपके', ']', ']']
# [['questioning', 'for', 'wanted', 'both', '..are', '.', '"']] [['"', '।', '।', '।', 'पूछताछ', 'के', 'लिए', 'आवश्यक', 'दोनों', 'हैं']] ['नहीं', ']']
# [['.', 'something', 'do', 'just', ',', 'phil']] [['फिल', ',', 'बस', 'कुछ', 'करो', '।']] ['ठीक', 'है', ',', 'बस', 'करो', '।']
# [['.', 'heroes', 'as', 'them', 'know', 'we']] [['हमनायकके', 'रूपमें', 'उन्हेंपता']] ['हम', 'बस', 'की', 'जाना', 'मिल', 'गया', 'है', '।']
# [['.', 'version', 'james', 'king', 'the', 'is', 'that']] [['राजा', 'जेम्स', 'संस्करण', 'है', '।']] ['कि', 'यह', 'कैसे', 'है', 'कि', 'है।']
# [['.', 'to', 'want', 'not', 'do', 'i']] [['मैं', 'करने', 'के', 'लिए', 'नहीं', 'करना', 'चाहती।']] ['मैं', 'नहीं', 'करना', 'चाहिए', '।']
# [['.', 'james', ',', 'me', 'all', 'was', 'it']] [['सबकी', 'मौत', 'के', 'पीछे', 'का', 'कारण', 'मैं', 'ही', 'था', ',', 'जेम्स।']] ['यह', 'है', ',', 'मुझे', 'था', '।']
# [['.', 'operation', 'the', 'from', 'likely', 'most']] [['अधिकांश', 'ऑपरेशन', 'की', 'वजह', 'से', 'है', '।']] ['से', 'जाओ', '।']
# [['.', 'floored', 'was', 'i', ',', 'yes']] [['हाँ', ',', 'मैं', 'फिदा', 'हो', 'गया', 'था।']] ['हाँ', ',', 'मैं', 'था', 'से', '।']
# [['?', 'agents', 'mi', 'watch', 'you']] [['तुम', 'एमआइ', 'पर', 'निगरानी', 'रखते', 'हो', '?']] ['आप', 'कुछ', 'ठीक', 'हैं', '?']
# [['.', 'be', 'is', 'e', 'b']] [['बी', 'ई', 'होता', 'है', 'बी', '।']] ['वहाँ', 'है', 'तुम', 'देखो', '।']
# [['?', 'it', 'not', 'was', ',', 'stupid', 'was', 'it']] [['यह', 'बेवकूफ', 'था', ',', 'है', 'ना', '?']] ['यह', 'है', 'कि', 'था', ',', 'नहीं', 'था', '?']
# [['?', 'murderer', 'me', 'call', 'you']] [['तुम', 'मुझे', 'कातिल', 'कहते', 'हैं', '?']] ['तुम', 'मुझे', 'सुन', 'रहे', 'हो', '?']
# [[',', 'once', 'this', 'for', 'but']] [['लेकिन', 'इस', 'बार', 'के', 'लिए', ',']] ['आप', 'इस', 'लिए', 'के', 'लिए', ',', 'तरह', 'तरह', 'से', 'ठीक', 'है']
# [['?', 'bill', ',', 'do', 'you', 'do', 'how']] [['तुम', 'कैसे', 'हो', ',', 'बिल', '?']] ['आप', 'कैसे', ',', 'आप', 'को', 'हैं', '?']
# [['.', 'talk', 'pep', 'your', 'is', 'there']] [['वहाँ', 'अपने', 'स्फूर्ति', 'बात', 'है।']] ['कोई', 'कोई', 'बात', 'क्या', 'कर', 'रहा', 'है', '।']
# [['.', 'revealed', 'risk', 'not', 'can', 'i']] [['मुझे', 'पता', 'चला', 'जोखिम', 'नहीं', 'कर', 'सकते', 'हैं', '।']] ['मैं', 'नहीं', 'नहीं', 'कर', 'सकते', '।']
# [['.', 'arranged', 'be', 'can', 'that']] [['इसका', 'बंदोबस्त', 'किया', 'जा', 'सकता', 'है।']] ['कि', 'आप', 'काम', 'कर', 'सकते', 'हैं', '।']
# [['.', 'to', 'points']] [['से', 'अंक', '।']] ['कुछ', 'पर', 'हैं।']
# [['?', 'me', 'let', 'not', 'wo', 'you']] [['तुम', 'मुझे', 'नहीं', 'होने', 'देंगे', '?']] ['तुम', 'मुझे', 'क्यों', 'नहीं', 'कर', 'सकते', 'हैं', '।']
# [['?', 'it', 'like', 'you', 'do', 'how']] [['तुमको', 'यह', 'कैसा', 'लगा', '?']] ['आप', 'यह', 'कैसे', 'किया', '?']
# [['.', 'is', 'name', 'your', 'whatever']] [['आपका', 'नाम', 'है', 'जो', 'भी', 'हो', '।']] ['नाम', 'नाम', 'के', 'लिए', 'आ', 'रहा', 'है', '।']
# [['?', 'home', 'go', 'we', 'can', ',', 'aunty']] [['चाची', ',', 'हम', 'घर', 'जा', 'सकते', 'हैं', '?']] ['ठीक', 'है', ',', 'हम', 'ठीक', 'है', 'कि', 'बस', 'की', '?']
# [['?', 'papers', 'got', 'you', 'have']] [['क्या', 'आपके', 'पास', 'कागज़ात', 'हैं', '?']] ['आप', 'कुछ', 'मिला', 'है', '?']
# [['!', 'off', 'this', 'turn', ',', 'right']] [['साथसाथ', 'दबाओ।', 'ठीक।']] ['ठीक', 'है', ',', 'यहाँ', 'से', '!']
# [['?', 'wrong', 'is', 'what', ',', 'edward']] [['~', 'एडवर्ड', ',', 'क्या', 'हुआ', '~', '?']] ['ठीक', 'है', ',', 'क्या', 'वह', 'है', '?']
# [[')', 'ringing', 'phone', '(mobile']] [['(मोबाइल', 'फोन', 'बज', ')']] ['lachamma', ')']
# [['.', 'inside', 'you', 'for', 'ready', 'are', 'we']] [['हम', 'अंदर', 'आप', 'के', 'लिए', 'तैयार', 'कर', 'रहे', 'हैं।']] ['हम', 'आप', 'के', 'लिए', 'हैं', '।']
# [['.', 'belle', 'is', 'name', 'my']] [['मेरा', 'नाम', 'बेले', 'है', '।']] ['मेरा', 'नाम', 'नाम', 'है', '।']
# [['!', 'privileged', 'the', 'to', 'power']] [['चुनिंदा', 'लोगों', 'को', 'शक्ति', 'मिले', '!']] ['मैं', 'इस', 'की', 'तरह', 'की', 'जरूरत', 'है', '!']
# [['.', 'light', 'led', 'a', 'is', 'this']] [['यह', 'एक', 'एलईडी', 'प्रकाश', 'है।']] ['यह', 'एक', 'एक', 'वास्तविक', 'है।']
# [['.', 'number', 'that', 'them', 'give']] [['उन्हें', 'यह', 'नम्बर', 'दे', 'दो', '।']] ['वह', 'तुम्हें', 'सब', 'दे', '।']
# [['!', 'hey', '!', 'finished', 'not', 'are', 'we', ',', 'no']] [['नहीं', ',', 'हम', 'समाप्त', 'नहीं', 'कर', 'रहे', 'हैं', '!']] ['नहीं', ',', 'हम', 'एक', 'नहीं', 'है', '!']
# [['.', 'involved', 'hope', 'want', 'not', 'do', 'we']] [['हमें', 'उम्मीद', 'है', 'शामिल', 'नहीं', 'करना', 'चाहती।']] ['हम', 'यहाँ', 'से', 'नहीं', 'करना', 'चाहिए', '।']
# [['.', '"', '"keys', 'saying', 'kept', 'just', 'she']] [['वह', 'सिर्फ', '"कुंजी', '"', 'कह', 'रखा', 'है', '।']] ['वह', 'सिर्फ', 'और', 'कुछ', 'नहीं', 'किया', 'था', '।']
# [['.', 'zombies', 'jade', 'of', 'kind', 'some']] [['हरे', 'ज़ोम्बी', 'जैसे', 'दिखते', 'हैं।']] ['एक', 'पिता', 'के', 'लिए', 'धन्यवाद', 'के', 'लिए', '।']
# [['?', 'i', 'was', 'where', 'and']] [['और', 'मैं', 'कहाँ', 'थी', '?']] ['और', 'मैं', 'कोई', 'कहाँ', 'किया', '?']
# [['.', 'back', 'him', 'give', 'must', 'we']] [['हिरण', 'परमेश्वर', 'ने', 'अपने', 'घाव', 'चंगा', 'है', '?', '!']] ['हम', 'वापस', 'मदद', 'वापस', 'करते', 'हैं', '।']
# [['.', 'down', 'way', 'long', 'a', 'is', 'it']] [['यह', 'काफी', 'नीचे', 'है', '।']] ['यह', 'एक', 'एक', 'कंपनी', 'की', 'है।']
# [['.', 'volatile', 'highly', 'is', 'process', 'the']] [['प्रक्रिया', 'अत्यधिक', 'अस्थिर', 'है।']] ['ये', 'अच्छा', 'में', 'है', '।']
# [['.', 'po', ',', 'gone', 'all', 'is', 'it']] [['पो', ',', 'सब', 'खत्म', 'हो', 'गया।']] ['यह', 'सब', ',', 'यह', 'हूँ', '।']
# [['.', 'sir', ',', 'moment', 'your', 'is', 'this']] [['सर।']] ['यह', 'मेरा', 'दोस्त', 'है', ',', 'है।']
# [['.', 'karma', 'that', 'call', 'they']] [['वे', 'कहते', 'हैं', 'कि', 'कर्म', 'कहते', 'हैं', '।']] ['वे', 'सब', 'तरह', 'कैसे', '।', '।', '।']
# [['.', 'brave', 'truly', 'are', 'you']] [['तुम', 'सच', 'में', 'बहादुर', 'हैं', '।']] ['आप', 'एक', 'हैं', '।']
# [['?', 'that', 'understand', 'you', 'do']] [['आप', 'समझते', 'हैं', 'कि', 'क्या', 'है', '?']] ['क्या', 'आप', 'यह', 'करना', 'चाहिए', '?']
# [['.', 'm', 'a', 'is', 'it']] [['बजे', 'हैं।']] ['यह', 'एक', 'एक', 'है', '।']
# [['.', 'simon', ',', 'back', 'coming', 'not', 'is', 'she']] [['वह', 'साइमन', ',', 'वापस', 'नहीं', 'आ', 'रही', 'है', '।']] ['हम', 'सही', 'नहीं', 'है', ',', 'यह', 'श्री', 'हैं', '।']
# [['.', 'friendly', 'particularly', 'not', 'were', 'folks', 'these']] [['वहाँ', 'के', 'लोग', 'स्नेहशील', 'नहीं', 'थे।']] ['उसे', 'लिए', 'नहीं', 'तरह', 'कर', 'रहे', 'हैं', '।']
# [['?', 'wrong', 'me', 'prove', 'gonna', 'is', 'who']] [['कौन', 'मुझे', 'गलत', 'साबित', 'करेगा', '?']] ['मुझे', 'कौन', 'कौन', 'है', '?']
# [['?', 'yet', 'there', 'we', 'are', ')']] [[')', 'हम', 'अभी', 'तक', 'कर', 'रहे', 'हैं', '?']] ['हमारे', 'वहाँ', 'वहाँ', 'से', 'बाहर', '?']
# [['!', 'tim', ',', 'up', 'hang', 'not', 'do']] [['फ़ोन', 'मत', 'काटना', ',', 'टिम', '!']] [',', 'मत', 'मत', 'करो', '!']
# [['?', 'today', 'start', 'gonna', 'you', 'so']] [['आज', 'तुम', 'शुरू', 'करोगे', 'तो', '?']] ['तो', 'तुम', 'कहाँ', 'हो', '?']
# [['.', 'nothing', 'do', 'not', 'ca', 'you']] [['आप', 'हाथ', 'पर', 'हाथ', 'रखे', 'नहीं', 'बैठे', 'रह', 'सकते', '।']] ['तुम', 'नहीं', 'नहीं', 'हो।']
# [['?', 'options', 'the', 'are', 'where']] [['कहाँ', 'विकल्प', 'क्या', 'हैं', '?']] ['हम', 'कहाँ', 'जा', 'रहे', 'हैं', '?']
# [['!', 'moved', 'be', 'not', 'ca', 'he']] [['उसे', 'नहीं', 'ले', 'जा', 'सकते', '!']] ['वह', 'कभी', 'नहीं', 'नहीं', '!']
# [['.', 'them', 'with', 'reason', ',', 'please']] [['कृपया', ',', 'उन', 'लोगों', 'के', 'साथ', 'कारण', '।']] ['पहले', 'से', 'हाथ', 'से', '"']
# [[')', 'hissing', 'gas', '(']] [['(गैसhissing', ')']] ['स्पष्ट', ')']
# [['.', 'much', 'so', 'you', 'miss', 'i']] [['मुझे', 'तुम्हारी', 'बहुत', 'याद', 'आती', 'है।']] ['मैं', 'तुम्हें', 'तुम्हारे', 'साथ', 'था', '।']
# [['.', 'forward', 'step', 'you', ',', 'pelle']] [['पेले', ',', 'आगे', 'कदम', 'बढ़ाओ', '।']] ['ठीक', 'है', ',', 'तुम', 'मदद', 'से', '।']
# [['jaegers', 'remaining', 'all', 'take', 'to']] [['शेष', 'सभी', 'jaegers', 'लेते', 'हैं']] ['तुम', 'उसे', 'ले', 'ले', 'ले', 'लो', '।']
# [['.', 'doubts', 'any', 'have', 'not', 'do']] [['कोई', 'शक', 'नहीं', 'है।']] ['नहीं', 'मत', 'करो', '।']
# [['.', 'stars', 'movie', 'of', 'lots']] [['बहुत', 'सारे', 'फिल्मी', 'सितारे', '।']] ['एक', 'की', 'तरह', 'से', 'एक', 'है।']
# [['.', 'live', 'you', 'let', 'shall', 'i']] [['मैं', 'तुम्हें', 'रहने', 'दे', 'रहा', 'हूँ']] ['मुझे', 'लगता', 'है', 'कि', '।']
# [['?', 'up', 'grow', 'never', 'you', 'will']] [['तुम', 'कभी', 'बड़ी', 'नहीं', 'होगी', '?']] ['तुम्हें', 'कुछ', 'कभी', 'नहीं', 'चाहिए', '?']
# [['.', '.', '.', 'used', ',', 'dashes', 'and', 'dots']] [['जिसमे', 'dots', 'और', 'dashes', 'का', ',', 'इस्तेमाल', 'होता', 'है', '।', '।', '।']] ['और', 'भी', ',', 'और', 'सकता', 'है', ',', 'तुम', '।', '।', '।']
# [['.', 'yours', 'learn', 'to', 'like', 'id']] [['मैं', 'तुम्हारा', 'सीखना', 'चाहते', 'हैं', '।']] ['मैंने', 'उसे', 'सकते', 'हो', '।']
# [['.', 'job', 'this', 'need', 'i', ',', 'christ']] [['ईश्वर', ',', 'मुझे', 'काम', 'चाहिए', 'था।']] ['देखो', ',', 'मैं', 'इसे', 'इसे', 'ले', 'हैं।']
# [['.', 'concern', 'my', 'voicing', 'just', 'im']] [['मैं', 'सिर्फ', 'अपनी', 'चिंता', 'व्यक्त', 'करता', 'हूँ', '।']] ['मैं', 'मैं', 'अपने', 'हूँ', 'को', 'रहा', 'हूँ', '।']
# [['.', 'me', 'to', 'them', 'bring']] [['उन्हें', 'मेरे', 'पास', 'लेकर', 'आओ।']] ['मुझे', 'और', 'मुझे', 'सुनो', '।']
# [['.', 'him', 'want', 'not', 'do', 'i']] [['मुझे', 'ये', 'कबूल', 'नहीं', '।']] ['मैं', 'उसे', 'नहीं', 'नहीं', '।']
# [['.', 'too', ',', 'home', 'my', 'is', 'this']] [['यह', 'मेरा', 'भी', 'घर', 'है', '।']] ['यह', 'एक', 'है', ',', 'यह', 'है।']
# [['.', 'seriously', ',', 'you', 'begging', 'im', ',', 'please']] [['कृपया', ',', 'मैं', 'तुम्हें', 'भीख', 'माँग', 'रहा', 'हूँ', ',', 'गंभीरता', 'से।']] ['ओह', ',', 'मैं', 'तुम्हें', 'प्यार', 'करता', 'हूँ', ',', 'आप', 'की', 'जरूरत', 'है', '।']
# [['?', 'yourself', 'it', 'design', 'you', 'did']] [['क्या', 'आपने', 'खुद', 'डिजाइन', 'की', '?']] ['आप', 'यह', 'ठीक', 'है', '?']
# [['?', 'go', 'you', 'whered', ',', 'hey']] [['ए', ',', 'तुम', 'कहाँ', 'चले', 'गए', '?']] ['अरे', ',', 'तुम', 'तो', '?']
# [['.', 'nothing', 'him', 'owes', 'he']] [['वह', 'उसे', 'कुछ', 'भी', 'नहीं', 'बकाया', 'है।']] ['वह', 'उसे', 'उसे', 'नहीं', 'किया', 'गया', '।']
# [[']', 'ringing', 'chimes', 'wind', '[']] [['[पवन', 'बज', 'झंकार', ']']] ['उनमें', 'की', ']']
# [['!', 'debt', 'in', 'not', 'are', 'you']] [['आप', 'कर्ज', 'में', 'नहीं', 'कर', 'रहे', 'हैं', '!']] ['तुम', 'नहीं', 'में', 'तुम', 'नहीं', 'हो', '!']
# [['.', 'up', 'shut', 'gonna', 'im']] [['मैं', 'चुप', 'रहा', 'हूँ', '।']] ['मैं', 'अपने', 'जाएगा', 'को', 'जा', 'रहा', 'हूँ।']
# [['.', 'daylight', 'is', 'it', 'me', 'tell', 'please']] [['कृपया', 'मुझे', 'बताओ', 'कि', 'यह', 'दिन', 'के', 'उजाले', 'करें', '।']] ['मुझे', 'लगता', 'है', 'कि', 'मैं', 'यहाँ', 'से', 'लिए', 'है।']
# [['!', 'street', 'the', 'off', 'get']] [['सड़क', 'से', 'परे', '!']] ['उसे', 'जाओ', 'जाओ', '!']
# [['!', 'po', 'for', 'is', 'food', 'that']] [['वह', 'खाना', 'पो', 'के', 'लिए', 'है', '!']] ['वह', 'एक', 'अच्छा', 'एक', 'है', '!']
# [['.', 'darren', ',', 'this', 'stop', 'can', 'you']] [['तुम्हें', 'पता', 'है', ',', 'डैरेन', 'इस', 'रोक', 'सकता', 'है।']] ['आप', 'यह', 'है', ',', 'आप', 'किया', 'था', '।']
# [['.', 'you', 'with', 'back', 'get', 'well']] [['हम', 'आप', 'के', 'साथ', 'वापस', 'मिल', 'जाएगा', '।']] ['हम', 'वापस', 'वापस', 'वापस', 'करते', 'हैं', '।']
# [['.', 'oogway', 'master', 'of', 'heard', 'weve']] [['गुरू', 'ऊगवे', 'का', 'नाम', 'सुना', 'है।']] ['वहाँ', 'की', 'तरह', 'की', 'जरूरत', 'है', '।']
# [['.', '.', '.', 'cock', 'her', 'lost', 'lachamma']] [['lachamma', 'lost', 'her', 'cock', '।', '।', '।']] ['उसके', 'लिए', 'her', '।', '।', '।']
# [['.', 'it', 'leave', 'or', 'it', 'take']] [['इसे', 'लो', 'या', 'छोड़', 'दें', '।']] ['इसे', 'यह', 'ले', 'ले', 'लो', '।']
# [['.', 'it', 'made', 'you', 'but']] [['लेकिन', 'आप', 'इसे', 'बनाया', 'है।']] ['लेकिन', 'यह', 'तुम्हें', 'पता', 'था', '।']
# [['?', 'you', 'will', ',', 'step', 'your', 'watch']] [['अपने', 'कदम', 'को', 'देखो', ',', 'क्या', 'तुम', '?']] ['आप', 'मेरे', 'मदद', 'से', 'हैं', '?']
# [['?', 'right', ',', 'together', 'live', 'to', 'weve']] [['हमें', 'साथ', 'साथ', 'रहना', 'है,ना', '?']] ['हम', 'उन्हें', 'घर', ',', 'जनाब।']
# [['!', 'need', 'i', 'what', 'just']] [['नैन्सी', 'बस', 'इसी', 'की', 'कमी', 'थी', '!']] ['मेरे', 'क्या', 'कर', 'सकते', 'हैं', '!']
# [['?', 'me', 'watching', 'you', 'were']] [['तुम', 'मुझे', 'देख', 'रहे', 'थे', '?']] ['क्या', 'मैं', 'उसे', 'सुन', '?']
# [['.', 'him', 'to', 'close', 'us', 'get']] [['हमें', 'उसके', 'पास', 'जाओ', '।']] ['हमें', 'हमें', 'उसे', 'करने', 'के', 'लिए', 'जाना', 'है।']
# [['?', 'me', 'miss', 'gonna', 'you', 'are']] [['तुम', 'मुझे', 'याद', 'कर', 'रहा', 'है', '?']] ['आप', 'मेरे', 'लिए', 'कर', 'रहे', 'हैं', '?']
# [['.', 'on', 'walk', 'better', 'you', ',', 'yeah']] [['हाँ,तुमबेहतरपरचलते', 'हैं', '।']] ['हाँ', ',', 'तुम', 'हैं', '।']
# [['.', 'smartass', 'the', ',', 'right', 'him', 'serves']] [['smartass', ',', 'उसे', 'सही', 'कार्य', 'करता', 'है', '।']] ['कोई', 'घर', 'के', 'बारे', 'में', ',', 'बात']
# ...
# [['.', 'million', '.', 'million']] [['लाख', '।', 'लाख', '।']] ['।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।']
# [['.', 'mistake', 'my', 'was', 'it']] [['यह', 'मेरी', 'गलती', 'थी', '।']] ['यह', 'मेरी', 'था', 'कि', 'था', '।']
# [['.', 'day', 'nice', 'a', 'have']] [['अच्छा', 'दिन', 'रहा', '।']] ['एक', 'कुछ', 'एक', 'अच्छा']
# [['.', 'that', 'need', 'actually', 'i']] [['मैं', 'वास्तव', 'में', 'है', 'कि', 'जरूरत', 'है', '।']] ['मुझे', 'लगता', 'है', 'कि', 'एक', 'सकता', 'है', '।']
# [['!', 'cover', 'to', 'another', 'and']] [['और', 'एक', 'और', 'कवर', 'करने', 'के', 'लिए', '!']] ['और', 'मेरे', 'मेरे', 'साथ', 'नहीं', '!']
# [['?', 'at', 'me', 'remember', 'you']] [['तुम', 'मुझे', 'में', 'याद', 'है', '?']] ['मुझे', 'बस', 'बताओ', '।']
# [['.', 'in', 'on', 'go']] [['अब', 'ठीक', 'है', ',', 'धक्का']] ['चलो', 'पर', 'जाओ', '।']
# [['.', 'fun', 'much', 'so', 'was', 'kayaking']] [['नौकायन', 'कितना', 'मज़ेदार', 'था', '।']] ['तो', 'तो', 'एक', 'इंतजार', 'अच्छी', 'था', '।']
# [['.', 'wife', 'a', 'have', 'already', 'i']] [['मैं', 'पहले', 'से', 'ही', 'एक', 'पत्नी', 'है', '।']] ['मैं', 'एक', 'और', 'काम', 'भी', 'रहा', 'हूँ', '।']
# [['.', 'ruth', ',', 'him', 'to', 'it', 'give']] [[',', 'उसे', 'रूत', 'दे', '।']] ['यह', ',', 'अंदर', 'हूँ', '।']
# [['.', '.', '.', 'makes', 'times']] [['गुणा', 'बनता', 'है', '।', '।', '।']] ['।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।']
# [['?', 'same', 'the', 'they', 'not', 'are']] [['क्या', 'दोनो', 'एक', 'ही', 'नहीं', 'होते', '?']] ['आप', 'क्यों', 'नहीं', 'हैं', '?']
# [['.', 'five', 'in', 'there', 'be', 'ill']] [['मैं', 'पांच', 'में', 'नहीं', 'होगा', '।']] ['मैं', 'वहाँ', 'से', 'बाहर', 'मिल', 'जाएगा', '।']
# [['?', 'now', 'do', 'i', 'should', 'what']] [['अब', 'मुझे', 'क्या', 'करना', 'चाहिए', '?']] ['अब', 'क्या', 'मैं', 'क्या', 'हैं', '?']
# [['.', 'little', 'a', 'me', 'scares', 'that']] [['उनसे', 'मुझे', 'थोड़ा', 'डर', 'लगता', 'है', '।']] ['वह', 'बात', 'मुझे', 'एक', 'चाहिए', '।']
# [['.', 'hand', 'your', 'me', 'give']] [['अपना', 'हाथ', 'देना', '।']] ['मुझे', 'अपनी', 'मदद', 'की', 'जरूरत', 'है', '।']
# [['.', 'here', 'up', 'it', 'bring', ',', 'here']] [['यहाँ', 'ऊपर', 'लेकर', 'आओ।']] ['यहाँ', ',', 'यहाँ', 'से', 'जाओ', '।']
# [['?', 'sleeping', 'you', 'were']] [['सो', 'रही', 'थी', '?']] ['क्या', 'तुम्हें', 'देखा', 'है', '?']
# [['.', 'michele', 'don', ',', 'bye']] [['बाय', ',', 'डॉन', 'मिशेल', '।']] ['अब', ',', 'वहाँ', 'हैं।']
# [['.', 'thing', 'same', 'the', 'seeing', 'are', 'we']] [['हम', 'एक', 'ही', 'बात', 'देख', 'रहे', 'हैं']] ['हम', 'एक', 'बात', 'बाहर', 'रहे', 'हैं', '।']
# [['!', 'diaper', 'your', 'to', 'on', 'hang']] [['तैयार', 'हो', 'जाओ', '!']] ['अपने', 'अपने', 'अपने', 'ले', 'ले', '!']
# [['.', 'distresses', 'and', '.', '.', '.', 'respect', 'of', 'out']] [['सम्मान', 'से', '।', '।', '।', 'और', 'चिंताओं', '।']] ['के', 'साथ', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।']
# [['.', 'are', 'you', 'whoever', 'out', 'come']] [['कौन', 'हो', 'तुम', 'बताओ', '।']] ['आप', 'अभी', 'भी', 'यहाँ', 'हो', 'रहे', 'हैं', '।']
# [['?', 'alexander', ',', 'point', 'the', 'is', 'what', 'but']] [['लेकिन', 'मुद्दा', 'यह', 'है', ',', 'अलेक्जेंडर', 'क्या', 'है', '?']] ['लेकिन', 'मैं', 'क्या', 'गया', 'है', ',', 'है', '?']
# [['.', 'ella', 'was', 'name', 'her']] [['her', 'name', 'is', 'ella', '।']] ['उसका', 'नाम', 'तरह', 'की', 'तरह', 'है।']
# [['?', 'mean', 'it', 'does', 'what']] [['इसका', 'क्या', 'मतलब', 'है', '?']] ['क्या', 'मतलब', 'है', '?']
# [['.', 'beds', 'sharing', 'not', 'are', 'we']] [['हम', 'बिस्तर', 'साझा', 'नहीं', 'कर', 'रहे', 'हैं', '।']] ['हम', 'सही', 'नहीं', 'हैं', '।']
# [['.', 'hummingbird', 'is', 'this', ',', 'castle']] [['हम', 'हमिंगबर्ड', 'हैं।']] ['इस', 'है', ',', 'वहाँ', 'एक', 'है', '।']
# [['.', 'either', 'it', 'like', 'not', 'do', 'i']] [['मैं', 'यह', 'भी', 'पसंद', 'नहीं', 'है।']] ['मुझे', 'यह', 'पसंद', 'है', 'नहीं', 'करो', '।']
# [['.', 'there', 'down', 'going', 'are', 'we']] [['हन्ना', 'स्थिर', ',', 'स्थिर', ',', '।']] ['हम', 'वापस', 'जा', 'रहे', 'हैं', '।']
# [['.', 'alexander', 'of', 'sword', 'the', 'is', 'it']] [['यह', 'अलेक्जेंडर', 'की', 'तलवार', 'है।']] ['यह', 'वास्तविक', 'की', 'तरह', 'है', '।']
# [['.', 'before', 'baby', 'a', 'found', 'ive']] [['मैं', 'एक', 'बच्चा', 'मिला', 'है', 'पहले', '।']] ['मैं', 'एक', 'से', 'एक', 'की', 'तरह', 'की', 'जरूरत', 'है', '।']
# [['.', 'hand', 'your', 'me', 'give']] [['मुझे', 'अपना', 'हाथ', 'दो', '।']] ['मुझे', 'अपनी', 'मदद', 'की', 'जरूरत', 'है', '।']
# [['.', 'it', 'catch', 'to', 'supposed', 'are', 'you']] [['तो', 'इसे', 'पकड़ो', '।']] ['आप', 'इसे', 'करने', 'के', 'लिए', 'करना', 'चाहते', 'हैं', '।']
# [['.', 'engines', 'the', 'start', ',', 'pilot']] [['पायलट', ',', 'इंजन', 'चालू', 'करो', '।']] [',', 'लो', '।']
# [['.', 'them', 'beat', 'not', 'wo', 'cold', 'the']] [['ठंड', 'उन्हें', 'हरा', 'नहीं', 'होंगे।']] ['उन', 'नहीं', 'की', 'तरह', 'नहीं', 'हैं।']
# [['.', 'honest', 'all', 'are', 'we', 'here']] [['यहाँ', 'हम', 'सब', 'ईमानदार', 'हैं', '।']] ['हम', 'सब', 'वहाँ', 'यहाँ', 'हैं', '।']
# [['.', 'you', 'with', 'here', 'im']] [['मैं', 'तुम्हारे', 'साथ', 'यहाँ', 'हूँ', '।']] ['मैं', 'तुम्हारे', 'साथ', 'यहाँ', 'हूँ।']
# [['.', '.', 'aright', 'its', ',', 'aright', 'its']] [['इसके', 'दाहिनी', 'ओर', ',', 'इसके', 'दाहिनी', 'ओर', '।', '।']] ['बस', ',', 'इसे', 'ले', 'लो', '।']
# [['.', 'pod', 'first', 'on', 'visuals']] [['पहले', 'फली', 'पर', 'विजुअल्स', '।']] ['चलो', 'पर', '।', '।', '।']
# [['.', 'friends', 'are', 'they', 'guess', 'i', ',', 'why']] [['क्यों,मुझेलगताहैकिवे', 'दोस्त', 'हैं', 'लगता']] ['नहीं', ',', 'वे', 'मैं', 'किया', 'हूँ', '।']
# [['.', 'today', 'shoe', 'my', 'tied', 'i']] [['मैंआजमेराजूताबंधे', '/मैं']] ['मैं', 'अपने', 'था', 'को', 'मिल', 'मिल', 'गया', '।']
# [['?', 'feel', 'that', 'does', 'how']] [['यह', 'कैसा', 'लग', 'रहा', 'है', '?']] ['वह', 'कैसे', 'थी', '?']
# [['.', 'cameron', ',', 'down', 'gun', 'the', 'put']] [[',', 'कैमरून', 'बंदूक', 'नीचे', 'रखो', '।']] [',', 'पर', 'नीचे', 'रखो', '।']
# [['.', 'touch', 'in', 'already', 'are', 'we']] [['हम', 'पहले', 'से', 'ही', 'संपर्क', 'में', 'हैं', '।']] ['हम', 'में', 'ही', 'वापस', 'हैं', '।']
# [['.', 'cool', 'of', 'kind', 'is', 'it']] [['यह', 'सचमुच', 'शानदार', 'है', '।']] ['यह', 'कोई', 'है', 'की', 'तरह', 'है।']
# [[')', '(gunshot', '.', '.', '.', 'about', 'something', 'says', 'it']] [['इसके', 'बारे', 'में', 'कुछ', 'कहना', 'है', '।', '।', '।', '(बंदूक', 'की', 'गोली', ')']] ['यह', 'कुछ', 'के', 'लिए', 'अच्छा', 'है', '।']
# [['.', 'mouffetard', 'rue', ',', 'bretodeau', 'dominique']] [['dominique', 'bretodeau', ',', 'rue', 'mouffetard', '।']] ['के', 'ज्यादा', ',', 'नीचे', 'की', 'तरह', '।']
# [['!', 'it', 'do', 'can', 'you']] [['आप', 'यह', 'कर', 'सकते', 'हैं', '!']] ['आप', 'यह', 'कर', 'सकते', 'हैं', '!']
# [['.', 'it', 'about', 'worry', 'not', 'do']] [['इसके', 'बारे', 'में', 'चिंता', 'मत', 'करो', '।']] ['के', 'बारे', 'में', 'मत', 'करो', ',', 'यह', 'अच्छा', 'की', 'जरूरत', 'है', '।']
# [['?', 'blowie', 'a', 'after', 'minutes', 'ten']] [['तुम', 'सैम', 'से', 'ऐसे', 'बात', 'करते', 'हो', '?']] ['एक', 'बाहर', 'के', 'साथ', '?']
# [['.', 'gina', 'mean', 'not', 'do', 'i']] [['मैं', 'gina', 'की', 'बात', 'नहीं', 'कर', 'रही', 'हूँ।']] ['मुझे', 'मतलब', 'नहीं', 'है', '।']
# [['.', 'on', 'hold', ',', 'guys', ',', 'hey']] [['अरे', ',', 'दोस्तों', ',', 'रुको', '।']] ['अरे', ',', 'ले', ',', 'मैं', 'अंदर', 'हूँ']
# [['.', 'here', 'it', 'love', 'would', 'gilly']] [['गिली', 'इसे', 'यहाँ', 'अच्छा', 'लगेगा।']] ['हमें', 'काम', 'पर', 'हैं', '!']
# [['?', 'doing', 'you', 'are', 'what', ',', 'snotlout']] [['स्नॉटलाउट', ',', 'तुम', 'क्या', 'कर', 'रहे', 'हो', '?']] ['अरे', 'तुम', 'क्या', 'कर', 'रहे', 'हो', '?']
# [['.', 'work', 'not', 'does', 'standard', 'warning']] [['चेतावनी', 'मानक', 'काम', 'नहीं', 'करता', 'है', '।']] ['हम', 'कभी', 'नहीं', 'नहीं', '।']
# [['?', 'animals', 'take', 'you', 'do']] [['आप', 'जानवरों', 'लेते', 'हैं', '?']] ['आप', 'कहाँ', 'के', 'बारे', 'में', '?']
# [['.', 'here', 'you', 'put', 'i']] [['मैं', 'यहाँ', 'डाल', 'दिया', '।']] ['मैं', 'तुम्हें', 'साथ', 'सकता', 'हूँ', '।']
# [['.', 'raju', 'from', 'present', 'a', 'is', 'it']] [['यह', 'राजू', 'ने', 'दिया', 'है', '।']] ['यह', 'एक', 'एक', 'है', 'मैं', 'है।']
# [['.', 'sir', ',', 'best', 'my', 'do', 'ill']] [['मैं', ',', 'साहब', 'अपनी', 'पूरी', 'कोशिश', 'करेंगे', '।']] ['मैं', 'मैं', 'यहाँ', ',', 'अच्छा', 'की', 'तरह', 'है', '।']
# [['.', 'work', 'still', 'could', 'it']] [['अभी', 'भी', 'काम', 'कर', 'सकता', 'है', '।']] ['यह', 'अभी', 'भी', 'भी', 'आदमी', 'करता', 'है', '।']
# [['.', 'it', 'got', 'we', ',', 'yeah']] [['हाँ', ',', 'हम', 'इसे', 'मिला', 'है।']] ['अब', 'हम', 'सही', ',', 'वहाँ', '।']
# [['.', 'wrinklier', 'and', 'older', 'except']] [['सिवाय', 'बुढ़ापे', 'और', 'झुर्रियों', 'के।']] ['शायद', 'और', 'के', 'लिए', 'में।']
# [['.', 'ground', 'castle', 'is', 'this', ',', 'hummingbird']] [['हम', 'कैसल', 'ग्राउंड', 'हैं।']] ['हम', 'ठीक', 'है', ',', 'एक', 'और', 'हमें']
# [['.', 'another', 'one', 'respect', 'youll']] [['आप', 'एक', 'दूसरे', 'का', 'सम्मान', 'करेंगे', '।']] ['आप', 'एक', 'साथ', 'से', 'की', 'जरूरत', 'है', '।']
# [['?', 'noise', 'this', 'all', 'is', 'what']] [['क्या', 'यह', 'सब', 'शोर', 'है', '?']] ['यह', 'क्या', 'क्या', 'है', '?']
# [['.', 'you', 'to', 'next', 'sit', 'shed']] [['वो', 'तुम्हारे', 'बगल', 'में', 'बैठेगी', '।']] ['आप', 'को', 'नीचे', 'की', 'जरूरत', 'है', '।']
# [['?', 'island', 'south', 'the', 'from']] [['दक्षिण', 'द्वीप', 'से', '?']] ['तो', 'वहाँ', 'के', 'साथ', '?']
# [[']', 'language', 'native', 'speaking', '[man']] [['[पुरुष', 'अपनी', 'मातृभाषा', 'में', 'बोल', 'रहा', 'है', ']']] ['पुरुष', 'अपनी', 'मातृभाषा', 'में', 'बोल', 'रहा', 'है']
# [['?', 'children', 'your', 'see', 'you', 'do']] [['तुम्हे', 'अपने', 'बच्चे', 'दिखाई', 'दे', 'रहे', 'हैं', '?']] ['आप', 'अपने', 'हाथ', 'को', 'जा', 'रहे', 'हैं', '?']
# [['.', 'me', 'with', 'was', 'brother', 'my']] [['मेरा', 'भाई', 'मेरे', 'साथ', 'था', '।']] ['मेरे', 'साथ', 'साथ', 'और', 'मैं', 'पर', 'गर्व', 'है।']
# [['.', 'thinking', 'im', 'what', 'know', 'you']] [['तुम्हें', 'पता', 'है', 'मैं', 'क्या', 'सोच', 'रहा', 'हूँ', 'पता', 'है', '।']] ['तुम्हें', 'पता', 'है', 'कि', 'क्या', 'पता', 'है', '।']
# [['.', 'specialty', 'my', 'is', 'that', ',', 'cars', 'foreign']] [['विदेशी', 'कारों', ',', 'मेरी', 'विशेषता', 'है', 'कि', '।']] ['उस', 'मेरी', ',', 'मेरी', 'तरह', 'चला', 'गया', 'है', '।']
# [['.', 'boy', 'the', 'like', 'already', 'you']] [['आप', 'पहले', 'से', 'ही', 'लड़के', 'को', 'पसंद', 'करती', 'हैं', '।']] ['तुम', 'उसे', 'को', 'सकते', 'हो', '।']
# [['.', 'years', 'many', 'so', 'been', 'is', 'it']] [['बहुत', 'साल', 'हो', 'गए।']] ['यह', 'कोई', 'है', '?']
# [['.', 'hold', ',', 'tower', 'sally']] [['सैली', 'टॉवर,पकड़', '/', '।', '।', 'मैं']] ['हम', 'करने', 'के', 'लिए', 'जा', 'रहा', 'हूँ।']
# [['.', 'not', 'why', 'see', 'not', 'do', 'i']] [['हाँ', ',', 'बिलकुल।']] ['मैं', 'ऐसा', 'नहीं', 'नहीं', 'है।']
# [['?', 'that', 'know', 'you', 'do', 'how']] [['आप', 'कैसे', 'जानते', 'हो', '?']] ['आप', 'कैसे', 'लगता', 'है', 'कि', '?']
# [['pirate', 'a', 'be', 'must', 'he']] [['वह', 'एक', 'समुद्री', 'डाकू', 'होना', 'चाहिए']] ['उन्होंने']
# [['?', 'phone', 'the', 'is', 'where', ',', 'now']] [['फ़ोन', 'कहां', 'है', '?']] ['ठीक', 'है', ',', 'कुछ', 'वहाँ', 'है', '?']
# [['.', 'beatrice', 'is', 'name', 'her']] [['आपका', 'नाम', 'बीट्राइस', 'है', '।', '।', '।']] ['उसका', 'नाम', 'है', '।']
# [['.', 'ready', 'get', 'must', 'you', ',', 'come']] [['आओ', ',', 'तैयार', 'हो', 'जाओ', '।']] ['अब', ',', 'तुम', 'कि', 'छोड़', 'छोड़', 'दिया', '।']
# [['.', 'work', 'interesting', 'some', 'doing', 'are', 'they']] [['वे', 'कुछ', 'दिलचस्प', 'काम', 'कर', 'रहे', 'हैं।']] ['वे', 'यहाँ', 'से', 'कुछ', 'भी', 'सकते', 'हैं', '।']
# [['.', 'it', 'fix', 'can', 'i']] [['मैं', 'इसे', 'ठीक', 'कर', 'सकता', 'हूँ।']] ['मैं', 'इसे', 'यह', 'कर', 'सकते', 'हैं', '।']
# [['.', 'all', 'them', 'kill', 'will', 'i']] [['मैं', 'उन', 'सभी', 'को', 'मार', 'डालेगा।']] ['मैं', 'उन्हें', 'उन्हें', 'ले', 'होगा।']
# [['alone', 'advance', 'of', 'way', 'by']] [['अकेले', 'अग्रिम', 'के', 'वैसे']] ['एक', 'से', 'बाहर', '!']
# [['.', 'superman', 'is', 'projectile']] [['फेंकने', 'सुपरमैन', 'है।']] ['अब', 'एक', 'है', '।']
# [['.', 'papers', 'your', 'see', 'me', 'let']] [['मुझे', 'अपने', 'कागज', 'दिखाओ', '।']] ['मुझे', 'अपने', 'मदद', 'देखते', 'हैं', '।']
# [['?', 'nicely', 'me', 'asking', 'are', 'you', 'because']] [['आप', 'अच्छी', 'तरह', 'से', 'मुझसे', 'पूछ', 'रहे', 'क्योंकि', '?']] ['अब', 'तुम', 'मुझे', 'पता', '?']
# [['.', 'killed', 'get', 'not', 'do', 'you', 'careful']] [['सावधान', 'तुम', 'कहीं', 'मारे', 'न', 'जाओ', '।']] ['आप', 'कुछ', 'नहीं', 'करना', 'करना', 'है।']
# [['.', 'ghat', 'dasasvamedh', 'called', 'is', 'it']] [['इसे', 'दसास्वमेघ', 'घाट', 'कहा', 'जाता', 'है', '।']] ['यह', 'कुछ', 'की', 'तरह', 'दे', 'किया', 'है।']
# [['.', '.', '.', 'are', 'you', ',', 'maam', ',', 'sorry', 'im']] [['मैं', 'माफी', 'चाहता', 'हूँ', ',', 'मैडम', ',', 'आप', 'कर', 'रहे', 'हैं', '।', '।', '।']] ['मुझे', 'पता', 'है', ',', 'तुम', 'हो', ',', 'वह', 'की', 'हूँ', '।', '।', '।']
# [['.', 'explosion', 'an', 'been', 'is', 'there']] [['वहां', 'पर', 'एक', 'विस्फोट', 'हुआ', '।']] ['कोई', 'बात', 'क्या', 'है।']
# [['.', 'funny', 'that', 'not', 'definitely']] [['निश्चित', 'नहीं', 'हास्यास्पद', 'है', '।']] ['बहुत', 'कि', 'तरह', 'से', 'नहीं', 'करते', 'हैं', '।']
# [['"', '.', 'you', 'on', 'swear', 'i', '"sweetheart']] [['"जानेमन', 'मैं', 'तुम', 'पर', 'कसम', 'खाता', 'हूँ।', '"']] ['"जानेमन', 'मैं', 'तुम', 'पर', 'कसम', 'खाता', 'हूँ।', '"']
# [['.', 'want', 'you', 'if', 'yeah']] [['हां', 'अगर', 'तु', 'चाहो', '।']] ['तो', 'तुम', 'किया', '।']
# [['.', 'machatas', ',', 'better', 'know', 'you']] [['आप', 'machatas', 'बेहतर', 'जानते', 'हैं', '।']] ['तुम', 'मुझे', 'एक', 'होगा', ',', 'तुम', 'लो', '।']
# [['.', 'beautiful', 'very', 'grown', 'has', 'indira']] [['इंद्रा', 'बहुत', 'खूबसूरत', 'हो', 'गयी', 'है', '।']] ['तुम्हारे', 'पिता', 'के', 'साथ', 'भी', 'पता', 'है', '।']
# [['.', 'hungarian', 'im', ',', 'shit', 'the', 'cut']] [['गंदगी', 'काटो', ',', 'मैं', 'हंगेरी', 'हूँ', '।']] ['जनाब।']
# [['.', '.', '.', 'run', 'to', 'tried', 'parents', 'my']] [['मेरे', 'मातापिता', 'को', 'चलाने', 'की', 'कोशिश', 'की', '।', '।', '।']] ['मेरी', 'के', 'साथ', 'बोल', 'रहा', 'है।']
# [['.', 'anymore', 'talk', 'not', 'do', 'we']] [['हम', 'अब', 'और', 'बात', 'नहीं', 'करते', '।']] ['हम', 'एक', 'नहीं', 'हैं', '।']
# [['.', 'you', 'into', 'running', 'me', 'imagine']] [['मुझे', 'आप', 'में', 'चल', 'कल्पना', 'करो', '।']] ['मेरी', 'मदद', 'के', 'साथ', '।']
# [['?', 'it', 'stop', 'you', 'will']] [['आप', 'इसे', 'बंद', 'कर', 'देंगे', '?']] ['क्या', 'तुम', 'यह', 'इसे', 'चाहते', 'हो', '?']
# [['?', 'tony', ',', 'eh', ',', 'feelings', 'hard', 'no']] [['कटुता', 'तो', 'न', 'रखोगे', ',', 'हे', 'टोनी', '?']] ['कोई', 'लिए', ',', 'कोई', 'नहीं', ',', 'हैं', '?']
# [['.', 'tiptoe', 'ill', 'promise', 'i']] [['मैं', 'वादा', 'करता', 'हूं', 'कि', 'मैं', 'दबे', 'पांव', 'जाऊंगा', '।']] ['मैं', 'अपने', 'बाहर', 'को', 'देखो', '।']
# [['.', 'right', 'are', 'you', 'hope', 'only', 'i']] [['मुझे', 'आशा', 'है', 'कि', 'तुम', 'सही', 'हो', '।']] ['मैं', 'अभी', 'है', 'कि', 'तुम', 'से', 'भी', 'मिल', 'गया', 'है', '।']
# [['.', 'agent', 'good', 'a', 'is', 'she']] [['वह', 'एक', 'अच्छा', 'एजेंट', 'है', '!']] ['वह', 'एक', 'अच्छा', 'अच्छा', 'है', '।']
# [['?', 'mean', 'you', 'do', 'what']] [['तुम्हारा', 'क्या', 'मतलब', 'है', '?']] ['क्या', 'मतलब', 'है', 'तुम्हारा', '?']
# [['.', 'it', 'about', 'talk', 'not', 'is', 'let']] [['बारे', 'में', 'बात', 'यह', 'नहीं', 'है', '।']] ['चलो', 'यह', 'मतलब', 'नहीं', 'हैं', '।']
# [['consciousness', 'regained', 'has', 'he']] [['वह', 'होश', 'में', 'आ', 'चुके', 'हैं।']] ['वह', 'बहुत', 'थे', '!']
# [['.', 'to', 'have', 'we']] [['करना', 'होगा।']] ['हम', 'रहे', 'हैं।']
# [['.', 'me', 'to', 'talk', '.', '.', '.', 'just']] [['अभी', 'मुझसे', 'बात', 'करें।']] ['बस', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।', '।']
# [['.', 'well', 'too', 'feeling', 'not', 'im']] [['मैं', 'बहुत', 'अच्छा', 'महसूस', 'नहीं', 'कर', 'रहा', 'हूँ', '।']] ['मैं', 'नहीं', 'क्यों', 'सकता', '।']
# [['.', 'copy', 'is', 'father', 'my', 'was', 'this']] [['एक', 'नज़र', 'रखना', '।']] ['यह', 'मेरा', 'काम', 'नहीं', 'है।']
# [[]] [[]] ['बात', 'करो']
#
# 0.2999428890652999
# 0.3126072380301577

# %% [markdown]
# ##seq_attention

# %%
#!/usr/bin/env python
# coding: utf-8

# In[5]:


# get_ipython().run_line_magic('run', 'seq2seq.ipynb')


# In[2]:


class Attention(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.layer1 = nn.Linear(dim * 2, dim)
        self.layer2 = nn.Linear(dim, 1)
        
    def forward(self, source_h, target_h, source_mask=None):
        
        num_sentences, num_words = source_h.shape[:-1]
        target_h = target_h.repeat(1, num_words).reshape(num_words * num_sentences, -1)
        mlp_input = torch.cat((target_h, source_h.reshape(num_words * num_sentences, -1)
                              ), dim=1).reshape(num_words * num_sentences, -1)
        
        h1 = torch.tanh(self.layer1(mlp_input))
        h2 = self.layer2(h1)
        
        raw_weights = h2.reshape(num_sentences, num_words)
        
        if source_mask is not None:
            raw_weights = source_mask * raw_weights
        weights = torch.softmax(f.relu(raw_weights), dim=1)
        
        return torch.sum(weights.unsqueeze(-1) * source_h, dim=1)


# ```
# source_h = torch.Tensor(np.random.randint(0, 10, (2, 4, 10)))
# target_h = torch.Tensor(np.random.randint(0, 10, (2, 10)))
# a = Attention(10)
# a(source_h, target_h)
# ```

# In[11]:


class DecoderAttention(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0, start_dim=1):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.decoder = nn.LSTM(embedding_dim + hidden_dim, hidden_dim, num_layers, batch_first=True)
        self.word_predictor = nn.Linear(hidden_dim, num_embeddings)
        self.start_dim = start_dim
        
        self.attention = Attention(hidden_dim)
        
    def forward(self, output, h, c, input=None, max_sen_len=20, source_mask=None):
        
        source_h = output
        num_sentences, num_words, hidden_dim = output.shape
        words_selected = torch.LongTensor([[self.start_dim] for _ in range(num_sentences)])

        decoder_context = torch.zeros(num_sentences, hidden_dim).cuda()
        pred = []
        
        if input is not None:
            max_sen_len = input.shape[1]
            teacher_words = input.t()
        
        for i in range(max_sen_len):
            embeddings = self.embedding(words_selected)
            decoder_input = torch.cat((embeddings, decoder_context.unsqueeze(1)), dim=-1)
            y_t, (h, c) = self.decoder(decoder_input, (h, c))
            orig_shape = y_t.shape
            pred_t = self.word_predictor(y_t.reshape(orig_shape[0]*orig_shape[1], 
                                                     -1)).reshape(*orig_shape[:-1], -1).squeeze(1)
            pred.append(pred_t)
            decoder_context = self.attention(source_h, h[-1], source_mask)
            
            if input is None:
                words_selected = torch.max(pred_t, dim=1)[1].unsqueeze(1)
            else:
                words_selected = teacher_words[i].unsqueeze(1)


        pred = torch.stack(pred, dim=1)
        return torch.log_softmax(pred, dim=-1), None


# In[28]:


class Seq2SeqWithAttention(nn.Module):
    def __init__(self, source_vocab_len, target_vocab_len, embedding_dim, hidden_dim, num_layers=1,
                       padding_dim_source=0, start_dim_target=1, padding_dim_target=0):
        super().__init__()
        self.encoder = Encoder(source_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_source)
        self.decoder = DecoderAttention(target_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_target, start_dim_target)
        
    def forward(self, source_input, target_input=None, source_mask=None):
        output, h, c = self.encoder(source_input)
        return self.decoder(output, h, c, target_input, source_mask=source_mask)


# ```
# s = Seq2SeqWithAttention(10, 12, 9, 8)
# s.cuda()
# input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# target = torch.cuda.LongTensor(np.random.randint(0, 12, (3, 10))
# 
# # without teacher forcing
# s(input)
# 
# # with teacher forcing
# ```

# %%
#!/usr/bin/env python
# coding: utf-8

# In[30]:


# get_ipython().run_line_magic('run', 'utils.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq_with_attention.ipynb')
# get_ipython().run_line_magic('run', 'effective_approaches.ipynb')
# get_ipython().run_line_magic('run', 'coverage.ipynb')


# In[4]:

# device = 'cuda' if torch.cuda.is_available() else 'cpu'
# m.to(device)
# torch.cuda.set_dezce(0)
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# In[24]:


d = Dataset(source_files, target_files, batch_size=10)
embedding_dim = 50
hidden_dim = 100
num_layers = 2


# In[25]:


def train_and_save(m, d, str_, coverage=False, coverage_type="linguistic", log=False):
    prev_score = -1
    for i in range(20):
        train(m, d, coverage, coverage_type, log=log)
        score = eval(m, d, log=True)
        best_state = None
        print()
        print(score)
        if score > prev_score:
            #torch.save(m.state_dict(), str_ + str(score)[:4] + ".params_")
            best_state = m.state_dict()
            prev_score = score
            
    torch.save(best_state, str_ + str(prev_score)[:4] + ".params")
    print(prev_score)


m = Seq2SeqWithAttention(d.len_source, d.len_target, embedding_dim, hidden_dim, num_layers=2, 
            padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
# print(m.cuda())
train_and_save(m, d, "attention_")

# %% [markdown]
# #try

# %%
import pandas as pd
df = pd.read_pickle('en_hi.pkl')
train, validate, test = np.split(df.sample(frac=1), [int(.7*len(df)), int(.8*len(df))])
print(train.shape, validate.shape, test.shape)
# Out:
# (7000, 2) (1000, 2) (2000, 2)

# %%
with open('/content/drive/My Drive/NeuralMT/data/dev.en', 'w') as writefile:
    writefile.write(('').join(validate['english']))
with open('/content/drive/My Drive/NeuralMT/data/dev.hi', 'w') as writefile:
    writefile.write(('').join(validate['hindi']))
with open('/content/drive/My Drive/NeuralMT/data/test.en', 'w') as writefile:
    writefile.write(('').join(test['english']))
with open('/content/drive/My Drive/NeuralMT/data/test.hi', 'w') as writefile:
    writefile.write(('').join(test['hindi']))
with open('/content/drive/My Drive/NeuralMT/data/train.en', 'w') as writefile:
    writefile.write(('').join(train['english']))
with open('/content/drive/My Drive/NeuralMT/data/train.hi', 'w') as writefile:
    writefile.write(('').join(train['hindi']))

# %%
data_folder = "data"
files = os.listdir(data_folder)
source_files = [os.path.join(data_folder, file) for file in files if ".en" in file]
target_files = [os.path.join(data_folder, file) for file in files if ".hi" in file]
print(source_files)

def generate_vocab(filenames):
    vocab = set()
    # no_words = 0
    for file in filenames:
        content = open(file).read()
        sentences = [sentence.split() for sentence in content.split('\n')]
        for sentence in sentences:
            for word in sentence:
                if word.lower() not in vocab:
                    vocab.add(word.lower())
                    # no_words += 1
    vocab = {word: num for num, word in enumerate(vocab)}
    return vocab

def parse_files_to_indices(filename, vocab):
    content = open(filename).read()
    return [[vocab[word] for word in sentence.split() if word in vocab] for sentence in content.split('\n')]

class Dataset:
    def __init__(self, source_files, target_files, batch_size=10):
        self.source_vocab = generate_vocab(source_files) #for entire lang
        self.target_vocab = generate_vocab(target_files) #for entire lang
        
        self.len_source = len(self.source_vocab.keys())
        self.source_pad, self.source_start, self.source_end = self.len_source + 2, self.len_source + 1, self.len_source
        self.len_target = len(self.target_vocab.keys())
        self.target_pad, self.target_start, self.target_end = self.len_target + 2, self.len_target + 1, self.len_target
        
        self.source_vocab['<pad>'], self.source_vocab['<start>'], self.source_vocab['<end>'] = [self.source_pad, 
                                                                                                self.source_start, 
                                                                                                self.source_end]
        self.target_vocab['<pad>'], self.target_vocab['<start>'], self.target_vocab['<end>'] = [self.target_pad,
                                                                                                self.target_start, 
                                                                                                self.target_end]
                                                                                              
        ##created indices for <pad>, <start> and <end> tokens
        self.len_source = len(self.source_vocab.keys())
        self.len_target = len(self.target_vocab.keys())
        
        ##inverse vocab for entire lang
        self.source_vocab_inv = {value:key for key, value in self.source_vocab.items()}
        self.target_vocab_inv = {value:key for key, value in self.target_vocab.items()}
        
        ##parsing files into indices
        for filename in source_files:
            if 'train' in filename:
                self.source_train = parse_files_to_indices(filename, self.source_vocab)
            if 'test' in filename:
                self.source_test = parse_files_to_indices(filename, self.source_vocab)
            if 'dev' in filename:
                self.source_dev = parse_files_to_indices(filename, self.source_vocab)
                
        for filename in target_files:
            if 'train' in filename:
                self.target_train = parse_files_to_indices(filename, self.target_vocab)
            if 'test' in filename:
                self.target_test = parse_files_to_indices(filename, self.target_vocab)
            if 'dev' in filename:
                self.target_dev = parse_files_to_indices(filename, self.target_vocab)
                
        ##random shuffling of training data before splitting into batches    
        self.indices = list(range(len(self.source_train)))
        random.shuffle(self.indices)
        self.current = -batch_size
        self.batch_size = batch_size
        
    def __get_batch_input(self, indices):
        source, target_input, target_target = [], [], []
        
        # padding length of sentence
        source_max_len = max(len(self.source_train[i]) for i in indices)
        target_max_len = max(len(self.target_train[i]) for i in indices)
        
        for i in indices:
            length = len(self.source_train[i])
            # reverse_source_sentences and pad at beginning
            sentence = [self.source_pad for _ in range(source_max_len - length)] + [self.source_end] + self.source_train[i][::-1] + [self.source_start]
            source.append(sentence)
            
            length = len(self.target_train[i])
            # padding at end for target
            sentence = [self.target_start] + self.target_train[i] + [self.target_end] + [self.target_pad for _ in range(target_max_len - length)]
            target_input.append(sentence)
            #removed <sos> and put <pad> at end
            target_target.append(sentence[1:] + [self.target_pad])
            
        return np.array(source), np.array(target_input), np.array(target_target)
    
    def get_batch_input(self):
        if self.current > len(self.indices) - self.batch_size:
            self.current = 0
            return None, None, None
        self.current += self.batch_size
        return self.__get_batch_input(self.indices[self.current: self.current + self.batch_size])
    
    def convert_indices_to_words(self, indices):
        output = []
        for sentence in indices:
            s = []
            for word in sentence:
                s.append(self.target_vocab_inv[word])
            output.append(s)
        return output


# ```
# %run seq2seq.ipynb
# 
# d = Dataset(source_files, target_files, 10)
# m = Seq2Seq(d.len_source, d.len_target, 9, 7)
# m.cuda()
# 
# a, b = d.get_batch_input()
# source, target = torch.cuda.LongTensor(a), torch.cuda.LongTensor(b)
# 
# # For teacher forcing:
# m(source, target)
# 
# # Using model's own predictions:
# m(source)
# ```

# In[37]:


def train(model, dataset, coverage=False, coverage_type="linguistic", iterations=1, use_teacher_forcing=True, log=True):
    # TODO: attention error
    loss_func = nn.NLLLoss()
    attn_loss_func = nn.MSELoss()
    
    optimizer = optim.Adagrad(model.parameters()) 
    
    for i in range(iterations):
        while True:
            optimizer.zero_grad() #set the gradients to zero before starting to do backpropragation because PyTorch accumulates the gradients on subsequent backward passes.
            source, target_input, target_output = d.get_batch_input() #sentences made into indices and padded to sentence lenght 

            if source is None: # end of current iteration
                break

            source, target_input, target_output = [torch.cuda.LongTensor(source), 
                                                   torch.cuda.LongTensor(target_input), 
                                                   torch.cuda.LongTensor(target_output)]
            
            source_mask = torch.ones(source.shape).cuda()
            source_mask[source == dataset.source_pad] = 0
            
            if use_teacher_forcing:
                pred, attn = model(source, target_input, source_mask=source_mask)
                # mask whatevers after <stop> 
                target_mask = torch.ones(target_output.shape).cuda()
                target_mask[target_output == dataset.target_pad] = 0
                pred = pred * target_mask.unsqueeze(-1)
                target_output = target_output * target_mask.long()
            else:
                pred, attn_weights = model(source)
                
            no_words = pred.shape[0] * pred.shape[1]
            pred = pred.reshape(no_words, -1)
            target_output = target_output.reshape(no_words)

            pred_error = loss_func(pred, target_output)
            attn_error = None
            
            if coverage:
                # if coverage type is linguistic, ignore fertility
                attn_weights, fertility = attn
                if coverage_type == "linguistic":
                    fertility = torch.ones(fertility.shape).cuda()
                attn_error = attn_loss_func(torch.sum(attn_weights, dim=-1) * source_mask, fertility * source_mask)
                pred_error += attn_error
                
            pred_error.backward() #backward prop
            optimizer.step()
            
            if log:
                print(d.current/d.batch_size, pred_error, end='\r')


# In[38]:


def convert_pred_to_indices(pred):
    return torch.max(pred, dim=-1)[1]


# In[39]:


def eval(model, dataset, log=False, source_test=None, target_test=None):
    scores = []
    if source_test is None:
        source_test = dataset.source_test
        target_test = dataset.target_test
        
    for sentence, target in zip(source_test, target_test):
        input = torch.cuda.LongTensor([[dataset.source_end] + sentence[::-1] + [dataset.source_start]])
        pred, _ = model(input)
        pred_words = convert_pred_to_indices(pred).cpu().numpy()
        predicted_target = dataset.convert_indices_to_words(pred_words)
        target = dataset.convert_indices_to_words([target])
        if log:
            print(target, predicted_target[0])
        scores.append(sentence_bleu(target, predicted_target[0], weights=(1, 0, 0, 0)))
    return sum(scores)/len(scores)
# Out:
# ['data/dev.en', 'data/test.en', 'data/train.en']

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:


import numpy as np


# In[2]:


import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as f


# In[3]:


class Encoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.encoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        
    def forward(self, input):
        '''
        input dim => 2d no_sentences * no_words
        make sure that the input is in reverse
        
        Outputs:
        output, h, c
        
        output => dim: (num_sentences * num_words * hidden_dim)
        h => (num_layers * num_sentences * hidden_dim)
        c => (num_layers * num_sentences * hidden_dim)
        '''
        embeddings = self.embedding(input)
        output, (h, c) = self.encoder(embeddings)
        
        return output, h, c


# In[4]:


class Decoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0, start_dim=1):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.decoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        self.word_predictor = nn.Linear(hidden_dim, num_embeddings)
        self.start_dim = start_dim
        
    def forward(self, output, h, c, input=None, max_sen_len=20):
        '''
        Output:
        pred: (no_sentences * no_words * no_embeddings)
        **Note: if input is not None, log_softmax is returned
        else, input is returned without softmax**
        '''
        
        if input is not None: # training with teacher forcing
            
            embeddings = self.embedding(input)
            yts, _ = self.decoder(embeddings, (h, c))
            orig_shape = yts.shape
            pred = self.word_predictor(yts.reshape(orig_shape[0]*orig_shape[1], -1)).reshape(*orig_shape[:-1], -1)
            return torch.log_softmax(pred, dim=-1), None
        
        else: # training using the decoders' own predictions
            
            num_sentences = output.shape[0]
            words_selected = torch.cuda.LongTensor([[self.start_dim] for _ in range(num_sentences)])
            pred = []
            for i in range(max_sen_len):
                embeddings = self.embedding(words_selected)
                y_t, (h, c) = self.decoder(embeddings, (h, c))
                orig_shape = y_t.shape
                pred_t = self.word_predictor(y_t.reshape(orig_shape[0]*orig_shape[1], 
                                                         -1)).reshape(*orig_shape[:-1], -1).squeeze(1)
                pred.append(pred_t)
                words_selected = torch.max(pred_t, dim=1)[1].unsqueeze(1)
            
            pred = torch.stack(pred, dim=1)
            return torch.log_softmax(pred, dim=-1), None


# In[5]:


class Seq2Seq(nn.Module):
    def __init__(self, source_vocab_len, target_vocab_len, embedding_dim, hidden_dim, num_layers=1,
                       padding_dim_source=0, start_dim_target=1, padding_dim_target=0):
        super().__init__()
        self.encoder = Encoder(source_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_source)
        self.decoder = Decoder(target_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_target, start_dim_target)
        
    def forward(self, source_input, target_input=None, source_mask=None):
        output, h, c = self.encoder(source_input)
        return self.decoder(output, h, c, target_input)


# **Without teacher forcing**
# ```
# input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s = Seq2Seq(10, 12, 9, 7)
# s.cuda()
# pred = s(input)
# ```

# **With teacher forcing**
# 
# ```
# tar_input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s(input, tar_input).shape
# ```

# In[ ]:

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)
# Out:
# cpu

# %%
#!/usr/bin/env python
# coding: utf-8

# In[30]:


# get_ipython().run_line_magic('run', 'utils.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq_with_attention.ipynb')
# get_ipython().run_line_magic('run', 'effective_approaches.ipynb')
# get_ipython().run_line_magic('run', 'coverage.ipynb')


# In[4]:

# device = 'cuda' if torch.cuda.is_available() else 'cpu'
# m.to(device)
torch.cuda.set_device(0)
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# In[24]:


d = Dataset(source_files, target_files, batch_size=10)
embedding_dim = 50
hidden_dim = 100
num_layers = 2


# In[25]:


def train_and_save(m, d, str_, coverage=False, coverage_type="linguistic", log=False):
    prev_score = -1
    for i in range(20):
        train(m, d, coverage, coverage_type, log=log)
        score = eval(m, d)
        best_state = None
        print()
        print(score)
        if score > prev_score:
            #torch.save(m.state_dict(), str_ + str(score)[:4] + ".params_")
            best_state = m.state_dict()
            prev_score = score
            
    torch.save(best_state, str_ + str(prev_score)[:4] + ".params")
    print(prev_score)


# In[26]:

m = Seq2Seq(d.len_source, d.len_target, embedding_dim, hidden_dim, num_layers=2, 
            padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
#print(m.cuda())
train_and_save(m, d, "seq2seq_")


# In[ ]:


# m = Seq2SeqWithAttention(d.len_source, d.len_target, embedding_dim, hidden_dim, num_layers=2, 
#             padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
# print(m.cuda())
# train_and_save(m, d, "attention_")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-2817b5358971> in <module>()
#      16 # device = 'cuda' if torch.cuda.is_available() else 'cpu'
#      17 # m.to(device)
# ---> 18 torch.cuda.set_device(0)
#      19 # device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#      20
#
# /usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py in set_device(device)
#     279     device = _get_device_index(device)
#     280     if device >= 0:
# --> 281         torch._C._cuda_setDevice(device)
#     282
#     283
#
# /usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py in _lazy_init()
#     188             raise AssertionError(
#     189                 "libcudart functions unavailable. It looks like you have a broken build?")
# --> 190         torch._C._cuda_init()
#     191         # Some of the queued calls may reentrantly call _lazy_init();
#     192         # we need to just return without initializing in that case.
#
# RuntimeError: cuda runtime error (100) : no CUDA-capable device is detected at /pytorch/aten/src/THC/THCGeneral.cpp:47

# %% [markdown]
# #utils

# %%
data_folder = "data"
files = os.listdir(data_folder)
source_files = [os.path.join(data_folder, file) for file in files if ".en" in file]
target_files = [os.path.join(data_folder, file) for file in files if ".hi" in file]
#print(source_files)

def generate_vocab(filenames):
    vocab = set()
    no_words = 0
    for file in filenames:
        content = open(file).read()
        sentences = [sentence.split() for sentence in content.split('\n')]
        for sentence in sentences:
            for word in sentence:
                if word.lower() not in vocab:
                    vocab.add(word.lower())
                    no_words += 1
    vocab = {word: num for num, word in enumerate(vocab)}
    return vocab

def parse_files_to_indices(filename, vocab):
    content = open(filename).read()
    return [[vocab[word] for word in sentence.split() if word in vocab] for sentence in content.split('\n')]

class Dataset:
    def __init__(self, source_files, target_files, batch_size=10):
        self.source_vocab = generate_vocab(source_files)
        self.target_vocab = generate_vocab(target_files)
        
        self.len_source = len(self.source_vocab.keys())
        self.source_pad, self.source_start, self.source_end = self.len_source + 2, self.len_source + 1, self.len_source
        self.len_target = len(self.target_vocab.keys())
        self.target_pad, self.target_start, self.target_end = self.len_target + 2, self.len_target + 1, self.len_target
        
        self.source_vocab['<pad>'], self.source_vocab['<start>'], self.source_vocab['<end>'] = [self.source_pad, 
                                                                                                self.source_start, 
                                                                                                self.source_end]
        self.target_vocab['<pad>'], self.target_vocab['<start>'], self.target_vocab['<end>'] = [self.target_pad,
                                                                                                self.target_start, 
                                                                                                self.target_end]
        self.len_source = len(self.source_vocab.keys())
        self.len_target = len(self.target_vocab.keys())
        
        self.source_vocab_inv = {value:key for key, value in self.source_vocab.items()}
        self.target_vocab_inv = {value:key for key, value in self.target_vocab.items()}


        for filename in source_files:
            if 'train' in filename:
                self.source_train = parse_files_to_indices(filename, self.source_vocab)
            if 'test' in filename:
                self.source_test = parse_files_to_indices(filename, self.source_vocab)
            if 'dev' in filename:
                self.source_dev = parse_files_to_indices(filename, self.source_vocab)
                
        for filename in target_files:
            if 'train' in filename:
                self.target_train = parse_files_to_indices(filename, self.target_vocab)
            if 'test' in filename:
                self.target_test = parse_files_to_indices(filename, self.target_vocab)
            if 'dev' in filename:
                self.target_dev = parse_files_to_indices(filename, self.target_vocab)
                
            
        self.indices = list(range(len(self.source_train)))
        random.shuffle(self.indices)
        self.current = -batch_size
        self.batch_size = batch_size
        
    def __get_batch_input(self, indices):
        source, target_input, target_target = [], [], []
        
        # padding length
        source_max_len = max(len(self.source_train[i]) for i in indices)
        target_max_len = max(len(self.target_train[i]) for i in indices)
        
        for i in indices:
            length = len(self.source_train[i])
            # reverse_source_sentences and pad at beginning
            sentence = [self.source_pad for _ in range(source_max_len - length)] + [self.source_end] + self.source_train[i][::-1] + [self.source_start]
            source.append(sentence)
            
            length = len(self.target_train[i])
            # padding at end for target
            sentence = [self.target_start] + self.target_train[i] + [self.target_end] + [self.target_pad for _ in range(target_max_len - length)]
            target_input.append(sentence)
            target_target.append(sentence[1:] + [self.target_pad])
            
        return np.array(source), np.array(target_input), np.array(target_target)
    
    def get_batch_input(self):
        if self.current > len(self.indices) - self.batch_size:
            self.current = 0
            return None, None, None
        self.current += self.batch_size
        return self.__get_batch_input(self.indices[self.current: self.current + self.batch_size])
    
    def convert_indices_to_words(self, indices):
        output = []
        for sentence in indices:
            s = []
            for word in sentence:
                s.append(self.target_vocab_inv[word])
            output.append(s)
        return output


# ```
# %run seq2seq.ipynb
# 
# d = Dataset(source_files, target_files, 10)
# m = Seq2Seq(d.len_source, d.len_target, 9, 7)
# m.cuda()
# 
# a, b = d.get_batch_input()
# source, target = torch.cuda.LongTensor(a), torch.cuda.LongTensor(b)
# 
# # For teacher forcing:
# m(source, target)
# 
# # Using model's own predictions:
# m(source)
# ```

# In[37]:


def train(model, dataset, coverage=False, coverage_type="linguistic", iterations=1, use_teacher_forcing=False, log=True):
    # TODO: attention error
    loss_func = nn.NLLLoss()
    attn_loss_func = nn.MSELoss()
    
    optimizer = optim.Adagrad(model.parameters())
    
    for i in range(iterations):
        while True:
            optimizer.zero_grad()
            source, target_input, target_output = d.get_batch_input()

            if source is None: # end of current iteration
                break

            source, target_input, target_output = [torch.cuda.LongTensor(source), 
                                                   torch.cuda.LongTensor(target_input), 
                                                   torch.cuda.LongTensor(target_output)]
            
            source_mask = torch.ones(source.shape).cuda()
            source_mask[source == dataset.source_pad] = 0
            
            if use_teacher_forcing:
                pred, attn = model(source, target_input, source_mask=source_mask)
                # mask whatevers after <stop> 
                target_mask = torch.ones(target_output.shape).cuda()
                target_mask[target_output == dataset.target_pad] = 0
                pred = pred * target_mask.unsqueeze(-1)
                target_output = target_output * target_mask.long()
            else:
                pred, attn_weights = model(source.cuda())
                
            no_words = pred.shape[0] * pred.shape[1]
            pred = pred.reshape(no_words, -1)
            target_output = target_output.reshape(no_words)

            pred_error = loss_func(pred, target_output)
            attn_error = None
            
            if coverage:
                # if coverage type is linguistic, ignore fertility
                attn_weights, fertility = attn
                if coverage_type == "linguistic":
                    fertility = torch.ones(fertility.shape).cuda()
                attn_error = attn_loss_func(torch.sum(attn_weights, dim=-1) * source_mask, fertility * source_mask)
                pred_error += attn_error
                
            pred_error.backward()
            optimizer.step()
            
            if log:
                print(d.current/d.batch_size, pred_error, end='\r')


# In[38]:


def convert_pred_to_indices(pred):
    return torch.max(pred, dim=-1)[1]


# In[39]:


def eval(model, dataset, log=False, source_test=None, target_test=None):
    scores = []
    if source_test is None:
        source_test = dataset.source_test
        target_test = dataset.target_test
        
    for sentence, target in zip(source_test, target_test):
        input = torch.cuda.LongTensor([[dataset.source_end] + sentence[::-1] + [dataset.source_start]])
        pred, _ = model(input)
        pred_words = convert_pred_to_indices(pred).cpu().numpy()
        predicted_target = dataset.convert_indices_to_words(pred_words)
        target = dataset.convert_indices_to_words([target])
        if log:
            print(target, predicted_target[0])
        scores.append(sentence_bleu(target, predicted_target[0], weights=(1, 0, 0, 0)))
    return sum(scores)/len(scores)


# In[ ]:





# In[ ]:

# %% [markdown]
# #seq2seq

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as f

class Encoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.encoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        
    def forward(self, input):
        '''
        input dim => 2d no_sentences * no_words
        make sure that the input is in reverse
        
        Outputs:
        output, h, c
        
        output => dim: (num_sentences * num_words * hidden_dim)
        h => (num_layers * num_sentences * hidden_dim)
        c => (num_layers * num_sentences * hidden_dim)
        '''
        embeddings = self.embedding(input)
        output, (h, c) = self.encoder(embeddings)
        
        return output, h, c

class Decoder(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0, start_dim=1):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.decoder = nn.LSTM(embedding_dim, hidden_dim, num_layers, batch_first=True)
        self.word_predictor = nn.Linear(hidden_dim, num_embeddings)
        self.start_dim = start_dim
        
    def forward(self, output, h, c, input=None, max_sen_len=20):
        '''
        Output:
        pred: (no_sentences * no_words * no_embeddings)
        **Note: if input is not None, log_softmax is returned
        else, input is returned without softmax**
        '''
        
        if input is not None: # training with teacher forcing
            
            embeddings = self.embedding(input)
            yts, _ = self.decoder(embeddings, (h, c))
            orig_shape = yts.shape
            pred = self.word_predictor(yts.reshape(orig_shape[0]*orig_shape[1], -1)).reshape(*orig_shape[:-1], -1)
            return torch.log_softmax(pred, dim=-1), None
        
        else: # training using the decoders' own predictions
            
            num_sentences = output.shape[0]
            words_selected = torch.cuda.LongTensor([[self.start_dim] for _ in range(num_sentences)])
            pred = []
            for i in range(max_sen_len):
                embeddings = self.embedding(words_selected)
                y_t, (h, c) = self.decoder(embeddings, (h, c))
                orig_shape = y_t.shape
                pred_t = self.word_predictor(y_t.reshape(orig_shape[0]*orig_shape[1], 
                                                         -1)).reshape(*orig_shape[:-1], -1).squeeze(1)
                pred.append(pred_t)
                words_selected = torch.max(pred_t, dim=1)[1].unsqueeze(1)
            
            pred = torch.stack(pred, dim=1)
            return torch.log_softmax(pred, dim=-1), None


# In[5]:


class Seq2Seq(nn.Module):
    def __init__(self, source_vocab_len, target_vocab_len, embedding_dim, hidden_dim, num_layers=1,
                       padding_dim_source=0, start_dim_target=1, padding_dim_target=0):
        super().__init__()
        self.encoder = Encoder(source_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_source)
        self.decoder = Decoder(target_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_target, start_dim_target)
        
    def forward(self, source_input, target_input=None, source_mask=None):
        output, h, c = self.encoder(source_input)
        return self.decoder(output, h, c, target_input)


# **Without teacher forcing**
# ```
# input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s = Seq2Seq(10, 12, 9, 7)
# s.cuda()
# pred = s(input)
# ```

# **With teacher forcing**
# 
# ```
# tar_input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# s(input, tar_input).shape
# ```

# In[ ]:

# %% [markdown]
# #seg2seq - attention

# %%
#!/usr/bin/env python
# coding: utf-8

# In[5]:


# get_ipython().run_line_magic('run', 'seq2seq.ipynb')


# In[2]:


class Attention(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.layer1 = nn.Linear(dim * 2, dim)
        self.layer2 = nn.Linear(dim, 1)
        
    def forward(self, source_h, target_h, source_mask=None):
        
        num_sentences, num_words = source_h.shape[:-1]
        target_h = target_h.repeat(1, num_words).reshape(num_words * num_sentences, -1)
        mlp_input = torch.cat((target_h, source_h.reshape(num_words * num_sentences, -1)
                              ), dim=1).reshape(num_words * num_sentences, -1)
        
        h1 = torch.tanh(self.layer1(mlp_input))
        h2 = self.layer2(h1)
        
        raw_weights = h2.reshape(num_sentences, num_words)
        
        if source_mask is not None:
            raw_weights = source_mask * raw_weights
        weights = torch.softmax(f.relu(raw_weights), dim=1)
        
        return torch.sum(weights.unsqueeze(-1) * source_h, dim=1)


# ```
# source_h = torch.Tensor(np.random.randint(0, 10, (2, 4, 10)))
# target_h = torch.Tensor(np.random.randint(0, 10, (2, 10)))
# a = Attention(10)
# a(source_h, target_h)
# ```

# In[11]:


class DecoderAttention(nn.Module):
    def __init__(self, num_embeddings, embedding_dim, hidden_dim, num_layers, padding_dim=0, start_dim=1):
        super().__init__()
        self.embedding = nn.Embedding(num_embeddings, embedding_dim, padding_dim)
        self.decoder = nn.LSTM(embedding_dim + hidden_dim, hidden_dim, num_layers, batch_first=True)
        self.word_predictor = nn.Linear(hidden_dim, num_embeddings)
        self.start_dim = start_dim
        
        self.attention = Attention(hidden_dim)
        
    def forward(self, output, h, c, input=None, max_sen_len=20, source_mask=None):
        
        source_h = output
        num_sentences, num_words, hidden_dim = output.shape
        words_selected = torch.cuda.LongTensor([[self.start_dim] for _ in range(num_sentences)])

        decoder_context = torch.zeros(num_sentences, hidden_dim).cuda()
        pred = []
        
        if input is not None:
            max_sen_len = input.shape[1]
            teacher_words = input.t()
        
        for i in range(max_sen_len):
            embeddings = self.embedding(words_selected)
            decoder_input = torch.cat((embeddings, decoder_context.unsqueeze(1)), dim=-1)
            y_t, (h, c) = self.decoder(decoder_input, (h, c))
            orig_shape = y_t.shape
            pred_t = self.word_predictor(y_t.reshape(orig_shape[0]*orig_shape[1], 
                                                     -1)).reshape(*orig_shape[:-1], -1).squeeze(1)
            pred.append(pred_t)
            decoder_context = self.attention(source_h, h[-1], source_mask)
            
            if input is None:
                words_selected = torch.max(pred_t, dim=1)[1].unsqueeze(1)
            else:
                words_selected = teacher_words[i].unsqueeze(1)


        pred = torch.stack(pred, dim=1)
        return torch.log_softmax(pred, dim=-1), None


# In[28]:


class Seq2SeqWithAttention(nn.Module):
    def __init__(self, source_vocab_len, target_vocab_len, embedding_dim, hidden_dim, num_layers=1,
                       padding_dim_source=0, start_dim_target=1, padding_dim_target=0):
        super().__init__()
        self.encoder = Encoder(source_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_source)
        self.decoder = DecoderAttention(target_vocab_len, embedding_dim, hidden_dim, num_layers, padding_dim_target, start_dim_target)
        
    def forward(self, source_input, target_input=None, source_mask=None):
        output, h, c = self.encoder(source_input)
        return self.decoder(output, h, c, target_input, source_mask=source_mask)


# ```
# s = Seq2SeqWithAttention(10, 12, 9, 8)
# s.cuda()
# input = torch.cuda.LongTensor(np.random.randint(0, 10, (3, 6)))
# target = torch.cuda.LongTensor(np.random.randint(0, 12, (3, 10))
# 
# # without teacher forcing
# s(input)
# 
# # with teacher forcing
# ```
# Out:
# ERROR:root:File `'seq2seq.ipynb.py'` not found.

# %% [markdown]
# #train&test

# %%
#!/usr/bin/env python
# coding: utf-8

# In[30]:


# get_ipython().run_line_magic('run', 'utils.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq.ipynb')
# get_ipython().run_line_magic('run', 'seq2seq_with_attention.ipynb')
# get_ipython().run_line_magic('run', 'effective_approaches.ipynb')
# get_ipython().run_line_magic('run', 'coverage.ipynb')


# In[4]:


torch.cuda.set_device(0)

# In[24]:


d = Dataset(source_files, target_files, batch_size=10)
embedding_dim = 50
hidden_dim = 100
num_layers = 2


# In[25]:


def train_and_save(m, d, str_, coverage=False, coverage_type="linguistic", log=False):
    prev_score = -1
    for i in range(20):
        train(m, d, coverage, coverage_type, log=log).cuda()
        score = eval(m, d)
        best_state = None
        print()
        print(score)
        if score > prev_score:
            #torch.save(m.state_dict(), str_ + str(score)[:4] + ".params_")
            best_state = m.state_dict()
            prev_score = score
            
    torch.save(best_state, str_ + str(prev_score)[:4] + ".params")
    print(prev_score)


# In[26]:


m = Seq2Seq(d.len_source, d.len_target, embedding_dim, hidden_dim, num_layers=2, 
            padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
#print(m.cuda())
train_and_save(m, d, "seq2seq_")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-2805b0465dfc> in <module>()
#      52             padding_dim_source=d.source_pad, padding_dim_target=d.target_pad, start_dim_target=d.target_start)
#      53 #print(m.cuda())
# ---> 54 train_and_save(m, d, "seq2seq_")
#
# <ipython-input-14-2805b0465dfc> in train_and_save(m, d, str_, coverage, coverage_type, log)
#      32     prev_score = -1
#      33     for i in range(20):
# ---> 34         train(m, d, coverage, coverage_type, log=log)
#      35         score = eval(m, d)
#      36         best_state = None
#
# <ipython-input-12-ac4886a94d35> in train(model, dataset, coverage, coverage_type, iterations, use_teacher_forcing, log)
#     156                 target_output = target_output * target_mask.long()
#     157             else:
# --> 158                 pred, attn_weights = model(source.cuda())
#     159
#     160             no_words = pred.shape[0] * pred.shape[1]
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# <ipython-input-13-9c6481183ac7> in forward(self, source_input, target_input, source_mask)
#      81
#      82     def forward(self, source_input, target_input=None, source_mask=None):
# ---> 83         output, h, c = self.encoder(source_input)
#      84         return self.decoder(output, h, c, target_input)
#      85
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# <ipython-input-13-9c6481183ac7> in forward(self, input)
#      23         c => (num_layers * num_sentences * hidden_dim)
#      24         '''
# ---> 25         embeddings = self.embedding(input)
#      26         output, (h, c) = self.encoder(embeddings)
#      27
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/sparse.py in forward(self, input)
#     124         return F.embedding(
#     125             input, self.weight, self.padding_idx, self.max_norm,
# --> 126             self.norm_type, self.scale_grad_by_freq, self.sparse)
#     127
#     128     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    1812         # remove once script supports set_grad_enabled
#    1813         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 1814     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    1815
#    1816
#
# RuntimeError: Expected object of device type cuda but got device type cpu for argument #1 'self' in call to _th_index_select
